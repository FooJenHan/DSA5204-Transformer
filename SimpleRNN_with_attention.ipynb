# %% [markdown]
# # RNN with attention architecture
#
# ## NN for language translation (Portugese to English)
#
# Will extract weights from the training.

# %%
pip install -q tensorflow_datasets

# %%
pip install -q tensorflow-text

# %%
import collections
import logging
import os
import pathlib
import re
import string
import sys
import time

import numpy as np
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds
import tensorflow_text as text

import tensorflow as tf

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set(font_scale=1.5)

import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata

import pickle

os.environ["TF_FORCE_GPU_ALLOW_GROWTH"]="true"

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
examples, metadata = tfds.load('ted_hrlr_translate/pt_to_en', with_info=True,
                               as_supervised=True)

# %%
examples
# Out:
# {'test': <PrefetchDataset shapes: ((), ()), types: (tf.string, tf.string)>,
#  'train': <PrefetchDataset shapes: ((), ()), types: (tf.string, tf.string)>,
#  'validation': <PrefetchDataset shapes: ((), ()), types: (tf.string, tf.string)>}

# %%
train_examples, val_examples = examples['train'], examples['validation']

# %%
train_examples
# Out:
# <PrefetchDataset shapes: ((), ()), types: (tf.string, tf.string)>

# %%
# no of examples: 51785
for pt_examples, en_examples in train_examples.batch(1).take(20):
  for pt in pt_examples.numpy():
    print(pt.decode('utf-8'))

  for en in en_examples.numpy():
    print(en.decode('utf-8'))
  
  print()
# Out:
# e quando melhoramos a procura , tiramos a única vantagem da impressão , que é a serendipidade .
# and when you improve searchability , you actually take away the one advantage of print , which is serendipity .
#
# mas e se estes fatores fossem ativos ?
# but what if it were active ?
#
# mas eles não tinham a curiosidade de me testar .
# but they did n't test for curiosity .
#
# e esta rebeldia consciente é a razão pela qual eu , como agnóstica , posso ainda ter fé .
# and this conscious defiance is why i , as an agnostic , can still have faith .
#
# `` `` '' podem usar tudo sobre a mesa no meu corpo . ''
# you can use everything on the table on me .
#
# `` eu escrevo muito acerca do `` '' teatro de segurança '' '' , que são produtos que fazem as pessoas sentirem-se seguras mas que , na realidade , não fazem nada . ''
# `` i write a lot about `` '' security theater , '' '' which are products that make people feel secure , but do n't actually do anything . ''
#
# colocaram-no bem no fundo duma mina de ferro no minnesota , nos últimos dois dias anunciaram os resultados mais sensíveis até agora .
# and they 've put it deep down in an iron mine in minnesota , ok , deep under the ground , and in fact , in the last couple of days announced the most sensitive results so far .
#
# algumas pessoas têm medo de que não gostem delas .
# see , some people might fear girls not liking them back .
#
# não , o que nos aconteceu , chris , é que o poder , o preço está fixado fora da margem .
# no , what happened to us , chris , is that power , it 's priced off the margin .
#
# de volta à minha pergunta : porque é que fiquei ?
# back to my question : why did i stay ?
#
# `` quando descobri que havia uma série de indústrias sem proteção de direitos de autor , pensei : `` '' qual será a lógica subjacente ? ''
# `` when i found out that there are a whole bunch of industries that did n't have copyright protection , i thought , `` '' what exactly is the underlying logic ? ''
#
# a segunda ronda de votos também não apurou um vencedor claro .
# now the second round of voting did not bring forth a clear winner either .
#
# a cirurgia foi um sucesso .
# the surgery was successful .
#
# em vez disso , virámo-nos para uma nova geração de sensores de vídeo inicialmente criados para uso em óculos de visão noturna
# so instead , we turned to a new generation of video sensors , originally created for use in night vision goggles .
#
# olá , o meu nome é marcin sou agricultor , tecnólogo .
# hi , my name is marcin — farmer , technologist .
#
# talvez seja altura de arranjar uma caixa de ferramentas que não conte somente o que é fácil de contar , o que é tangível na vida , mas que conte realmente o que é mais precioso , as coisas que são intangíveis .
# maybe it 's time we get a toolbox that does n't just count what 's easily counted , the tangible in life , but actually counts what we most value , the things that are intangible .
#
# e , além disso , prevê-se que , para o final do século , quase todas as línguas que agora existem — existem cerca de 6000 — deixarão de ser faladas .
# and in addition to that , it 's been predicted that at the end of the century almost all of the languages that exist now — there are about 6,000 — will no longer be spoken .
#
# eu era amada .
# i was loved .
#
# o cérebro está a decidir qual é a textura associada à recompensa .
# and the brain is deciding what is the texture associated with the reward .
#
# eu acredito mesmo que não se pode pedir a um pequeno agricultor que trabalhe a terra , e se curve 150 000 vezes , para fazer crescer um hectare de arroz , só para plantar uma colheita e limpar as ervas .
# i feel so strongly that you can not ask a small farmer to work the land and bend over to grow a hectare of rice , 150,000 times , just to plant a crop and weed it .

# %%
# Only work with smaller data set as number of nodes in final layer of 
# SimpleRNN with attention is equal to vocab size (number of unique words) in 
# training set. Using the full dataset of 51785 examples will generate a 
# vocab size of 17000+ words, where we have insufficient RAM. The original
# nn architecture was only meant to train small datasets.

def create_dataset(training_data):
    the_data = []
    for pt_examples, en_examples in training_data.batch(1).take(1500):
        curr_example = []
        for en in en_examples.numpy():
            contents_en = '<start> ' + en.decode('utf-8') + ' <end>'
            curr_example.append(contents_en)
        for pt in pt_examples.numpy():
            contents_pt = '<start> ' + pt.decode('utf-8') + ' <end>'
            curr_example.append(contents_pt)
        the_data.append(curr_example)
    return zip(*the_data)

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %%
def load_dataset(data):
  # creating cleaned input, output pairs
  targ_lang, inp_lang = create_dataset(data)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %%
input_tensor_train, target_tensor_train, inp_lang, targ_lang = load_dataset(train_examples)

# %%
max_length_targ, max_length_inp = target_tensor_train.shape[1], input_tensor_train.shape[1]

# %%
input_tensor_val, target_tensor_val, _, _ = load_dataset(val_examples)

# %%
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 1500 1500 1193 1193

# %%
def convert(lang, tensor):
  for t in tensor:
    if t != 0:
      print(f'{t} ----> {lang.index_word[t]}')

# %%
print("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print()
print("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 2 ----> <start>
# 8 ----> e
# 41 ----> quando
# 1833 ----> melhoramos
# 5 ----> a
# 759 ----> procura
# 1 ----> ,
# 1834 ----> tiramos
# 5 ----> a
# 351 ----> única
# 1835 ----> vantagem
# 22 ----> da
# 760 ----> impressão
# 1 ----> ,
# 7 ----> que
# 10 ----> é
# 5 ----> a
# 1836 ----> serendipidade
# 4 ----> .
# 3 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 6 ----> and
# 48 ----> when
# 16 ----> you
# 739 ----> improve
# 1678 ----> searchability
# 4 ----> ,
# 16 ----> you
# 90 ----> actually
# 131 ----> take
# 308 ----> away
# 5 ----> the
# 40 ----> one
# 1679 ----> advantage
# 8 ----> of
# 1680 ----> print
# 4 ----> ,
# 107 ----> which
# 14 ----> is
# 1681 ----> serendipity
# 3 ----> .
# 2 ----> <end>

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 16
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 512
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1
#vocab_inp_size = 8500
#vocab_tar_size = 8000

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
vocab_inp_size
# Out:
# 5290

# %%
vocab_tar_size
# Out:
# 4385

# %%
dataset
# Out:
# <BatchDataset shapes: ((16, 119), (16, 144)), types: (tf.int32, tf.int32)>

# %%
len(input_tensor_train)
# Out:
# 1500

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([16, 119]), TensorShape([16, 144]))

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.rnn = tf.keras.layers.SimpleRNN(self.enc_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.rnn(x, initial_state=hidden)
    return output, state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_output, sample_hidden = encoder(example_input_batch, sample_hidden)
print('Encoder output shape: (batch size, sequence length, units)', sample_output.shape)
print('Encoder Hidden state shape: (batch size, units)', sample_hidden.shape)
# Out:
# Encoder output shape: (batch size, sequence length, units) (16, 119, 1024)
# Encoder Hidden state shape: (batch size, units) (16, 1024)

# %%
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):
    # query hidden state shape == (batch_size, hidden size)
    # query_with_time_axis shape == (batch_size, 1, hidden size)
    # values shape == (batch_size, max_len, hidden size)
    # we are doing this to broadcast addition along the time axis to calculate the score
    query_with_time_axis = tf.expand_dims(query, 1)

    # score shape == (batch_size, max_length, 1)
    # we get 1 at the last axis because we are applying score to self.V
    # the shape of the tensor before applying self.V is (batch_size, max_length, units)
    score = self.V(tf.nn.tanh(
        self.W1(query_with_time_axis) + self.W2(values)))

    # attention_weights shape == (batch_size, max_length, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
attention_layer = BahdanauAttention(10)
attention_result, attention_weights = attention_layer(sample_hidden, sample_output)

print("Attention result shape: (batch size, units)", attention_result.shape)
print("Attention weights shape: (batch_size, sequence_length, 1)", attention_weights.shape)
# Out:
# Attention result shape: (batch size, units) (16, 1024)
# Attention weights shape: (batch_size, sequence_length, 1) (16, 119, 1)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.rnn = tf.keras.layers.SimpleRNN(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

    # used for attention
    self.attention = BahdanauAttention(self.dec_units)

  def call(self, x, hidden, enc_output):
    # enc_output shape == (batch_size, max_length, hidden_size)
    context_vector, attention_weights = self.attention(hidden, enc_output)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the SimpleRNN
    output, state = self.rnn(x)

    # output shape == (batch_size * 1, hidden_size)
    output = tf.reshape(output, (-1, output.shape[2]))

    # output shape == (batch_size, vocab)
    x = self.fc(output)

    return x, state, attention_weights

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

sample_decoder_output, _, _ = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden, sample_output)

print('Decoder output shape: (batch_size, vocab size)', sample_decoder_output.shape)
# Out:
# Decoder output shape: (batch_size, vocab size) (16, 4385)

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True,
                                                            reduction='none')


def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %%
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
DICT_WEIGHTS = {}

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_output, enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
EPOCHS = 100

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print(f'Epoch {epoch+1} Batch {batch} Loss {batch_loss.numpy():.4f}')
  # saving (checkpoint) the model every 2 epochs
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix=checkpoint_prefix)
  
  DICT_WEIGHTS[epoch] = decoder.fc.get_weights()

  print(f'Epoch {epoch+1} Loss {total_loss/steps_per_epoch:.4f}')
  print(f'Time taken for 1 epoch {time.time()-start:.2f} sec\n')
# Out:
# Epoch 1 Batch 0 Loss 0.9254
# Epoch 1 Loss 0.8429
# Time taken for 1 epoch 147.26 sec
#
# Epoch 2 Batch 0 Loss 0.7340
# Epoch 2 Loss 0.7784
# Time taken for 1 epoch 36.53 sec
#
# Epoch 3 Batch 0 Loss 1.0413
# Epoch 3 Loss 0.7252
# Time taken for 1 epoch 36.01 sec
#
# Epoch 4 Batch 0 Loss 0.6657
# Epoch 4 Loss 0.6511
# Time taken for 1 epoch 36.49 sec
#
# Epoch 5 Batch 0 Loss 0.5478
# Epoch 5 Loss 0.6064
# Time taken for 1 epoch 36.51 sec
#
# Epoch 6 Batch 0 Loss 0.4549
# Epoch 6 Loss 0.5684
# Time taken for 1 epoch 37.31 sec
#
# Epoch 7 Batch 0 Loss 0.6130
# Epoch 7 Loss 0.5287
# Time taken for 1 epoch 36.73 sec
#
# Epoch 8 Batch 0 Loss 0.4275
# Epoch 8 Loss 0.4917
# Time taken for 1 epoch 36.83 sec
#
# Epoch 9 Batch 0 Loss 0.4082
# Epoch 9 Loss 0.4539
# Time taken for 1 epoch 36.37 sec
#
# Epoch 10 Batch 0 Loss 0.4482
# Epoch 10 Loss 0.4239
# Time taken for 1 epoch 36.61 sec
#
# Epoch 11 Batch 0 Loss 0.4428
# Epoch 11 Loss 0.3854
# Time taken for 1 epoch 36.18 sec
#
# Epoch 12 Batch 0 Loss 0.3777
# Epoch 12 Loss 0.3470
# Time taken for 1 epoch 36.35 sec
#
# Epoch 13 Batch 0 Loss 0.4231
# Epoch 13 Loss 0.3239
# Time taken for 1 epoch 36.19 sec
#
# Epoch 14 Batch 0 Loss 0.2545
# Epoch 14 Loss 0.3013
# Time taken for 1 epoch 36.58 sec
#
# Epoch 15 Batch 0 Loss 0.2030
# Epoch 15 Loss 0.2827
# Time taken for 1 epoch 36.13 sec
#
# Epoch 16 Batch 0 Loss 0.1889
# Epoch 16 Loss 0.2752
# Time taken for 1 epoch 36.35 sec
#
# Epoch 17 Batch 0 Loss 0.2076
# Epoch 17 Loss 0.2673
# Time taken for 1 epoch 35.90 sec
#
# Epoch 18 Batch 0 Loss 0.2881
# Epoch 18 Loss 0.3244
# Time taken for 1 epoch 36.23 sec
#
# Epoch 19 Batch 0 Loss 0.2932
# Epoch 19 Loss 0.2881
# Time taken for 1 epoch 36.04 sec
#
# Epoch 20 Batch 0 Loss 0.2705
# Epoch 20 Loss 0.2721
# Time taken for 1 epoch 36.68 sec
#
# Epoch 21 Batch 0 Loss 0.3465
# Epoch 21 Loss 0.2598
# Time taken for 1 epoch 36.52 sec
#
# Epoch 22 Batch 0 Loss 0.1503
# Epoch 22 Loss 0.2280
# Time taken for 1 epoch 36.79 sec
#
# Epoch 23 Batch 0 Loss 0.1134
# Epoch 23 Loss 0.2032
# Time taken for 1 epoch 36.52 sec
#
# Epoch 24 Batch 0 Loss 0.2289
# Epoch 24 Loss 0.1966
# Time taken for 1 epoch 36.79 sec
#
# Epoch 25 Batch 0 Loss 0.1668
# Epoch 25 Loss 0.8343
# Time taken for 1 epoch 36.50 sec
#
# Epoch 26 Batch 0 Loss 0.7300
# Epoch 26 Loss 0.6857
# Time taken for 1 epoch 36.54 sec
#
# Epoch 27 Batch 0 Loss 0.6392
# Epoch 27 Loss 0.6052
# Time taken for 1 epoch 36.02 sec
#
# Epoch 28 Batch 0 Loss 0.4278
# Epoch 28 Loss 0.5659
# Time taken for 1 epoch 36.32 sec
#
# Epoch 29 Batch 0 Loss 0.5676
# Epoch 29 Loss 0.5391
# Time taken for 1 epoch 36.21 sec
#
# Epoch 30 Batch 0 Loss 0.4231
# Epoch 30 Loss 0.5184
# Time taken for 1 epoch 36.65 sec
#
# Epoch 31 Batch 0 Loss 0.4758
# Epoch 31 Loss 0.5045
# Time taken for 1 epoch 36.28 sec
#
# Epoch 32 Batch 0 Loss 0.4452
# Epoch 32 Loss 0.4906
# Time taken for 1 epoch 36.54 sec
#
# Epoch 33 Batch 0 Loss 0.4209
# Epoch 33 Loss 0.4841
# Time taken for 1 epoch 36.22 sec
#
# Epoch 34 Batch 0 Loss 0.5554
# Epoch 34 Loss 0.4717
# Time taken for 1 epoch 36.68 sec
#
# Epoch 35 Batch 0 Loss 0.3996
# Epoch 35 Loss 0.4622
# Time taken for 1 epoch 36.38 sec
#
# Epoch 36 Batch 0 Loss 0.4593
# Epoch 36 Loss 0.4587
# Time taken for 1 epoch 36.33 sec
#
# Epoch 37 Batch 0 Loss 0.3711
# Epoch 37 Loss 0.4513
# Time taken for 1 epoch 36.16 sec
#
# Epoch 38 Batch 0 Loss 0.4176
# Epoch 38 Loss 0.4440
# Time taken for 1 epoch 36.53 sec
#
# Epoch 39 Batch 0 Loss 0.4977
# Epoch 39 Loss 0.4386
# Time taken for 1 epoch 36.31 sec
#
# Epoch 40 Batch 0 Loss 0.3935
# Epoch 40 Loss 0.4342
# Time taken for 1 epoch 37.69 sec
#
# Epoch 41 Batch 0 Loss 0.4477
# Epoch 41 Loss 0.4243
# Time taken for 1 epoch 36.16 sec
#
# Epoch 42 Batch 0 Loss 0.4076
# Epoch 42 Loss 0.4152
# Time taken for 1 epoch 36.86 sec
#
# Epoch 43 Batch 0 Loss 0.3539
# Epoch 43 Loss 0.4062
# Time taken for 1 epoch 36.06 sec
#
# Epoch 44 Batch 0 Loss 0.3338
# Epoch 44 Loss 0.4012
# Time taken for 1 epoch 36.29 sec
#
# Epoch 45 Batch 0 Loss 0.2892
# Epoch 45 Loss 0.3920
# Time taken for 1 epoch 36.17 sec
#
# Epoch 46 Batch 0 Loss 0.3197
# Epoch 46 Loss 0.3816
# Time taken for 1 epoch 36.39 sec
#
# Epoch 47 Batch 0 Loss 0.3992
# Epoch 47 Loss 0.3758
# Time taken for 1 epoch 36.61 sec
#
# Epoch 48 Batch 0 Loss 0.3134
# Epoch 48 Loss 0.3666
# Time taken for 1 epoch 36.49 sec
#
# Epoch 49 Batch 0 Loss 0.3702
# Epoch 49 Loss 0.3584
# Time taken for 1 epoch 36.41 sec
#
# Epoch 50 Batch 0 Loss 0.4673
# Epoch 50 Loss 0.3459
# Time taken for 1 epoch 36.85 sec
#
# Epoch 51 Batch 0 Loss 0.2718
# Epoch 51 Loss 0.3373
# Time taken for 1 epoch 35.91 sec
#
# Epoch 52 Batch 0 Loss 0.4017
# Epoch 52 Loss 0.3272
# Time taken for 1 epoch 36.25 sec
#
# Epoch 53 Batch 0 Loss 0.2903
# Epoch 53 Loss 0.3207
# Time taken for 1 epoch 35.69 sec
#
# Epoch 54 Batch 0 Loss 0.3188
# Epoch 54 Loss 0.3111
# Time taken for 1 epoch 35.84 sec
#
# Epoch 55 Batch 0 Loss 0.2554
# Epoch 55 Loss 0.3023
# Time taken for 1 epoch 35.66 sec
#
# Epoch 56 Batch 0 Loss 0.3289
# Epoch 56 Loss 0.2944
# Time taken for 1 epoch 36.26 sec
#
# Epoch 57 Batch 0 Loss 0.3194
# Epoch 57 Loss 0.2849
# Time taken for 1 epoch 35.71 sec
#
# Epoch 58 Batch 0 Loss 0.2163
# Epoch 58 Loss 0.2761
# Time taken for 1 epoch 36.52 sec
#
# Epoch 59 Batch 0 Loss 0.2067
# Epoch 59 Loss 0.2683
# Time taken for 1 epoch 36.02 sec
#
# Epoch 60 Batch 0 Loss 0.1756
# Epoch 60 Loss 0.2623
# Time taken for 1 epoch 36.16 sec
#
# Epoch 61 Batch 0 Loss 0.1911
# Epoch 61 Loss 0.2595
# Time taken for 1 epoch 35.89 sec
#
# Epoch 62 Batch 0 Loss 0.2582
# Epoch 62 Loss 0.2507
# Time taken for 1 epoch 36.36 sec
#
# Epoch 63 Batch 0 Loss 0.2125
# Epoch 63 Loss 0.2432
# Time taken for 1 epoch 36.02 sec
#
# Epoch 64 Batch 0 Loss 0.2781
# Epoch 64 Loss 0.2385
# Time taken for 1 epoch 36.31 sec
#
# Epoch 65 Batch 0 Loss 0.2865
# Epoch 65 Loss 0.2319
# Time taken for 1 epoch 35.92 sec
#
# Epoch 66 Batch 0 Loss 0.2030
# Epoch 66 Loss 0.2253
# Time taken for 1 epoch 36.07 sec
#
# Epoch 67 Batch 0 Loss 0.1651
# Epoch 67 Loss 0.2196
# Time taken for 1 epoch 35.67 sec
#
# Epoch 68 Batch 0 Loss 0.1966
# Epoch 68 Loss 0.2117
# Time taken for 1 epoch 36.33 sec
#
# Epoch 69 Batch 0 Loss 0.1908
# Epoch 69 Loss 0.2076
# Time taken for 1 epoch 36.30 sec
#
# Epoch 70 Batch 0 Loss 0.2081
# Epoch 70 Loss 0.2068
# Time taken for 1 epoch 36.60 sec
#
# Epoch 71 Batch 0 Loss 0.2318
# Epoch 71 Loss 0.1998
# Time taken for 1 epoch 35.95 sec
#
# Epoch 72 Batch 0 Loss 0.1528
# Epoch 72 Loss 0.1945
# Time taken for 1 epoch 36.15 sec
#
# Epoch 73 Batch 0 Loss 0.2012
# Epoch 73 Loss 0.1904
# Time taken for 1 epoch 35.86 sec
#
# Epoch 74 Batch 0 Loss 0.1705
# Epoch 74 Loss 0.1843
# Time taken for 1 epoch 36.37 sec
#
# Epoch 75 Batch 0 Loss 0.2564
# Epoch 75 Loss 0.1815
# Time taken for 1 epoch 35.94 sec
#
# Epoch 76 Batch 0 Loss 0.1497
# Epoch 76 Loss 0.1770
# Time taken for 1 epoch 36.34 sec
#
# Epoch 77 Batch 0 Loss 0.1481
# Epoch 77 Loss 0.1770
# Time taken for 1 epoch 35.68 sec
#
# Epoch 78 Batch 0 Loss 0.1673
# Epoch 78 Loss 0.1720
# Time taken for 1 epoch 35.81 sec
#
# Epoch 79 Batch 0 Loss 0.1512
# Epoch 79 Loss 0.1674
# Time taken for 1 epoch 35.68 sec
#
# Epoch 80 Batch 0 Loss 0.1385
# Epoch 80 Loss 0.1609
# Time taken for 1 epoch 36.00 sec
#
# Epoch 81 Batch 0 Loss 0.1380
# Epoch 81 Loss 0.1581
# Time taken for 1 epoch 35.76 sec
#
# Epoch 82 Batch 0 Loss 0.1281
# Epoch 82 Loss 0.1514
# Time taken for 1 epoch 36.26 sec
#
# Epoch 83 Batch 0 Loss 0.1291
# Epoch 83 Loss 0.1497
# Time taken for 1 epoch 36.31 sec
#
# Epoch 84 Batch 0 Loss 0.1226
# Epoch 84 Loss 0.1458
# Time taken for 1 epoch 35.84 sec
#
# Epoch 85 Batch 0 Loss 0.1398
# Epoch 85 Loss 0.1425
# Time taken for 1 epoch 35.86 sec
#
# Epoch 86 Batch 0 Loss 0.1578
# Epoch 86 Loss 0.1426
# Time taken for 1 epoch 35.83 sec
#
# Epoch 87 Batch 0 Loss 0.1777
# Epoch 87 Loss 0.1385
# Time taken for 1 epoch 36.03 sec
#
# Epoch 88 Batch 0 Loss 0.1538
# Epoch 88 Loss 0.1445
# Time taken for 1 epoch 35.91 sec
#
# Epoch 89 Batch 0 Loss 0.1110
# Epoch 89 Loss 0.1367
# Time taken for 1 epoch 35.86 sec
#
# Epoch 90 Batch 0 Loss 0.0963
# Epoch 90 Loss 0.1312
# Time taken for 1 epoch 36.37 sec
#
# Epoch 91 Batch 0 Loss 0.0948
# Epoch 91 Loss 0.1286
# Time taken for 1 epoch 35.64 sec
#
# Epoch 92 Batch 0 Loss 0.0794
# Epoch 92 Loss 0.1263
# Time taken for 1 epoch 36.25 sec
#
# Epoch 93 Batch 0 Loss 0.0863
# Epoch 93 Loss 0.1227
# Time taken for 1 epoch 35.82 sec
#
# Epoch 94 Batch 0 Loss 0.1321
# Epoch 94 Loss 0.1169
# Time taken for 1 epoch 36.29 sec
#
# Epoch 95 Batch 0 Loss 0.0953
# Epoch 95 Loss 0.1159
# Time taken for 1 epoch 36.22 sec
#
# Epoch 96 Batch 0 Loss 0.0974
# Epoch 96 Loss 0.1148
# Time taken for 1 epoch 36.28 sec
#
# Epoch 97 Batch 0 Loss 0.1160
# Epoch 97 Loss 0.1183
# Time taken for 1 epoch 35.95 sec
#
# Epoch 98 Batch 0 Loss 0.1294
# Epoch 98 Loss 0.1149
# Time taken for 1 epoch 36.73 sec
#
# Epoch 99 Batch 0 Loss 0.1047
# Epoch 99 Loss 0.1093
# Time taken for 1 epoch 36.39 sec
#
# Epoch 100 Batch 0 Loss 0.1329
# Epoch 100 Loss 0.1086
# Time taken for 1 epoch 37.27 sec

# %%
DICT_WEIGHTS
# Out:
# {0: [array([[ 0.00594871, -0.04100084,  0.01540139, ...,  0.01026866,
#            0.01692024,  0.00473942],
#          [-0.06073233, -0.01007862,  0.00063406, ..., -0.04472669,
#           -0.02510406,  0.00542651],
#          [ 0.00747386, -0.02148957,  0.03446212, ...,  0.02423963,
#           -0.02894041, -0.03608339],
#          ...,
#          [-0.00698006, -0.0216593 ,  0.03743872, ...,  0.01404807,
#           -0.03787516, -0.06008399],
#          [-0.01430119,  0.0015238 ,  0.05294842, ..., -0.02681281,
#           -0.01180326,  0.00986064],
#          [-0.00035907, -0.02182003, -0.00640455, ..., -0.00555149,
#           -0.01639977,  0.00428274]], dtype=float32),
#   array([-0.02648735, -0.02659549,  0.01306769, ..., -0.01795044,
#          -0.0201058 , -0.02513897], dtype=float32)],
#  1: [array([[ 0.01095735, -0.03618924,  0.01626272, ...,  0.01186435,
#            0.01723504,  0.00674417],
#          [-0.06653862, -0.01713975, -0.00684611, ..., -0.04744849,
#           -0.02697391,  0.00102185],
#          [ 0.0061795 , -0.02208518,  0.03037591, ...,  0.01916606,
#           -0.02349827, -0.04142649],
#          ...,
#          [-0.00457856, -0.01774851,  0.03626908, ...,  0.00862348,
#           -0.02658174, -0.06223102],
#          [-0.0131558 ,  0.00435716,  0.05123686, ..., -0.03361304,
#           -0.00652274,  0.00891379],
#          [ 0.00596464, -0.01620251, -0.00194871, ..., -0.00774429,
#           -0.01880896,  0.00520027]], dtype=float32),
#   array([-0.03030986, -0.03111589,  0.00604178, ..., -0.02065689,
#          -0.02205954, -0.0296369 ], dtype=float32)],
#  2: [array([[ 0.00930914, -0.03811358,  0.01412222, ...,  0.01322441,
#            0.01552342,  0.00279933],
#          [-0.0697012 , -0.02098832, -0.0136971 , ..., -0.05076271,
#           -0.02571208,  0.0009777 ],
#          [ 0.00737186, -0.02037287,  0.02602476, ...,  0.01752395,
#           -0.02663692, -0.04389942],
#          ...,
#          [-0.00302925, -0.01534507,  0.03216908, ...,  0.00522112,
#           -0.0315728 , -0.06428995],
#          [-0.01188109,  0.00690689,  0.04451083, ..., -0.03469935,
#            0.00036441,  0.00799885],
#          [ 0.00518961, -0.01566898,  0.00143601, ..., -0.00452482,
#           -0.01777536,  0.00801841]], dtype=float32),
#   array([-0.03250243, -0.03371967, -0.00118301, ..., -0.02419552,
#          -0.0200435 , -0.02927304], dtype=float32)],
#  3: [array([[ 0.00578032, -0.04088001,  0.01162078, ...,  0.01456037,
#            0.01376089,  0.00058167],
#          [-0.07636401, -0.02676895, -0.01816496, ..., -0.05326696,
#           -0.02569384, -0.00092173],
#          [ 0.0081222 , -0.01951306,  0.02539106, ...,  0.01326638,
#           -0.03164118, -0.04589657],
#          ...,
#          [ 0.00138317, -0.01146546,  0.03046517, ...,  0.00291298,
#           -0.0363949 , -0.06259862],
#          [-0.01088695,  0.00900243,  0.04316522, ..., -0.03338288,
#            0.00798138,  0.00810586],
#          [ 0.00357996, -0.01780336,  0.00174256, ..., -0.00192505,
#           -0.01887056,  0.00626403]], dtype=float32),
#   array([-0.04029634, -0.0403793 , -0.00705843, ..., -0.02813356,
#          -0.02057609, -0.0345678 ], dtype=float32)],
#  4: [array([[ 0.00282693, -0.04353778,  0.01111605, ...,  0.01679231,
#            0.00959588,  0.00769203],
#          [-0.08089391, -0.03098181, -0.01993444, ..., -0.05287564,
#           -0.02184994,  0.00022185],
#          [ 0.00921755, -0.01846602,  0.02762485, ...,  0.01111891,
#           -0.04226319, -0.05292937],
#          ...,
#          [ 0.00456208, -0.00855709,  0.03187121, ...,  0.00124377,
#           -0.04668549, -0.06996063],
#          [-0.00960485,  0.01076492,  0.04195292, ..., -0.02900798,
#            0.0208432 ,  0.00595139],
#          [ 0.00341144, -0.01820428, -0.00023908, ..., -0.00337669,
#           -0.02476972,  0.00584079]], dtype=float32),
#   array([-0.04723414, -0.04665979, -0.00975422, ..., -0.03039591,
#          -0.01658245, -0.02922055], dtype=float32)],
#  5: [array([[ 0.00018498, -0.04571312,  0.00907958, ...,  0.02093602,
#            0.0031416 ,  0.00563542],
#          [-0.08415056, -0.03409196, -0.02132805, ..., -0.05382799,
#           -0.02404425, -0.00301432],
#          [ 0.00947448, -0.01834024,  0.0285076 , ...,  0.00639397,
#           -0.04565701, -0.05536908],
#          ...,
#          [ 0.00568666, -0.00776685,  0.03201068, ..., -0.00188217,
#           -0.04609942, -0.0690914 ],
#          [-0.00889412,  0.0118272 ,  0.04238523, ..., -0.02695004,
#            0.02156832,  0.00466562],
#          [ 0.00360466, -0.01818547, -0.00226429, ..., -0.0071673 ,
#           -0.02645772,  0.00447459]], dtype=float32),
#   array([-0.05285176, -0.05174852, -0.01191309, ..., -0.03031859,
#          -0.02239089, -0.03295594], dtype=float32)],
#  6: [array([[-0.0015473 , -0.04712828,  0.00701264, ...,  0.02396896,
#           -0.00299836,  0.00353825],
#          [-0.08572359, -0.03554339, -0.02210859, ..., -0.0524926 ,
#           -0.02256313, -0.00221111],
#          [ 0.00941656, -0.01844892,  0.02881461, ...,  0.00260599,
#           -0.05037474, -0.0585203 ],
#          ...,
#          [ 0.00618903, -0.00745475,  0.03150205, ..., -0.00403419,
#           -0.04770906, -0.06881187],
#          [-0.00804349,  0.01287706,  0.04269492, ..., -0.02163064,
#            0.02408388,  0.00570454],
#          [ 0.00322295, -0.01861011, -0.00394511, ..., -0.00888156,
#           -0.03079657,  0.00185938]], dtype=float32),
#   array([-0.05746455, -0.0558847 , -0.01399018, ..., -0.03173815,
#          -0.02424362, -0.03440562], dtype=float32)],
#  7: [array([[-0.00291302, -0.04836719,  0.00723444, ...,  0.02264159,
#           -0.00948709, -0.00434799],
#          [-0.08688055, -0.03664422, -0.02170985, ..., -0.05002017,
#           -0.02043696, -0.0038231 ],
#          [ 0.00943432, -0.01839523,  0.03001495, ...,  0.00132723,
#           -0.0529835 , -0.06322496],
#          ...,
#          [ 0.00636576, -0.00742308,  0.03352474, ..., -0.00354581,
#           -0.05000033, -0.07093149],
#          [-0.00740384,  0.01364997,  0.04186423, ..., -0.02154248,
#            0.02675217,  0.00055188],
#          [ 0.0028686 , -0.01897852, -0.00377669, ..., -0.01547157,
#           -0.03362006, -0.00147002]], dtype=float32),
#   array([-0.06078845, -0.05893622, -0.01291693, ..., -0.03563954,
#          -0.02599268, -0.03291561], dtype=float32)],
#  8: [array([[-3.4659433e-03, -4.8862990e-02,  9.2601152e-03, ...,
#            1.9358316e-02, -8.3650881e-03, -1.3837167e-02],
#          [-8.7677211e-02, -3.7353888e-02, -2.2010215e-02, ...,
#           -5.1310007e-02, -2.7705206e-02, -6.8091894e-03],
#          [ 9.5558614e-03, -1.8212056e-02,  3.0687319e-02, ...,
#            5.1205806e-03, -4.7774907e-02, -6.1635211e-02],
#          ...,
#          [ 6.3924738e-03, -7.4921469e-03,  3.3251140e-02, ...,
#           -2.2876528e-05, -4.3783613e-02, -6.8792351e-02],
#          [-6.9214376e-03,  1.4177538e-02,  4.0709313e-02, ...,
#           -1.5525172e-02,  2.0877652e-02,  2.4462636e-03],
#          [ 2.7453580e-03, -1.9164009e-02, -4.2760479e-03, ...,
#           -1.4529670e-02, -2.7962506e-02, -2.3382520e-03]], dtype=float32),
#   array([-0.06297672, -0.06091181, -0.01368608, ..., -0.04221996,
#          -0.03782345, -0.03797294], dtype=float32)],
#  9: [array([[-0.00375809, -0.04906225,  0.01137803, ...,  0.02317358,
#           -0.01672631, -0.01402366],
#          [-0.08812621, -0.03778718, -0.02097113, ..., -0.04674051,
#           -0.02284746, -0.00600643],
#          [ 0.009497  , -0.01820908,  0.03248854, ...,  0.0023569 ,
#           -0.05407224, -0.06561703],
#          ...,
#          [ 0.00644695, -0.00752316,  0.03481629, ..., -0.00292163,
#           -0.04917913, -0.07239582],
#          [-0.00659433,  0.01452269,  0.04109615, ..., -0.01010174,
#            0.02667044,  0.00238648],
#          [ 0.00263523, -0.01927512, -0.00571234, ..., -0.0132972 ,
#           -0.03861888, -0.01024307]], dtype=float32),
#   array([-0.06438869, -0.06224037, -0.01269584, ..., -0.04072924,
#          -0.03485245, -0.035468  ], dtype=float32)],
#  10: [array([[-0.00386037, -0.04912239,  0.01223026, ...,  0.02352507,
#           -0.01455918, -0.02330171],
#          [-0.088432  , -0.03805235, -0.01899389, ..., -0.04578007,
#           -0.02769721, -0.00642606],
#          [ 0.00942238, -0.01826263,  0.03518133, ..., -0.00111412,
#           -0.0507597 , -0.06127665],
#          ...,
#          [ 0.00640293, -0.00761344,  0.03693182, ..., -0.00541522,
#           -0.04818321, -0.06888434],
#          [-0.00631538,  0.01479412,  0.04178125, ..., -0.01173939,
#            0.02659074,  0.00188813],
#          [ 0.00252166, -0.01938032, -0.0072898 , ..., -0.010723  ,
#           -0.03932953, -0.01741234]], dtype=float32),
#   array([-0.06509392, -0.0628634 , -0.01099221, ..., -0.03984773,
#          -0.0409029 , -0.03794401], dtype=float32)],
#  11: [array([[-0.00389133, -0.04913593,  0.01107498, ...,  0.02038908,
#           -0.02315119, -0.03569355],
#          [-0.0885366 , -0.03814298, -0.01975638, ..., -0.04706086,
#           -0.02225584, -0.00298795],
#          [ 0.00935237, -0.01832029,  0.03471314, ...,  0.00045077,
#           -0.05280348, -0.06093383],
#          ...,
#          [ 0.00633675, -0.00771094,  0.03664542, ..., -0.00376523,
#           -0.05338687, -0.07432964],
#          [-0.00608855,  0.01501279,  0.0402656 , ..., -0.00835898,
#            0.03212516,  0.00260484],
#          [ 0.00243721, -0.01944825, -0.00661867, ..., -0.00674507,
#           -0.04766647, -0.02482368]], dtype=float32),
#   array([-0.06550391, -0.0632434 , -0.01140068, ..., -0.04308775,
#          -0.03664054, -0.03348196], dtype=float32)],
#  12: [array([[-0.00389703, -0.04913026,  0.00740042, ...,  0.02424663,
#           -0.02451018, -0.04486332],
#          [-0.08862648, -0.03822622, -0.01797576, ..., -0.04881527,
#           -0.02550277, -0.01007362],
#          [ 0.00932542, -0.01834385,  0.03642512, ..., -0.00527494,
#           -0.04910061, -0.0541856 ],
#          ...,
#          [ 0.00627112, -0.0077893 ,  0.03821831, ..., -0.00873798,
#           -0.05023865, -0.06786811],
#          [-0.00591256,  0.01518114,  0.04037771, ..., -0.01164807,
#            0.0297164 ,  0.0030552 ],
#          [ 0.00239395, -0.01948241, -0.00968859, ..., -0.00793553,
#           -0.04775776, -0.02299791]], dtype=float32),
#   array([-0.06577648, -0.06348831, -0.01000321, ..., -0.03806933,
#          -0.0405485 , -0.04032706], dtype=float32)],
#  13: [array([[-0.00390326, -0.04911681,  0.00974797, ...,  0.02323729,
#           -0.02515135, -0.04888725],
#          [-0.088691  , -0.03828629, -0.01843858, ..., -0.05188128,
#           -0.0261425 , -0.00815059],
#          [ 0.00931222, -0.01835893,  0.03720293, ..., -0.00412674,
#           -0.04868535, -0.05487653],
#          ...,
#          [ 0.00623338, -0.00784668,  0.03981406, ..., -0.00790302,
#           -0.04986653, -0.07003156],
#          [-0.00575233,  0.01533868,  0.03921643, ..., -0.01550335,
#            0.0296655 ,  0.00352639],
#          [ 0.00235813, -0.01950325, -0.00805823, ..., -0.0117052 ,
#           -0.04849853, -0.02623564]], dtype=float32),
#   array([-0.06599656, -0.06369326, -0.00858624, ..., -0.03933319,
#          -0.04145959, -0.03906354], dtype=float32)],
#  14: [array([[-0.00388644, -0.04909306,  0.00797329, ...,  0.02750588,
#           -0.02787971, -0.05009253],
#          [-0.08873077, -0.03831782, -0.01790215, ..., -0.05458069,
#           -0.02506302, -0.01042694],
#          [ 0.00930239, -0.0183706 ,  0.03814905, ..., -0.00839219,
#           -0.04803398, -0.05434329],
#          ...,
#          [ 0.00619419, -0.00789571,  0.03974207, ..., -0.01188969,
#           -0.05102816, -0.06925744],
#          [-0.0056172 ,  0.01546691,  0.03857277, ..., -0.01528477,
#            0.03108923,  0.00376017],
#          [ 0.00233403, -0.01951225, -0.00853595, ..., -0.01494874,
#           -0.05120866, -0.02592871]], dtype=float32),
#   array([-0.06616199, -0.06384756, -0.00867349, ..., -0.03534599,
#          -0.04083472, -0.04015193], dtype=float32)],
#  15: [array([[-0.00387507, -0.0490763 ,  0.01100823, ...,  0.02235185,
#           -0.03348292, -0.05726273],
#          [-0.08875388, -0.03833966, -0.01694279, ..., -0.05194746,
#           -0.02081881, -0.00490411],
#          [ 0.00928421, -0.01838779,  0.03824385, ..., -0.00557281,
#           -0.05342317, -0.05059726],
#          ...,
#          [ 0.00616218, -0.00793236,  0.04174943, ..., -0.0070462 ,
#           -0.05511185, -0.06717629],
#          [-0.00551686,  0.01556352,  0.03876217, ..., -0.01238035,
#            0.03569627,  0.00850378],
#          [ 0.00228626, -0.01954421, -0.00828299, ..., -0.01795021,
#           -0.05763568, -0.03254126]], dtype=float32),
#   array([-0.0662874 , -0.06396504, -0.00689005, ..., -0.03939322,
#          -0.03739701, -0.03681277], dtype=float32)],
#  16: [array([[-0.00387486, -0.04907024,  0.01071476, ...,  0.02217283,
#           -0.03461055, -0.04874557],
#          [-0.08876555, -0.03834971, -0.01771136, ..., -0.04981632,
#           -0.02866506, -0.01879787],
#          [ 0.00927568, -0.01839985,  0.03813862, ..., -0.00578765,
#           -0.04866937, -0.0503983 ],
#          ...,
#          [ 0.00614754, -0.00795359,  0.04174443, ..., -0.00899617,
#           -0.04792748, -0.0669169 ],
#          [-0.0054641 ,  0.01561834,  0.03618358, ..., -0.00945703,
#            0.03023089,  0.00448618],
#          [ 0.00226995, -0.01954868, -0.00855339, ..., -0.02135064,
#           -0.05403572, -0.0200819 ]], dtype=float32),
#   array([-0.06635232, -0.06403089, -0.00690077, ..., -0.03846716,
#          -0.04509314, -0.0470351 ], dtype=float32)],
#  17: [array([[-0.00397278, -0.04918168,  0.01307784, ...,  0.02001267,
#           -0.03673441, -0.04860525],
#          [-0.08881722, -0.03838646, -0.01509778, ..., -0.04952711,
#           -0.02709724, -0.01910555],
#          [ 0.00926751, -0.01839853,  0.03775983, ..., -0.00384225,
#           -0.04936353, -0.05171913],
#          ...,
#          [ 0.00615053, -0.00797509,  0.0425818 , ..., -0.01077931,
#           -0.04943189, -0.06946424],
#          [-0.00536096,  0.01572095,  0.03952325, ..., -0.0027685 ,
#            0.03186445, -0.00015975],
#          [ 0.00216399, -0.01963128, -0.00680311, ..., -0.01726155,
#           -0.05593618, -0.01951744]], dtype=float32),
#   array([-0.06651171, -0.06419346, -0.00598633, ..., -0.03885426,
#          -0.04404703, -0.04717071], dtype=float32)],
#  18: [array([[-0.00398099, -0.04918703,  0.01326854, ...,  0.01942101,
#           -0.04170873, -0.06985331],
#          [-0.08882679, -0.03839547, -0.0133204 , ..., -0.04713085,
#           -0.026208  ,  0.00164006],
#          [ 0.00926706, -0.01839999,  0.03878511, ..., -0.00140233,
#           -0.04968443, -0.06104416],
#          ...,
#          [ 0.00613717, -0.00798673,  0.0436677 , ..., -0.01058458,
#           -0.05354813, -0.07954764],
#          [-0.00530961,  0.0157692 ,  0.04096913, ..., -0.01623083,
#            0.03468286, -0.01449123],
#          [ 0.00214987, -0.01963945, -0.00876979, ..., -0.02391949,
#           -0.06072552, -0.03917515]], dtype=float32),
#   array([-0.06656501, -0.06424196, -0.00473731, ..., -0.03946297,
#          -0.04431678, -0.03223803], dtype=float32)],
#  19: [array([[-0.0039896 , -0.04919448,  0.01442845, ...,  0.02588551,
#           -0.04234014, -0.05531713],
#          [-0.08884533, -0.03841266, -0.01175767, ..., -0.03949775,
#           -0.02738115, -0.01425027],
#          [ 0.00925504, -0.01841444,  0.0419558 , ..., -0.00685472,
#           -0.04990723, -0.06086824],
#          ...,
#          [ 0.0061365 , -0.00798976,  0.04636705, ..., -0.01439589,
#           -0.05322558, -0.07902364],
#          [-0.00526311,  0.01581177,  0.0419172 , ..., -0.01663158,
#            0.03450469, -0.01690312],
#          [ 0.00213874, -0.01964715, -0.00735045, ..., -0.02115909,
#           -0.06175705, -0.02379363]], dtype=float32),
#   array([-0.06661191, -0.06428296, -0.00221874, ..., -0.03431604,
#          -0.04550607, -0.04485742], dtype=float32)],
#  20: [array([[-0.00399204, -0.04919513,  0.01584734, ...,  0.02539688,
#           -0.0419284 , -0.06502092],
#          [-0.0888471 , -0.03841386, -0.01119762, ..., -0.03765849,
#           -0.02921204, -0.00929954],
#          [ 0.00925379, -0.01841735,  0.04411932, ..., -0.00438042,
#           -0.05009108, -0.06690332],
#          ...,
#          [ 0.00613051, -0.00799734,  0.04774402, ..., -0.01352056,
#           -0.05236951, -0.08817638],
#          [-0.00523136,  0.01583918,  0.04157456, ..., -0.01609727,
#            0.03346197, -0.01319453],
#          [ 0.00213108, -0.01965088, -0.0112023 , ..., -0.02648352,
#           -0.06048522, -0.0334377 ]], dtype=float32),
#   array([-0.06664638, -0.06431185, -0.00046077, ..., -0.03491609,
#          -0.0472261 , -0.03731128], dtype=float32)],
#  21: [array([[-0.00399434, -0.04919629,  0.01421852, ...,  0.02130881,
#           -0.04293035, -0.05891502],
#          [-0.08884781, -0.03841419, -0.01303521, ..., -0.04006659,
#           -0.02923926, -0.01876406],
#          [ 0.00924821, -0.0184228 ,  0.04246389, ..., -0.000665  ,
#           -0.05114403, -0.06312437],
#          ...,
#          [ 0.00612327, -0.00800464,  0.04652566, ..., -0.01068368,
#           -0.05268844, -0.08683929],
#          [-0.00521021,  0.01585829,  0.04049528, ..., -0.0137411 ,
#            0.03406709, -0.00045501],
#          [ 0.00211831, -0.01965949, -0.01179018, ..., -0.02733124,
#           -0.06123029, -0.02609731]], dtype=float32),
#   array([-0.06667028, -0.06433323, -0.00169313, ..., -0.03882606,
#          -0.04735785, -0.04378849], dtype=float32)],
#  22: [array([[-0.0039934 , -0.04919421,  0.01048407, ...,  0.0261092 ,
#           -0.04289371, -0.0691928 ],
#          [-0.08884849, -0.03841441, -0.01292501, ..., -0.03427468,
#           -0.02970721, -0.01084446],
#          [ 0.00923979, -0.01843132,  0.04307269, ..., -0.00495898,
#           -0.05142489, -0.06825397],
#          ...,
#          [ 0.00611567, -0.00801256,  0.04748937, ..., -0.01450322,
#           -0.05244416, -0.09075312],
#          [-0.00518981,  0.01587655,  0.0387493 , ..., -0.00923626,
#            0.03412707, -0.01038814],
#          [ 0.00211199, -0.01966325, -0.01231442, ..., -0.02896752,
#           -0.06145209, -0.03473363]], dtype=float32),
#   array([-0.06669237, -0.06435253, -0.00088291, ..., -0.03416085,
#          -0.04782655, -0.03600124], dtype=float32)],
#  23: [array([[-0.00399115, -0.04919052,  0.00595657, ...,  0.02000941,
#           -0.04249261, -0.06819408],
#          [-0.08884872, -0.0384146 , -0.01428844, ..., -0.03756434,
#           -0.03051027, -0.01357   ],
#          [ 0.00923464, -0.01843667,  0.0427347 , ..., -0.00065844,
#           -0.05117876, -0.06736083],
#          ...,
#          [ 0.00611041, -0.00801892,  0.04692082, ..., -0.00841627,
#           -0.0520323 , -0.09221595],
#          [-0.00517202,  0.01589239,  0.0369871 , ..., -0.01394054,
#            0.03377772, -0.01029308],
#          [ 0.00210393, -0.01966815, -0.01185769, ..., -0.02537227,
#           -0.06122202, -0.03244282]], dtype=float32),
#   array([-0.06671319, -0.06437117, -0.00134303, ..., -0.03948086,
#          -0.04858704, -0.03828149], dtype=float32)],
#  24: [array([[ 0.03875033, -0.00333654,  0.00942474, ...,  0.02139461,
#           -0.04017712, -0.06146942],
#          [-0.04662417,  0.00539366, -0.01083449, ..., -0.03548691,
#           -0.02313371, -0.00570149],
#          [ 0.05091793,  0.02288113,  0.03533825, ...,  0.00376463,
#           -0.04077066, -0.05601401],
#          ...,
#          [ 0.04155842,  0.02884373,  0.13638793, ..., -0.00623612,
#           -0.0525001 , -0.08299826],
#          [-0.03841591, -0.01700316,  0.05593287, ..., -0.01735569,
#            0.02984341, -0.02124556],
#          [-0.0383958 , -0.05993995,  0.01376746, ..., -0.04990805,
#           -0.09319636, -0.02790831]], dtype=float32),
#   array([-0.11139292, -0.11176626, -0.00181902, ..., -0.04260147,
#          -0.05605183, -0.04410464], dtype=float32)],
#  25: [array([[ 0.0387601 , -0.00332643,  0.01255798, ...,  0.02165662,
#           -0.03405248, -0.06216924],
#          [-0.04661412,  0.00540403, -0.00674684, ..., -0.0358237 ,
#           -0.01762046, -0.00673123],
#          [ 0.05092828,  0.02289174,  0.03834757, ...,  0.00414698,
#           -0.03468583, -0.05693152],
#          ...,
#          [ 0.04156775,  0.02885281,  0.13828294, ..., -0.01176244,
#           -0.05589976, -0.08777477],
#          [-0.0384247 , -0.01701165,  0.06329695, ..., -0.00152038,
#            0.0427952 , -0.0147363 ],
#          [-0.03840593, -0.05995035,  0.00848715, ..., -0.07677545,
#           -0.08841123, -0.02259785]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00472269, ..., -0.04279728,
#          -0.06136438, -0.04352367], dtype=float32)],
#  26: [array([[ 0.0387601 , -0.00332643,  0.01444548, ...,  0.02159813,
#           -0.03824355, -0.06261821],
#          [-0.04661412,  0.00540403, -0.00353805, ..., -0.03711523,
#           -0.02264929, -0.00828367],
#          [ 0.05092828,  0.02289174,  0.04016653, ...,  0.00412674,
#           -0.03885401, -0.05749639],
#          ...,
#          [ 0.04156775,  0.02885281,  0.13738222, ..., -0.01722421,
#           -0.06519811, -0.09599806],
#          [-0.0384247 , -0.01701165,  0.06597524, ...,  0.01082265,
#            0.05288277, -0.00349583],
#          [-0.03840593, -0.05995035,  0.00277171, ..., -0.06678632,
#           -0.0838633 , -0.00840775]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00648161, ..., -0.0427229 ,
#          -0.05764054, -0.04314355], dtype=float32)],
#  27: [array([[ 0.0387601 , -0.00332643,  0.0145605 , ...,  0.02390803,
#           -0.03855296, -0.06401692],
#          [-0.04661412,  0.00540403, -0.00274765, ..., -0.03476075,
#           -0.02225567, -0.01318511],
#          [ 0.05092828,  0.02289174,  0.04027773, ...,  0.00676951,
#           -0.039162  , -0.05914297],
#          ...,
#          [ 0.04156775,  0.02885281,  0.13789988, ..., -0.02074503,
#           -0.07062713, -0.10227856],
#          [-0.0384247 , -0.01701165,  0.06585541, ...,  0.00708764,
#            0.05776891, -0.00040259],
#          [-0.03840593, -0.05995035,  0.00643537, ..., -0.08694727,
#           -0.08639445,  0.00080991]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00658943, ..., -0.04476179,
#          -0.05736077, -0.04191511], dtype=float32)],
#  28: [array([[ 0.0387601 , -0.00332643,  0.01462625, ...,  0.02042956,
#           -0.03655535, -0.06260766],
#          [-0.04661412,  0.00540403, -0.00220499, ..., -0.03736168,
#           -0.01607843, -0.01512913],
#          [ 0.05092828,  0.02289174,  0.04034124, ...,  0.00289807,
#           -0.03717213, -0.05749675],
#          ...,
#          [ 0.04156775,  0.02885281,  0.1382576 , ..., -0.02665833,
#           -0.07484599, -0.10524622],
#          [-0.0384247 , -0.01701165,  0.06698846, ...,  0.0068783 ,
#            0.0618458 ,  0.00655472],
#          [-0.03840593, -0.05995035,  0.00569502, ..., -0.08492829,
#           -0.0966811 ,  0.00407927]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00665095, ..., -0.04162804,
#          -0.05919289, -0.04315962], dtype=float32)],
#  29: [array([[ 0.0387601 , -0.00332643,  0.01470834, ...,  0.02414587,
#           -0.03502508, -0.06173161],
#          [-0.04661412,  0.00540403, -0.00209195, ..., -0.0389172 ,
#           -0.00943771, -0.0205228 ],
#          [ 0.05092828,  0.02289174,  0.04042064, ...,  0.00699773,
#           -0.03564621, -0.05652165],
#          ...,
#          [ 0.04156775,  0.02885281,  0.13852084, ..., -0.02724806,
#           -0.07883559, -0.10726787],
#          [-0.0384247 , -0.01701165,  0.06865758, ...,  0.00966967,
#            0.06568182,  0.01510603],
#          [-0.03840593, -0.05995035,  0.00485208, ..., -0.08325476,
#           -0.10644802, -0.00913644]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00672798, ..., -0.0450005 ,
#          -0.06062711, -0.04395783], dtype=float32)],
#  30: [array([[ 0.0387601 , -0.00332643,  0.01547526, ...,  0.02351591,
#           -0.03722795, -0.06304125],
#          [-0.04661412,  0.00540403, -0.00224399, ..., -0.03795034,
#           -0.00839881, -0.02616543],
#          [ 0.05092828,  0.02289174,  0.04116598, ...,  0.00631201,
#           -0.03784336, -0.05796618],
#          ...,
#          [ 0.04156775,  0.02885281,  0.13799873, ..., -0.02897068,
#           -0.0821225 , -0.10809968],
#          [-0.0384247 , -0.01701165,  0.06996229, ...,  0.01930838,
#            0.06856517,  0.01589424],
#          [-0.03840593, -0.05995035, -0.00219839, ..., -0.06876107,
#           -0.11833899, -0.0218335 ]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00745397, ..., -0.04442255,
#          -0.05855182, -0.04275678], dtype=float32)],
#  31: [array([[ 0.0387601 , -0.00332643,  0.01552423, ...,  0.02424915,
#           -0.03686834, -0.06214422],
#          [-0.04661412,  0.00540403, -0.00225635, ..., -0.03555157,
#           -0.00581654, -0.02820477],
#          [ 0.05092828,  0.02289174,  0.04121418, ...,  0.00710074,
#           -0.03748458, -0.05698818],
#          ...,
#          [ 0.04156775,  0.02885281,  0.13852853, ..., -0.03051869,
#           -0.08534464, -0.10995267],
#          [-0.0384247 , -0.01701165,  0.07159644, ...,  0.01956733,
#            0.07192934,  0.02075117],
#          [-0.03840593, -0.05995035, -0.00031063, ..., -0.08316998,
#           -0.12477106, -0.02745467]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00750143, ..., -0.04510239,
#          -0.05889304, -0.04358683], dtype=float32)],
#  32: [array([[ 0.0387601 , -0.00332643,  0.01456558, ...,  0.02371785,
#           -0.03389354, -0.0633205 ],
#          [-0.04661412,  0.00540403, -0.00022445, ..., -0.02701889,
#           -0.00787557, -0.03344256],
#          [ 0.05092828,  0.02289174,  0.04027976, ...,  0.00653184,
#           -0.03451493, -0.05825209],
#          ...,
#          [ 0.04156775,  0.02885281,  0.13969722, ..., -0.03541761,
#           -0.08403428, -0.11309622],
#          [-0.0384247 , -0.01701165,  0.07692323, ...,  0.02305758,
#            0.07220057,  0.03260276],
#          [-0.03840593, -0.05995035, -0.00070406, ..., -0.09322736,
#           -0.13061975, -0.04547838]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00658896, ..., -0.04460781,
#          -0.06175008, -0.0424862 ], dtype=float32)],
#  33: [array([[ 0.0387601 , -0.00332643,  0.01543434, ...,  0.02371953,
#           -0.03675532, -0.06241808],
#          [-0.04661412,  0.00540403, -0.0015102 , ..., -0.02134741,
#           -0.00638646, -0.03645253],
#          [ 0.05092828,  0.02289174,  0.04112721, ...,  0.00653481,
#           -0.03737214, -0.05728682],
#          ...,
#          [ 0.04156775,  0.02885281,  0.13911188, ..., -0.03712931,
#           -0.08808567, -0.113203  ],
#          [-0.0384247 , -0.01701165,  0.07736308, ...,  0.03817223,
#            0.07608254,  0.03656517],
#          [-0.03840593, -0.05995035,  0.00482789, ..., -0.08903805,
#           -0.13882463, -0.05164719]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00741706, ..., -0.04460843,
#          -0.05899341, -0.04333383], dtype=float32)],
#  34: [array([[ 0.0387601 , -0.00332643,  0.01455299, ...,  0.02451875,
#           -0.03702661, -0.06356397],
#          [-0.04661412,  0.00540403, -0.00232198, ..., -0.02086882,
#           -0.00210495, -0.03912317],
#          [ 0.05092828,  0.02289174,  0.04026632, ...,  0.00738172,
#           -0.03764285, -0.05849693],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14016262, ..., -0.03646915,
#           -0.08922963, -0.11505399],
#          [-0.0384247 , -0.01701165,  0.08001731, ...,  0.03783471,
#            0.07730693,  0.03801339],
#          [-0.03840593, -0.05995035,  0.00709662, ..., -0.0891776 ,
#           -0.14242192, -0.05088604]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00657482, ..., -0.0453597 ,
#          -0.05873485, -0.04224605], dtype=float32)],
#  35: [array([[ 0.0387601 , -0.00332643,  0.01508582, ...,  0.02462419,
#           -0.03738161, -0.06319858],
#          [-0.04661412,  0.00540403, -0.00327059, ..., -0.01057843,
#           -0.00906986, -0.04122563],
#          [ 0.05092828,  0.02289174,  0.04078698, ...,  0.00748939,
#           -0.03799752, -0.05810592],
#          ...,
#          [ 0.04156775,  0.02885281,  0.13982251, ..., -0.03763327,
#           -0.09048392, -0.11510373],
#          [-0.0384247 , -0.01701165,  0.08058707, ...,  0.02945688,
#            0.07996772,  0.04566   ],
#          [-0.03840593, -0.05995035,  0.01196914, ..., -0.11293443,
#           -0.14280659, -0.03994961]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00708439, ..., -0.04546237,
#          -0.0583876 , -0.04258893], dtype=float32)],
#  36: [array([[ 0.0387601 , -0.00332643,  0.01557394, ...,  0.02374751,
#           -0.03618949, -0.06139528],
#          [-0.04661412,  0.00540403, -0.00541267, ..., -0.01372026,
#           -0.01216359, -0.04338991],
#          [ 0.05092828,  0.02289174,  0.04126471, ...,  0.00657083,
#           -0.03680671, -0.05622289],
#          ...,
#          [ 0.04156775,  0.02885281,  0.139377  , ..., -0.03915918,
#           -0.09015361, -0.11368012],
#          [-0.0384247 , -0.01701165,  0.08309309, ...,  0.0392151 ,
#            0.08046201,  0.04800434],
#          [-0.03840593, -0.05995035,  0.02189734, ..., -0.12650755,
#           -0.15130565, -0.06581843]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00755262, ..., -0.04462922,
#          -0.0595492 , -0.0443178 ], dtype=float32)],
#  37: [array([[ 0.0387601 , -0.00332643,  0.01566222, ...,  0.02344151,
#           -0.04118849, -0.06670175],
#          [-0.04661412,  0.00540403, -0.00522253, ..., -0.00355055,
#           -0.00462346, -0.04606376],
#          [ 0.05092828,  0.02289174,  0.04135211, ...,  0.00625195,
#           -0.04180089, -0.06173716],
#          ...,
#          [ 0.04156775,  0.02885281,  0.13932586, ..., -0.0414049 ,
#           -0.09522939, -0.11901338],
#          [-0.0384247 , -0.01701165,  0.08447058, ...,  0.03350738,
#            0.0856168 ,  0.05480434],
#          [-0.03840593, -0.05995035,  0.01972913, ..., -0.12170032,
#           -0.15686484, -0.06437102]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00763921, ..., -0.04433685,
#          -0.05466321, -0.03920797], dtype=float32)],
#  38: [array([[ 0.0387601 , -0.00332643,  0.01551268, ...,  0.02416496,
#           -0.03642837, -0.06060905],
#          [-0.04661412,  0.00540403, -0.00475872, ..., -0.0076992 ,
#           -0.0041275 , -0.04188734],
#          [ 0.05092828,  0.02289174,  0.04120569, ...,  0.00699958,
#           -0.03704511, -0.05543372],
#          ...,
#          [ 0.04156775,  0.02885281,  0.13946523, ..., -0.04129105,
#           -0.09310075, -0.11363813],
#          [-0.0384247 , -0.01701165,  0.084805  , ...,  0.03785016,
#            0.08370964,  0.05307484],
#          [-0.03840593, -0.05995035,  0.02353296, ..., -0.14142583,
#           -0.15667063, -0.08051037]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00749563, ..., -0.0450341 ,
#          -0.05932098, -0.04509875], dtype=float32)],
#  39: [array([[ 0.0387601 , -0.00332643,  0.01566793, ...,  0.02405132,
#           -0.03668183, -0.06328033],
#          [-0.04661412,  0.00540403, -0.0051711 , ..., -0.00752418,
#           -0.01304592, -0.04679678],
#          [ 0.05092828,  0.02289174,  0.04135829, ...,  0.00688087,
#           -0.03729834, -0.05818747],
#          ...,
#          [ 0.04156775,  0.02885281,  0.13960475, ..., -0.04131966,
#           -0.09446057, -0.11746093],
#          [-0.0384247 , -0.01701165,  0.09014837, ...,  0.03150959,
#            0.08520758,  0.0607236 ],
#          [-0.03840593, -0.05995035,  0.02252105, ..., -0.13130061,
#           -0.15851855, -0.08222484]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00764577, ..., -0.04492585,
#          -0.05907261, -0.04250739], dtype=float32)],
#  40: [array([[ 0.0387601 , -0.00332643,  0.01524599, ...,  0.02395275,
#           -0.04119254, -0.06656156],
#          [-0.04661412,  0.00540403, -0.00462577, ..., -0.00760249,
#           -0.00984538, -0.05178418],
#          [ 0.05092828,  0.02289174,  0.04094424, ...,  0.00677971,
#           -0.04180597, -0.06155675],
#          ...,
#          [ 0.04156775,  0.02885281,  0.1399256 , ..., -0.04200614,
#           -0.09941521, -0.12163672],
#          [-0.0384247 , -0.01701165,  0.09073614, ...,  0.03467711,
#            0.0903567 ,  0.06749595],
#          [-0.03840593, -0.05995035,  0.01796215, ..., -0.13462615,
#           -0.16690506, -0.09682502]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00723901, ..., -0.04483015,
#          -0.05463492, -0.03931235], dtype=float32)],
#  41: [array([[ 0.0387601 , -0.00332643,  0.01557379, ...,  0.02573687,
#           -0.03743398, -0.0632932 ],
#          [-0.04661412,  0.00540403, -0.00433551, ..., -0.01519466,
#           -0.01623624, -0.05130523],
#          [ 0.05092828,  0.02289174,  0.04126639, ...,  0.00860669,
#           -0.03805013, -0.05819424],
#          ...,
#          [ 0.04156775,  0.02885281,  0.13979203, ..., -0.04197878,
#           -0.09658942, -0.11943388],
#          [-0.0384247 , -0.01701165,  0.09256374, ...,  0.04086202,
#            0.08808092,  0.06853417],
#          [-0.03840593, -0.05995035,  0.01869249, ..., -0.12054908,
#           -0.16768713, -0.09887467]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00755593, ..., -0.04656648,
#          -0.05832928, -0.04248895], dtype=float32)],
#  42: [array([[ 0.0387601 , -0.00332643,  0.01500201, ...,  0.02490926,
#           -0.04177999, -0.06803376],
#          [-0.04661412,  0.00540403, -0.00545206, ..., -0.02382053,
#           -0.02574366, -0.05709628],
#          [ 0.05092828,  0.02289174,  0.04070388, ...,  0.0077582 ,
#           -0.04239379, -0.06303716],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14046109, ..., -0.0430973 ,
#           -0.10112719, -0.12462531],
#          [-0.0384247 , -0.01701165,  0.09490827, ...,  0.04731651,
#            0.0927991 ,  0.07478594],
#          [-0.03840593, -0.05995035,  0.02480299, ..., -0.12006145,
#           -0.17317182, -0.10635401]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.007002  , ..., -0.0457621 ,
#          -0.05403936, -0.03785032], dtype=float32)],
#  43: [array([[ 0.0387601 , -0.00332643,  0.0157889 , ...,  0.02510495,
#           -0.03662582, -0.06146982],
#          [-0.04661412,  0.00540403, -0.00602367, ..., -0.02511309,
#           -0.02191111, -0.05203343],
#          [ 0.05092828,  0.02289174,  0.04147828, ...,  0.00795711,
#           -0.03724245, -0.05633616],
#          ...,
#          [ 0.04156775,  0.02885281,  0.13984473, ..., -0.04387698,
#           -0.09754581, -0.11767847],
#          [-0.0384247 , -0.01701165,  0.09592163, ...,  0.04613383,
#            0.08963889,  0.07139982],
#          [-0.03840593, -0.05995035,  0.03082449, ..., -0.09274935,
#           -0.17777677, -0.11102554]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00776478, ..., -0.04595409,
#          -0.05912646, -0.04427768], dtype=float32)],
#  44: [array([[ 0.0387601 , -0.00332643,  0.01467151, ...,  0.02041281,
#           -0.03558641, -0.06213792],
#          [-0.04661412,  0.00540403, -0.00429534, ..., -0.01757077,
#           -0.0381871 , -0.05358927],
#          [ 0.05092828,  0.02289174,  0.04037833, ...,  0.00317874,
#           -0.03620348, -0.0570169 ],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14109203, ..., -0.04770337,
#           -0.09689774, -0.11879835],
#          [-0.0384247 , -0.01701165,  0.09733277, ...,  0.04814861,
#            0.0896519 ,  0.07389751],
#          [-0.03840593, -0.05995035,  0.02954776, ..., -0.09969995,
#           -0.1766327 , -0.11209729]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00668106, ..., -0.0413598 ,
#          -0.06015544, -0.04362212], dtype=float32)],
#  45: [array([[ 0.0387601 , -0.00332643,  0.01555114, ...,  0.02526358,
#           -0.0372687 , -0.06279238],
#          [-0.04661412,  0.00540403, -0.00405838, ..., -0.03250572,
#           -0.03555846, -0.05648842],
#          [ 0.05092828,  0.02289174,  0.04124488, ...,  0.00811564,
#           -0.03788508, -0.0576821 ],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14010206, ..., -0.04360075,
#           -0.09175961, -0.11089098],
#          [-0.0384247 , -0.01701165,  0.09832065, ...,  0.04900344,
#            0.09169169,  0.07608782],
#          [-0.03840593, -0.05995035,  0.03406724, ..., -0.08195028,
#           -0.18164706, -0.11071162]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00753541, ..., -0.04611267,
#          -0.05848985, -0.04297849], dtype=float32)],
#  46: [array([[ 0.0387601 , -0.00332643,  0.01579918, ...,  0.02711992,
#           -0.03708753, -0.06510101],
#          [-0.04661412,  0.00540403, -0.00315962, ..., -0.03032492,
#           -0.045024  , -0.05951807],
#          [ 0.05092828,  0.02289174,  0.04149029, ...,  0.00999978,
#           -0.03770389, -0.06002416],
#          ...,
#          [ 0.04156775,  0.02885281,  0.13989165, ..., -0.04184183,
#           -0.09177466, -0.11350536],
#          [-0.0384247 , -0.01701165,  0.09951328, ...,  0.04798181,
#            0.09200226,  0.08027755],
#          [-0.03840593, -0.05995035,  0.03100029, ..., -0.08210977,
#           -0.18341602, -0.12176483]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00777833, ..., -0.0479371 ,
#          -0.0586713 , -0.04070385], dtype=float32)],
#  47: [array([[ 0.0387601 , -0.00332643,  0.01520141, ...,  0.02552003,
#           -0.04158442, -0.06593251],
#          [-0.04661412,  0.00540403, -0.00181171, ..., -0.04597645,
#           -0.05844293, -0.06105082],
#          [ 0.05092828,  0.02289174,  0.04090073, ...,  0.00837712,
#           -0.04219943, -0.06085861],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14075741, ..., -0.04029241,
#           -0.09623532, -0.103541  ],
#          [-0.0384247 , -0.01701165,  0.10430478, ...,  0.05524541,
#            0.09710994,  0.08298817],
#          [-0.03840593, -0.05995035,  0.02795442, ..., -0.07463884,
#           -0.1887757 , -0.12404408]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00719646, ..., -0.04636343,
#          -0.0542067 , -0.03987567], dtype=float32)],
#  48: [array([[ 0.0387601 , -0.00332643,  0.01482664, ...,  0.02830589,
#           -0.03769384, -0.06164239],
#          [-0.04661412,  0.00540403,  0.00132577, ..., -0.059448  ,
#           -0.06456047, -0.05817706],
#          [ 0.05092828,  0.02289174,  0.04053062, ...,  0.01119743,
#           -0.03831005, -0.05651589],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14127675, ..., -0.03674764,
#           -0.0937808 , -0.09995907],
#          [-0.0384247 , -0.01701165,  0.10604607, ...,  0.05826656,
#            0.09456416,  0.08071884],
#          [-0.03840593, -0.05995035,  0.03507089, ..., -0.06088909,
#           -0.1866109 , -0.12051449]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00683071, ..., -0.04910948,
#          -0.05806809, -0.04411202], dtype=float32)],
#  49: [array([[ 0.0387601 , -0.00332643,  0.01441848, ...,  0.02640147,
#           -0.0371213 , -0.06105961],
#          [-0.04661412,  0.00540403,  0.0014854 , ..., -0.06817743,
#           -0.07542894, -0.05817699],
#          [ 0.05092828,  0.02289174,  0.04012731, ...,  0.00927138,
#           -0.03773763, -0.05592715],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14179234, ..., -0.03832374,
#           -0.09383021, -0.09901181],
#          [-0.0384247 , -0.01701165,  0.10259438, ...,  0.05903762,
#            0.09502712,  0.0816499 ],
#          [-0.03840593, -0.05995035,  0.03517633, ..., -0.04838791,
#           -0.18839692, -0.13240694]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00643197, ..., -0.04723012,
#          -0.05863701, -0.04468868], dtype=float32)],
#  50: [array([[ 0.0387601 , -0.00332643,  0.01517778, ...,  0.02458642,
#           -0.04249663, -0.06578009],
#          [-0.04661412,  0.00540403,  0.00113517, ..., -0.06620603,
#           -0.08099549, -0.06380214],
#          [ 0.05092828,  0.02289174,  0.04087783, ...,  0.00743819,
#           -0.04311164, -0.06069385],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14129789, ..., -0.04051332,
#           -0.0996774 , -0.10402457],
#          [-0.0384247 , -0.01701165,  0.10444579, ...,  0.06543913,
#            0.10065871,  0.08708002],
#          [-0.03840593, -0.05995035,  0.03629916, ..., -0.04009651,
#           -0.19483514, -0.14053722]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00717423, ..., -0.0454362 ,
#          -0.0532937 , -0.0400158 ], dtype=float32)],
#  51: [array([[ 0.0387601 , -0.00332643,  0.0151343 , ...,  0.03942119,
#           -0.0375796 , -0.06074664],
#          [-0.04661412,  0.00540403,  0.00330585, ..., -0.08866131,
#           -0.08097001, -0.06078219],
#          [ 0.05092828,  0.02289174,  0.04083521, ...,  0.02233526,
#           -0.03819584, -0.05561342],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14160748, ..., -0.0256328 ,
#           -0.09718686, -0.09922039],
#          [-0.0384247 , -0.01701165,  0.11118525, ...,  0.08642354,
#            0.09669843,  0.0830754 ],
#          [-0.03840593, -0.05995035,  0.03813567, ..., -0.01556774,
#           -0.19422644, -0.13866201]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00713241, ..., -0.06019663,
#          -0.05818184, -0.04500084], dtype=float32)],
#  52: [array([[ 0.0387601 , -0.00332643,  0.01532342, ...,  0.03249262,
#           -0.03751919, -0.05888269],
#          [-0.04661412,  0.00540403,  0.00366318, ..., -0.08810767,
#           -0.08347283, -0.06011654],
#          [ 0.05092828,  0.02289174,  0.04102293, ...,  0.01537109,
#           -0.03813548, -0.05373421],
#          ...,
#          [ 0.04156775,  0.02885281,  0.1414388 , ..., -0.03272272,
#           -0.09771806, -0.09736673],
#          [-0.0384247 , -0.01701165,  0.11720932, ...,  0.0980441 ,
#            0.09697141,  0.08318347],
#          [-0.03840593, -0.05995035,  0.04680003, ..., -0.00642643,
#           -0.19546303, -0.14332026]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00731876, ..., -0.05331019,
#          -0.05824194, -0.04684898], dtype=float32)],
#  53: [array([[ 0.0387601 , -0.00332643,  0.01393731, ...,  0.02517235,
#           -0.03918997, -0.06262038],
#          [-0.04661412,  0.00540403,  0.00321218, ..., -0.08173838,
#           -0.09009433, -0.06471739],
#          [ 0.05092828,  0.02289174,  0.03965025, ...,  0.00801515,
#           -0.03980589, -0.05749968],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14271934, ..., -0.04041737,
#           -0.09970399, -0.0939106 ],
#          [-0.0384247 , -0.01701165,  0.11395419, ...,  0.10496926,
#            0.09896511,  0.08780409],
#          [-0.03840593, -0.05995035,  0.04985074, ...,  0.00411161,
#           -0.19780236, -0.15034226]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00595879, ..., -0.04603216,
#          -0.05657954, -0.04314013], dtype=float32)],
#  54: [array([[ 0.0387601 , -0.00332643,  0.01454102, ...,  0.02650145,
#           -0.03834086, -0.05354718],
#          [-0.04661412,  0.00540403,  0.00601346, ..., -0.08262926,
#           -0.09189402, -0.05634302],
#          [ 0.05092828,  0.02289174,  0.04024873, ...,  0.00935071,
#           -0.03895694, -0.04836687],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14222178, ..., -0.03911591,
#           -0.09934074, -0.08220821],
#          [-0.0384247 , -0.01701165,  0.11535271, ...,  0.10395071,
#            0.0985281 ,  0.07912485],
#          [-0.03840593, -0.05995035,  0.04973609, ...,  0.00399528,
#           -0.19763571, -0.14263892]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.0065523 , ..., -0.04735363,
#          -0.05742439, -0.05215134], dtype=float32)],
#  55: [array([[ 0.0387601 , -0.00332643,  0.01407317, ...,  0.02531525,
#           -0.03861285, -0.06214102],
#          [-0.04661412,  0.00540403,  0.00845979, ..., -0.08218175,
#           -0.09420485, -0.06540702],
#          [ 0.05092828,  0.02289174,  0.03978486, ...,  0.00815892,
#           -0.03922889, -0.05701271],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14267297, ..., -0.04078991,
#           -0.10005544, -0.0884256 ],
#          [-0.0384247 , -0.01701165,  0.11701274, ...,  0.10838056,
#            0.09902673,  0.0883679 ],
#          [-0.03840593, -0.05995035,  0.0429761 , ...,  0.01324779,
#           -0.19833799, -0.15368104]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00609221, ..., -0.04617404,
#          -0.05715371, -0.04361163], dtype=float32)],
#  56: [array([[ 0.0387601 , -0.00332643,  0.01363415, ...,  0.02565701,
#           -0.0392596 , -0.06118496],
#          [-0.04661412,  0.00540403,  0.01130023, ..., -0.08355407,
#           -0.09901693, -0.0646673 ],
#          [ 0.05092828,  0.02289174,  0.03934915, ...,  0.0085022 ,
#           -0.03987548, -0.05605081],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14326604, ..., -0.04030034,
#           -0.10136218, -0.0906544 ],
#          [-0.0384247 , -0.01701165,  0.12187273, ...,  0.10992851,
#            0.09996597,  0.08780652],
#          [-0.03840593, -0.05995035,  0.03770925, ...,  0.01440139,
#           -0.19958088, -0.15801296]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00565966, ..., -0.04651403,
#          -0.05651003, -0.0445616 ], dtype=float32)],
#  57: [array([[ 0.0387601 , -0.00332643,  0.01541353, ...,  0.02638284,
#           -0.03782228, -0.06210051],
#          [-0.04661412,  0.00540403,  0.01077515, ..., -0.08547921,
#           -0.09900007, -0.06588615],
#          [ 0.05092828,  0.02289174,  0.04111532, ...,  0.00923133,
#           -0.03843847, -0.05697184],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14160155, ..., -0.0395533 ,
#           -0.10040956, -0.09398118],
#          [-0.0384247 , -0.01701165,  0.12558866, ...,  0.10973188,
#            0.09873413,  0.08910313],
#          [-0.03840593, -0.05995035,  0.04271522, ...,  0.01397311,
#           -0.19842859, -0.1601718 ]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00741324, ..., -0.04723598,
#          -0.05794037, -0.04365178], dtype=float32)],
#  58: [array([[ 0.0387601 , -0.00332643,  0.01456782, ...,  0.02243449,
#           -0.03699267, -0.06341448],
#          [-0.04661412,  0.00540403,  0.01717994, ..., -0.08913463,
#           -0.09862057, -0.06764489],
#          [ 0.05092828,  0.02289174,  0.04027596, ...,  0.00526554,
#           -0.03760896, -0.05829   ],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14239769, ..., -0.04380568,
#           -0.10029556, -0.10095212],
#          [-0.0384247 , -0.01701165,  0.12726036, ...,  0.11611125,
#            0.09825305,  0.09101786],
#          [-0.03840593, -0.05995035,  0.03387617, ...,  0.02140016,
#           -0.1982864 , -0.16265023]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00657993, ..., -0.0433083 ,
#          -0.05876777, -0.04234222], dtype=float32)],
#  59: [array([[ 0.0387601 , -0.00332643,  0.01451658, ...,  0.02550112,
#           -0.03921308, -0.06313435],
#          [-0.04661412,  0.00540403,  0.01702056, ..., -0.09177564,
#           -0.10205612, -0.06781059],
#          [ 0.05092828,  0.02289174,  0.04022524, ...,  0.00834601,
#           -0.03982903, -0.05800854],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14232248, ..., -0.04087411,
#           -0.10292772, -0.10017572],
#          [-0.0384247 , -0.01701165,  0.12951344, ...,  0.11176369,
#            0.10070757,  0.09127274],
#          [-0.03840593, -0.05995035,  0.04246705, ...,  0.02557815,
#           -0.20096724, -0.1640147 ]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00652969, ..., -0.04635853,
#          -0.05655567, -0.04262093], dtype=float32)],
#  60: [array([[ 0.0387601 , -0.00332643,  0.01393464, ...,  0.0442604 ,
#           -0.0380343 , -0.0632956 ],
#          [-0.04661412,  0.00540403,  0.02054738, ..., -0.07516257,
#           -0.10148223, -0.06862171],
#          [ 0.05092828,  0.02289174,  0.03964718, ...,  0.02715791,
#           -0.03865043, -0.05816751],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14320102, ..., -0.02231359,
#           -0.102931  , -0.09583218],
#          [-0.0384247 , -0.01701165,  0.12534627, ...,  0.08959811,
#            0.09986269,  0.09184589],
#          [-0.03840593, -0.05995035,  0.04160997, ...,  0.01187618,
#           -0.2004062 , -0.16519569]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00595533, ..., -0.06505504,
#          -0.05772981, -0.04245735], dtype=float32)],
#  61: [array([[ 0.0387601 , -0.00332643,  0.0137956 , ...,  0.03632537,
#           -0.03767164, -0.0573465 ],
#          [-0.04661412,  0.00540403,  0.02522549, ..., -0.0802825 ,
#           -0.10188781, -0.06259283],
#          [ 0.05092828,  0.02289174,  0.03950899, ...,  0.01920142,
#           -0.03828782, -0.05219564],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14353152, ..., -0.03008975,
#           -0.10298204, -0.08957481],
# ...
#           -0.11700303, -0.08287491],
#          [-0.0384247 , -0.01701165,  0.12627879, ...,  0.11291887,
#            0.10268619,  0.09085622],
#          [-0.03840593, -0.05995035,  0.06934597, ...,  0.03368208,
#           -0.2045041 , -0.18461116]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00423895, ..., -0.05406538,
#          -0.05903082, -0.04589765], dtype=float32)],
#  80: [array([[ 0.0387601 , -0.00332643,  0.01249713, ...,  0.02536336,
#           -0.0361978 , -0.05179444],
#          [-0.04661412,  0.00540403,  0.06879208, ..., -0.11801304,
#           -0.11598706, -0.05821136],
#          [ 0.05092828,  0.02289174,  0.03821529, ...,  0.00821661,
#           -0.03681419, -0.04663754],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14807053, ..., -0.04039709,
#           -0.11679902, -0.0718863 ],
#          [-0.0384247 , -0.01701165,  0.12438776, ...,  0.12141179,
#            0.10219534,  0.08273923],
#          [-0.03840593, -0.05995035,  0.07305684, ...,  0.04196782,
#           -0.20401894, -0.17626154]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00452879, ..., -0.04621096,
#          -0.05955895, -0.05392837], dtype=float32)],
#  81: [array([[ 0.0387601 , -0.00332643,  0.01139286, ...,  0.03926617,
#           -0.03601211, -0.06110468],
#          [-0.04661412,  0.00540403,  0.07312647, ..., -0.10348222,
#           -0.11591635, -0.0675994 ],
#          [ 0.05092828,  0.02289174,  0.03711272, ...,  0.02212434,
#           -0.03662853, -0.05595408],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14931996, ..., -0.02627185,
#           -0.11695217, -0.06746754],
#          [-0.0384247 , -0.01701165,  0.12730503, ...,  0.10675286,
#            0.10210298,  0.09222252],
#          [-0.03840593, -0.05995035,  0.06564903, ...,  0.02781604,
#           -0.20387255, -0.18616891]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00342788, ..., -0.06010785,
#          -0.05974408, -0.04462478], dtype=float32)],
#  82: [array([[ 0.0387601 , -0.00332643,  0.01214828, ...,  0.03193057,
#           -0.03638619, -0.04987682],
#          [-0.04661412,  0.00540403,  0.07417807, ..., -0.10592782,
#           -0.11656845, -0.05629762],
#          [ 0.05092828,  0.02289174,  0.03786703, ...,  0.01478629,
#           -0.03700256, -0.04471947],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14838696, ..., -0.03373319,
#           -0.1173853 , -0.07931346],
#          [-0.0384247 , -0.01701165,  0.12898985, ...,  0.11452477,
#            0.10255808,  0.08093851],
#          [-0.03840593, -0.05995035,  0.06748284, ...,  0.03540806,
#           -0.20431833, -0.17456585]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00418111, ..., -0.05277517,
#          -0.05937112, -0.05584547], dtype=float32)],
#  83: [array([[ 0.0387601 , -0.00332643,  0.01248338, ...,  0.02440018,
#           -0.03653638, -0.05914014],
#          [-0.04661412,  0.00540403,  0.07683684, ..., -0.10398587,
#           -0.11702479, -0.06561657],
#          [ 0.05092828,  0.02289174,  0.03820169, ...,  0.00725355,
#           -0.03715272, -0.05398775],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14839424, ..., -0.04136888,
#           -0.11788961, -0.09127632],
#          [-0.0384247 , -0.01701165,  0.1262849 , ...,  0.12253662,
#            0.10280027,  0.09027432],
#          [-0.03840593, -0.05995035,  0.07785884, ...,  0.04319655,
#           -0.2045199 , -0.18413647]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00451537, ..., -0.04524764,
#          -0.05922139, -0.0465874 ], dtype=float32)],
#  84: [array([[ 0.0387601 , -0.00332643,  0.0115172 , ...,  0.0399197 ,
#           -0.03638352, -0.0499308 ],
#          [-0.04661412,  0.00540403,  0.07811326, ..., -0.0843115 ,
#           -0.11700796, -0.05636001],
#          [ 0.05092828,  0.02289174,  0.03723668, ...,  0.02277653,
#           -0.0369999 , -0.04477406],
#          ...,
#          [ 0.04156775,  0.02885281,  0.1495839 , ..., -0.02569904,
#           -0.11801738, -0.08389919],
#          [-0.0384247 , -0.01701165,  0.13340144, ...,  0.10645937,
#            0.10268635,  0.08100627],
#          [-0.03840593, -0.05995035,  0.08574386, ...,  0.0282904 ,
#           -0.20440558, -0.17468955]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00355152, ..., -0.06076301,
#          -0.05937378, -0.05579214], dtype=float32)],
#  85: [array([[ 0.0387601 , -0.00332643,  0.01221326, ...,  0.03587086,
#           -0.03679839, -0.05990361],
#          [-0.04661412,  0.00540403,  0.07876182, ..., -0.08505322,
#           -0.11765136, -0.06638201],
#          [ 0.05092828,  0.02289174,  0.03793193, ...,  0.01872684,
#           -0.03741471, -0.05475113],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14914525, ..., -0.02979781,
#           -0.1187632 , -0.08555531],
#          [-0.0384247 , -0.01701165,  0.13322489, ...,  0.11067333,
#            0.10321028,  0.09104683],
#          [-0.03840593, -0.05995035,  0.08467729, ...,  0.03259557,
#           -0.20494868, -0.18495326]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00424598, ..., -0.05671517,
#          -0.05896012, -0.04582391], dtype=float32)],
#  86: [array([[ 0.0387601 , -0.00332643,  0.01252166, ...,  0.02848195,
#           -0.03636592, -0.05144319],
#          [-0.04661412,  0.00540403,  0.08121739, ..., -0.0951464 ,
#           -0.11759714, -0.05788393],
#          [ 0.05092828,  0.02289174,  0.03824004, ...,  0.01133644,
#           -0.03698229, -0.0462873 ],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14913191, ..., -0.03726632,
#           -0.11892772, -0.09353282],
#          [-0.0384247 , -0.01701165,  0.1302069 , ...,  0.11834363,
#            0.10291492,  0.08254344],
#          [-0.03840593, -0.05995035,  0.08909701, ...,  0.04010076,
#           -0.20459256, -0.17629525]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00455378, ..., -0.04932804,
#          -0.05939132, -0.05428075], dtype=float32)],
#  87: [array([[ 0.0387601 , -0.00332643,  0.01179924, ...,  0.02293625,
#           -0.03736633, -0.06111677],
#          [-0.04661412,  0.00540403,  0.08181957, ..., -0.09937104,
#           -0.11960606, -0.06759743],
#          [ 0.05092828,  0.02289174,  0.0375184 , ...,  0.00578967,
#           -0.0379826 , -0.05596439],
#          ...,
#          [ 0.04156775,  0.02885281,  0.15021819, ..., -0.04288831,
#           -0.12063869, -0.0997655 ],
#          [-0.0384247 , -0.01701165,  0.13497773, ...,  0.12414401,
#            0.10406084,  0.09227156],
#          [-0.03840593, -0.05995035,  0.08598867, ...,  0.0459582 ,
#           -0.20571886, -0.18623103]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00383287, ..., -0.04378365,
#          -0.05839381, -0.04461086], dtype=float32)],
#  88: [array([[ 0.0387601 , -0.00332643,  0.01196489, ...,  0.0414729 ,
#           -0.0363998 , -0.05011136],
#          [-0.04661412,  0.00540403,  0.08506239, ..., -0.08144879,
#           -0.1188865 , -0.05656179],
#          [ 0.05092828,  0.02289174,  0.03768388, ...,  0.02432881,
#           -0.03701617, -0.04495532],
#          ...,
#          [ 0.04156775,  0.02885281,  0.15017574, ..., -0.0242789 ,
#           -0.12026653, -0.09451411],
#          [-0.0384247 , -0.01701165,  0.13913088, ...,  0.10584122,
#            0.10332008,  0.08130111],
#          [-0.03840593, -0.05995035,  0.08562168, ...,  0.02768517,
#           -0.20481035, -0.17525178]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00399822, ..., -0.06231733,
#          -0.05935753, -0.05561244], dtype=float32)],
#  89: [array([[ 0.0387601 , -0.00332643,  0.01160463, ...,  0.03520338,
#           -0.03676311, -0.05996566],
#          [-0.04661412,  0.00540403,  0.08615159, ..., -0.0890809 ,
#           -0.11953108, -0.06645084],
#          [ 0.05092828,  0.02289174,  0.03732389, ...,  0.01805849,
#           -0.03737945, -0.05481253],
#          ...,
#          [ 0.04156775,  0.02885281,  0.15068552, ..., -0.03059191,
#           -0.12083389, -0.08249272],
#          [-0.0384247 , -0.01701165,  0.13726701, ...,  0.11233728,
#            0.10373486,  0.09120429],
#          [-0.03840593, -0.05995035,  0.08629572, ...,  0.03409867,
#           -0.20527585, -0.18537912]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00363852, ..., -0.05604878,
#          -0.05899528, -0.0457612 ], dtype=float32)],
#  90: [array([[ 0.0387601 , -0.00332643,  0.01263885, ...,  0.0284021 ,
#           -0.03667628, -0.05462785],
#          [-0.04661412,  0.00540403,  0.08629468, ..., -0.09466121,
#           -0.11957707, -0.06109865],
#          [ 0.05092828,  0.02289174,  0.03835728, ...,  0.01125638,
#           -0.03729263, -0.04947323],
#          ...,
#          [ 0.04156775,  0.02885281,  0.14984855, ..., -0.03744594,
#           -0.12096106, -0.08002964],
#          [-0.0384247 , -0.01701165,  0.13685599, ...,  0.11940589,
#            0.10368268,  0.08585283],
#          [-0.03840593, -0.05995035,  0.09257925, ...,  0.04097889,
#           -0.20524895, -0.18013732]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00467113, ..., -0.04924852,
#          -0.05908187, -0.05109746], dtype=float32)],
#  91: [array([[ 0.0387601 , -0.00332642,  0.01247388, ...,  0.02365299,
#           -0.03653407, -0.06095297],
#          [-0.04661412,  0.00540403,  0.08999809, ..., -0.10099196,
#           -0.11965388, -0.06745203],
#          [ 0.05092828,  0.02289174,  0.03819242, ...,  0.0065067 ,
#           -0.03715043, -0.05579986],
#          ...,
#          [ 0.04156775,  0.02885281,  0.15016647, ..., -0.04222018,
#           -0.12141214, -0.07234422],
#          [-0.0384247 , -0.01701165,  0.13645235, ...,  0.12438034,
#            0.10364024,  0.09224458],
#          [-0.03840593, -0.05995035,  0.1001656 , ...,  0.04575616,
#           -0.2051946 , -0.1866758 ]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.0045064 , ..., -0.04450009,
#          -0.05922368, -0.04477393], dtype=float32)],
#  92: [array([[ 0.0387601 , -0.00332641,  0.01246241, ...,  0.03518136,
#           -0.03686816, -0.05318319],
#          [-0.04661412,  0.00540403,  0.09205326, ..., -0.09148334,
#           -0.12018925, -0.05966658],
#          [ 0.05092828,  0.02289174,  0.03818096, ...,  0.01803629,
#           -0.03748449, -0.04802825],
#          ...,
#          [ 0.04156775,  0.02885281,  0.15065114, ..., -0.03066801,
#           -0.12217169, -0.07130669],
#          [-0.0384247 , -0.01701165,  0.13765663, ...,  0.11251993,
#            0.10406327,  0.08446738],
#          [-0.03840593, -0.05995035,  0.09849168, ...,  0.03402724,
#           -0.20560312, -0.17895128]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00449494, ..., -0.05602703,
#          -0.05889053, -0.05254187], dtype=float32)],
#  93: [array([[ 0.0387601 , -0.00332639,  0.0117402 , ...,  0.03277677,
#           -0.03725138, -0.05402414],
#          [-0.04661412,  0.00540403,  0.09918521, ..., -0.09423915,
#           -0.1208756 , -0.06050895],
#          [ 0.05092828,  0.02289174,  0.03745918, ...,  0.01563147,
#           -0.03786767, -0.04886933],
#          ...,
#          [ 0.04156775,  0.02885281,  0.15307935, ..., -0.03306113,
#           -0.12292179, -0.0672183 ],
#          [-0.0384247 , -0.01701165,  0.13632607, ...,  0.11500008,
#            0.10457998,  0.08531046],
#          [-0.03840593, -0.05995035,  0.10749471, ...,  0.03648247,
#           -0.20606977, -0.1798026 ]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00377356, ..., -0.05362272,
#          -0.05850841, -0.05170103], dtype=float32)],
#  94: [array([[ 0.0387601 , -0.00332637,  0.0132266 , ...,  0.02342215,
#           -0.03736903, -0.05423425],
#          [-0.04661412,  0.00540403,  0.09396029, ..., -0.10698739,
#           -0.12135779, -0.0607205 ],
#          [ 0.05092828,  0.02289174,  0.03894469, ...,  0.00627593,
#           -0.0379853 , -0.0490795 ],
#          ...,
#          [ 0.04156775,  0.02885281,  0.15197232, ..., -0.04242802,
#           -0.1246485 , -0.04959315],
#          [-0.0384247 , -0.01701165,  0.14167324, ...,  0.12465134,
#            0.10486319,  0.08552208],
#          [-0.03840593, -0.05995035,  0.10906675, ...,  0.04520481,
#           -0.20632568, -0.18001777]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00525821, ..., -0.04426918,
#          -0.05839112, -0.05149102], dtype=float32)],
#  95: [array([[ 0.0387601 , -0.00332637,  0.01304822, ...,  0.03745984,
#           -0.03630606, -0.06368307],
#          [-0.04661412,  0.00540403,  0.09621464, ..., -0.09752551,
#           -0.12024496, -0.07019669],
#          [ 0.05092828,  0.02289174,  0.0387664 , ...,  0.0203147 ,
#           -0.03692245, -0.05852978],
#          ...,
#          [ 0.04156775,  0.02885281,  0.15233798, ..., -0.02844503,
#           -0.12401543, -0.05594434],
#          [-0.0384247 , -0.01701165,  0.14146955, ...,  0.11039795,
#            0.10386973,  0.09503672],
#          [-0.03840593, -0.05995035,  0.11446335, ...,  0.03185147,
#           -0.20528719, -0.18992405]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00508   , ..., -0.0583056 ,
#          -0.05945103, -0.04204409], dtype=float32)],
#  96: [array([[ 0.0387601 , -0.00332636,  0.01487431, ...,  0.03108173,
#           -0.03579313, -0.04691903],
#          [-0.04661412,  0.00540403,  0.09836747, ..., -0.10810782,
#           -0.11985373, -0.05343359],
#          [ 0.05092828,  0.02289174,  0.04059209, ...,  0.01393614,
#           -0.03640955, -0.04176267],
#          ...,
#          [ 0.04156775,  0.02885281,  0.15091617, ..., -0.03487523,
#           -0.12433482, -0.07458078],
#          [-0.0384247 , -0.01701165,  0.13919765, ...,  0.11693946,
#            0.10339794,  0.07832824],
#          [-0.03840593, -0.05995035,  0.11707115, ...,  0.03834136,
#           -0.20482476, -0.1734141 ]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00690478, ..., -0.05192805,
#          -0.05996248, -0.0588065 ], dtype=float32)],
#  97: [array([[ 0.0387601 , -0.00332637,  0.01191944, ...,  0.02482925,
#           -0.03463729, -0.03746174],
#          [-0.04661412,  0.00540403,  0.0959652 , ..., -0.11703996,
#           -0.12098142, -0.06259819],
#          [ 0.05092828,  0.02289174,  0.03988922, ...,  0.00809724,
#           -0.03721656, -0.05091565],
#          ...,
#          [ 0.04156775,  0.02885281,  0.15188068, ..., -0.0407392 ,
#           -0.12569465, -0.07506316],
#          [-0.0384247 , -0.01701165,  0.14375912, ...,  0.12295092,
#            0.10427875,  0.08749725],
#          [-0.03840593, -0.05995035,  0.11280704, ...,  0.04447831,
#           -0.20578851, -0.1826364 ]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00620227, ..., -0.04609003,
#          -0.05915769, -0.04965581], dtype=float32)],
#  98: [array([[ 0.0387601 , -0.0033264 ,  0.01154955, ...,  0.01179268,
#           -0.03582127, -0.04418759],
#          [-0.04661412,  0.00540403,  0.09909452, ..., -0.09967434,
#           -0.11968955, -0.0558634 ],
#          [ 0.05092828,  0.02289174,  0.0402588 , ...,  0.02108582,
#           -0.03603268, -0.04418902],
#          ...,
#          [ 0.04156775,  0.02885281,  0.15201062, ..., -0.02771815,
#           -0.12550096, -0.08032117],
#          [-0.0384247 , -0.01701165,  0.1460251 , ...,  0.10972627,
#            0.10325962,  0.08075961],
#          [-0.03840593, -0.05995035,  0.10763084, ...,  0.03164294,
#           -0.20466663, -0.1758633 ]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00657173, ..., -0.05907691,
#          -0.0603383 , -0.05638085], dtype=float32)],
#  99: [array([[ 0.0387601 , -0.00332642,  0.01210878, ...,  0.01847064,
#           -0.03550655, -0.03473318],
#          [-0.04661412,  0.00540403,  0.10410762, ..., -0.10872798,
#           -0.12020218, -0.06532931],
#          [ 0.05092828,  0.02289174,  0.03969979, ...,  0.01443039,
#           -0.03634737, -0.05364444],
#          ...,
#          [ 0.04156775,  0.02885281,  0.15318613, ..., -0.03441561,
#           -0.1260257 , -0.08486212],
#          [-0.0384247 , -0.01701165,  0.14478144, ...,  0.11650857,
#            0.10362004,  0.09022993],
#          [-0.03840593, -0.05995035,  0.10864878, ...,  0.03838551,
#           -0.20503731, -0.1853808 ]], dtype=float32),
#   array([-0.11140331, -0.11177709, -0.00601296, ..., -0.0524223 ,
#          -0.06002446, -0.0469275 ], dtype=float32)]}

# %%
# Converts the unicode file to ascii
def unicode_to_ascii(s):
  return ''.join(c for c in unicodedata.normalize('NFD', s)
                 if unicodedata.category(c) != 'Mn')


def preprocess_sentence(w):
  w = unicode_to_ascii(w.lower().strip())

  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,¿])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  w = re.sub(r"[^a-zA-Z?.!,¿]+", " ", w)

  w = w.strip()

  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
  w = '<start> ' + w + ' <end>'
  return w

# %%
def evaluate(sentence):
  attention_plot = np.zeros((max_length_targ, max_length_inp))

  sentence = preprocess_sentence(sentence)

  inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, units))]
  enc_out, enc_hidden = encoder(inputs, hidden)

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  for t in range(max_length_targ):
    predictions, dec_hidden, attention_weights = decoder(dec_input,
                                                         dec_hidden,
                                                         enc_out)

    # storing the attention weights to plot later on
    attention_weights = tf.reshape(attention_weights, (-1, ))
    attention_plot[t] = attention_weights.numpy()

    predicted_id = tf.argmax(predictions[0]).numpy()

    result += targ_lang.index_word[predicted_id] + ' '

    if targ_lang.index_word[predicted_id] == '<end>':
      return result, sentence, attention_plot

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence, attention_plot

# %%
# function for plotting the attention weights
def plot_attention(attention, sentence, predicted_sentence):
  fig = plt.figure(figsize=(10, 10))
  ax = fig.add_subplot(1, 1, 1)
  ax.matshow(attention, cmap='viridis')

  fontdict = {'fontsize': 14}

  ax.set_xticklabels([''] + sentence, fontdict=fontdict, rotation=90)
  ax.set_yticklabels([''] + predicted_sentence, fontdict=fontdict)

  ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
  ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

  plt.show()

# %%
def translate(sentence):
  result, sentence, attention_plot = evaluate(sentence)

  print('Input:', sentence)
  print('Predicted translation:', result)

  attention_plot = attention_plot[:len(result.split(' ')),
                                  :len(sentence.split(' '))]
  plot_attention(attention_plot, sentence.split(' '), result.split(' '))

# %%
# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
test_sentence = 'mas e se estes fatores fossem ativos ?'
translate(test_sentence)
# Out:
# Input: <start> mas e se estes fatores fossem ativos ? <end>
# Predicted translation: but what if we have here at all ? <end>

# %%
np.save("rnn_attention_100epoch_1500data_weights.npy", DICT_WEIGHTS)

# %%
# !cp rnn_attention_100epoch_1500data_weights.npy "drive/My Drive/DSA5204_mine/RNN_attention"

# %%
pip install -q pyyaml h5py  # Required to save models in HDF5 format

# %%
encoder.save_weights('encoder_RNNattention_100epoch_1500dataset.h5')
# !cp encoder_RNNattention_100epoch_1500dataset.h5 "drive/My Drive/DSA5204_mine/RNN_attention"

# %%
decoder.save_weights('decoder_RNNattention_100epoch_1500dataset.h5')

# %%
# !cp decoder_RNNattention_100epoch_1500dataset.h5 "drive/My Drive/DSA5204_mine/RNN_attention"

# %% [markdown]
# To recall the weights, next time call `encoder.load_weights(path_to_load_weights)` or `decoder.load_weights(path_to_load_weights)`
