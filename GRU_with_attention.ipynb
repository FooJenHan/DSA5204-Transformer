# %% [markdown]
# # GRU with attention architecture
#
# ## NN for language translation (Portugese to English)
#
# Will extract weights from the training.

# %%
pip install -q tensorflow_datasets

# %%
pip install -q tensorflow-text

# %%
import collections
import logging
import os
import pathlib
import re
import string
import sys
import time

import numpy as np
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds
import tensorflow_text as text

import tensorflow as tf

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set(font_scale=1.5)

import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata

import pickle

os.environ["TF_FORCE_GPU_ALLOW_GROWTH"]="true"

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
examples, metadata = tfds.load('ted_hrlr_translate/pt_to_en', with_info=True,
                               as_supervised=True)

# %%
examples
# Out:
# {'test': <PrefetchDataset shapes: ((), ()), types: (tf.string, tf.string)>,
#  'train': <PrefetchDataset shapes: ((), ()), types: (tf.string, tf.string)>,
#  'validation': <PrefetchDataset shapes: ((), ()), types: (tf.string, tf.string)>}

# %%
train_examples, val_examples = examples['train'], examples['validation']

# %%
train_examples
# Out:
# <PrefetchDataset shapes: ((), ()), types: (tf.string, tf.string)>

# %%
# no of examples: 51785
for pt_examples, en_examples in train_examples.batch(1).take(20):
  for pt in pt_examples.numpy():
    print(pt.decode('utf-8'))

  for en in en_examples.numpy():
    print(en.decode('utf-8'))
  
  print()
# Out:
# e quando melhoramos a procura , tiramos a única vantagem da impressão , que é a serendipidade .
# and when you improve searchability , you actually take away the one advantage of print , which is serendipity .
#
# mas e se estes fatores fossem ativos ?
# but what if it were active ?
#
# mas eles não tinham a curiosidade de me testar .
# but they did n't test for curiosity .
#
# e esta rebeldia consciente é a razão pela qual eu , como agnóstica , posso ainda ter fé .
# and this conscious defiance is why i , as an agnostic , can still have faith .
#
# `` `` '' podem usar tudo sobre a mesa no meu corpo . ''
# you can use everything on the table on me .
#
# `` eu escrevo muito acerca do `` '' teatro de segurança '' '' , que são produtos que fazem as pessoas sentirem-se seguras mas que , na realidade , não fazem nada . ''
# `` i write a lot about `` '' security theater , '' '' which are products that make people feel secure , but do n't actually do anything . ''
#
# colocaram-no bem no fundo duma mina de ferro no minnesota , nos últimos dois dias anunciaram os resultados mais sensíveis até agora .
# and they 've put it deep down in an iron mine in minnesota , ok , deep under the ground , and in fact , in the last couple of days announced the most sensitive results so far .
#
# algumas pessoas têm medo de que não gostem delas .
# see , some people might fear girls not liking them back .
#
# não , o que nos aconteceu , chris , é que o poder , o preço está fixado fora da margem .
# no , what happened to us , chris , is that power , it 's priced off the margin .
#
# de volta à minha pergunta : porque é que fiquei ?
# back to my question : why did i stay ?
#
# `` quando descobri que havia uma série de indústrias sem proteção de direitos de autor , pensei : `` '' qual será a lógica subjacente ? ''
# `` when i found out that there are a whole bunch of industries that did n't have copyright protection , i thought , `` '' what exactly is the underlying logic ? ''
#
# a segunda ronda de votos também não apurou um vencedor claro .
# now the second round of voting did not bring forth a clear winner either .
#
# a cirurgia foi um sucesso .
# the surgery was successful .
#
# em vez disso , virámo-nos para uma nova geração de sensores de vídeo inicialmente criados para uso em óculos de visão noturna
# so instead , we turned to a new generation of video sensors , originally created for use in night vision goggles .
#
# olá , o meu nome é marcin sou agricultor , tecnólogo .
# hi , my name is marcin — farmer , technologist .
#
# talvez seja altura de arranjar uma caixa de ferramentas que não conte somente o que é fácil de contar , o que é tangível na vida , mas que conte realmente o que é mais precioso , as coisas que são intangíveis .
# maybe it 's time we get a toolbox that does n't just count what 's easily counted , the tangible in life , but actually counts what we most value , the things that are intangible .
#
# e , além disso , prevê-se que , para o final do século , quase todas as línguas que agora existem — existem cerca de 6000 — deixarão de ser faladas .
# and in addition to that , it 's been predicted that at the end of the century almost all of the languages that exist now — there are about 6,000 — will no longer be spoken .
#
# eu era amada .
# i was loved .
#
# o cérebro está a decidir qual é a textura associada à recompensa .
# and the brain is deciding what is the texture associated with the reward .
#
# eu acredito mesmo que não se pode pedir a um pequeno agricultor que trabalhe a terra , e se curve 150 000 vezes , para fazer crescer um hectare de arroz , só para plantar uma colheita e limpar as ervas .
# i feel so strongly that you can not ask a small farmer to work the land and bend over to grow a hectare of rice , 150,000 times , just to plant a crop and weed it .

# %%
# Only work with smaller data set as number of nodes in final layer of 
# GRU with attention is equal to vocab size (number of unique words) in 
# training set. Using the full dataset of 51785 examples will generate a 
# vocab size of 17000+ words, where we have insufficient RAM. The original
# nn architecture was only meant to train small datasets.

def create_dataset(training_data):
    the_data = []
    for pt_examples, en_examples in training_data.batch(1).take(1500):
        curr_example = []
        for en in en_examples.numpy():
            contents_en = '<start> ' + en.decode('utf-8') + ' <end>'
            curr_example.append(contents_en)
        for pt in pt_examples.numpy():
            contents_pt = '<start> ' + pt.decode('utf-8') + ' <end>'
            curr_example.append(contents_pt)
        the_data.append(curr_example)
    return zip(*the_data)

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %%
def load_dataset(data):
  # creating cleaned input, output pairs
  targ_lang, inp_lang = create_dataset(data)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %%
input_tensor_train, target_tensor_train, inp_lang, targ_lang = load_dataset(train_examples)

# %%
max_length_targ, max_length_inp = target_tensor_train.shape[1], input_tensor_train.shape[1]

# %%
input_tensor_val, target_tensor_val, _, _ = load_dataset(val_examples)

# %%
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 1500 1500 1193 1193

# %%
def convert(lang, tensor):
  for t in tensor:
    if t != 0:
      print(f'{t} ----> {lang.index_word[t]}')

# %%
print("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print()
print("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 2 ----> <start>
# 8 ----> e
# 41 ----> quando
# 1833 ----> melhoramos
# 5 ----> a
# 759 ----> procura
# 1 ----> ,
# 1834 ----> tiramos
# 5 ----> a
# 351 ----> única
# 1835 ----> vantagem
# 22 ----> da
# 760 ----> impressão
# 1 ----> ,
# 7 ----> que
# 10 ----> é
# 5 ----> a
# 1836 ----> serendipidade
# 4 ----> .
# 3 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 6 ----> and
# 48 ----> when
# 16 ----> you
# 739 ----> improve
# 1678 ----> searchability
# 4 ----> ,
# 16 ----> you
# 90 ----> actually
# 131 ----> take
# 308 ----> away
# 5 ----> the
# 40 ----> one
# 1679 ----> advantage
# 8 ----> of
# 1680 ----> print
# 4 ----> ,
# 107 ----> which
# 14 ----> is
# 1681 ----> serendipity
# 3 ----> .
# 2 ----> <end>

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 16
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 512
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1
#vocab_inp_size = 8500
#vocab_tar_size = 8000

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
vocab_inp_size
# Out:
# 5290

# %%
vocab_tar_size
# Out:
# 4385

# %%
dataset
# Out:
# <BatchDataset shapes: ((16, 119), (16, 144)), types: (tf.int32, tf.int32)>

# %%
len(input_tensor_train)
# Out:
# 1500

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([16, 119]), TensorShape([16, 144]))

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state=hidden)
    return output, state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_output, sample_hidden = encoder(example_input_batch, sample_hidden)
print('Encoder output shape: (batch size, sequence length, units)', sample_output.shape)
print('Encoder Hidden state shape: (batch size, units)', sample_hidden.shape)
# Out:
# Encoder output shape: (batch size, sequence length, units) (16, 119, 1024)
# Encoder Hidden state shape: (batch size, units) (16, 1024)

# %%
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):
    # query hidden state shape == (batch_size, hidden size)
    # query_with_time_axis shape == (batch_size, 1, hidden size)
    # values shape == (batch_size, max_len, hidden size)
    # we are doing this to broadcast addition along the time axis to calculate the score
    query_with_time_axis = tf.expand_dims(query, 1)

    # score shape == (batch_size, max_length, 1)
    # we get 1 at the last axis because we are applying score to self.V
    # the shape of the tensor before applying self.V is (batch_size, max_length, units)
    score = self.V(tf.nn.tanh(
        self.W1(query_with_time_axis) + self.W2(values)))

    # attention_weights shape == (batch_size, max_length, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
attention_layer = BahdanauAttention(10)
attention_result, attention_weights = attention_layer(sample_hidden, sample_output)

print("Attention result shape: (batch size, units)", attention_result.shape)
print("Attention weights shape: (batch_size, sequence_length, 1)", attention_weights.shape)
# Out:
# Attention result shape: (batch size, units) (16, 1024)
# Attention weights shape: (batch_size, sequence_length, 1) (16, 119, 1)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

    # used for attention
    self.attention = BahdanauAttention(self.dec_units)

  def call(self, x, hidden, enc_output):
    # enc_output shape == (batch_size, max_length, hidden_size)
    context_vector, attention_weights = self.attention(hidden, enc_output)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x)

    # output shape == (batch_size * 1, hidden_size)
    output = tf.reshape(output, (-1, output.shape[2]))

    # output shape == (batch_size, vocab)
    x = self.fc(output)

    return x, state, attention_weights

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

sample_decoder_output, _, _ = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden, sample_output)

print('Decoder output shape: (batch_size, vocab size)', sample_decoder_output.shape)
# Out:
# Decoder output shape: (batch_size, vocab size) (16, 4385)

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True,
                                                            reduction='none')


def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %%
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
DICT_WEIGHTS = {}

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_output, enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
EPOCHS = 100

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print(f'Epoch {epoch+1} Batch {batch} Loss {batch_loss.numpy():.4f}')
  # saving (checkpoint) the model every 2 epochs
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix=checkpoint_prefix)
  
  DICT_WEIGHTS[epoch] = decoder.fc.get_weights()

  print(f'Epoch {epoch+1} Loss {total_loss/steps_per_epoch:.4f}')
  print(f'Time taken for 1 epoch {time.time()-start:.2f} sec\n')
# Out:
# Epoch 1 Batch 0 Loss 1.2812
# Epoch 1 Loss 0.8277
# Time taken for 1 epoch 284.27 sec
#
# Epoch 2 Batch 0 Loss 0.7728
# Epoch 2 Loss 0.7469
# Time taken for 1 epoch 75.41 sec
#
# Epoch 3 Batch 0 Loss 0.5408
# Epoch 3 Loss 0.6927
# Time taken for 1 epoch 74.49 sec
#
# Epoch 4 Batch 0 Loss 0.5798
# Epoch 4 Loss 0.6390
# Time taken for 1 epoch 74.85 sec
#
# Epoch 5 Batch 0 Loss 0.7682
# Epoch 5 Loss 0.5987
# Time taken for 1 epoch 74.65 sec
#
# Epoch 6 Batch 0 Loss 0.4766
# Epoch 6 Loss 0.5509
# Time taken for 1 epoch 75.19 sec
#
# Epoch 7 Batch 0 Loss 0.5450
# Epoch 7 Loss 0.4983
# Time taken for 1 epoch 75.02 sec
#
# Epoch 8 Batch 0 Loss 0.4030
# Epoch 8 Loss 0.4548
# Time taken for 1 epoch 75.40 sec
#
# Epoch 9 Batch 0 Loss 0.4444
# Epoch 9 Loss 0.4049
# Time taken for 1 epoch 75.01 sec
#
# Epoch 10 Batch 0 Loss 0.4373
# Epoch 10 Loss 0.3563
# Time taken for 1 epoch 75.47 sec
#
# Epoch 11 Batch 0 Loss 0.1911
# Epoch 11 Loss 0.3122
# Time taken for 1 epoch 74.99 sec
#
# Epoch 12 Batch 0 Loss 0.2492
# Epoch 12 Loss 0.2707
# Time taken for 1 epoch 75.34 sec
#
# Epoch 13 Batch 0 Loss 0.3186
# Epoch 13 Loss 0.2347
# Time taken for 1 epoch 74.95 sec
#
# Epoch 14 Batch 0 Loss 0.2051
# Epoch 14 Loss 0.2025
# Time taken for 1 epoch 75.28 sec
#
# Epoch 15 Batch 0 Loss 0.1926
# Epoch 15 Loss 0.1737
# Time taken for 1 epoch 74.94 sec
#
# Epoch 16 Batch 0 Loss 0.1575
# Epoch 16 Loss 0.1488
# Time taken for 1 epoch 75.33 sec
#
# Epoch 17 Batch 0 Loss 0.1123
# Epoch 17 Loss 0.1263
# Time taken for 1 epoch 74.92 sec
#
# Epoch 18 Batch 0 Loss 0.0684
# Epoch 18 Loss 0.1045
# Time taken for 1 epoch 75.53 sec
#
# Epoch 19 Batch 0 Loss 0.0548
# Epoch 19 Loss 0.0888
# Time taken for 1 epoch 74.94 sec
#
# Epoch 20 Batch 0 Loss 0.0395
# Epoch 20 Loss 0.0756
# Time taken for 1 epoch 75.43 sec
#
# Epoch 21 Batch 0 Loss 0.0675
# Epoch 21 Loss 0.0640
# Time taken for 1 epoch 75.00 sec
#
# Epoch 22 Batch 0 Loss 0.0434
# Epoch 22 Loss 0.0518
# Time taken for 1 epoch 75.39 sec
#
# Epoch 23 Batch 0 Loss 0.0236
# Epoch 23 Loss 0.0442
# Time taken for 1 epoch 75.03 sec
#
# Epoch 24 Batch 0 Loss 0.0466
# Epoch 24 Loss 0.0377
# Time taken for 1 epoch 75.41 sec
#
# Epoch 25 Batch 0 Loss 0.0265
# Epoch 25 Loss 0.0328
# Time taken for 1 epoch 74.97 sec
#
# Epoch 26 Batch 0 Loss 0.0205
# Epoch 26 Loss 0.0286
# Time taken for 1 epoch 75.37 sec
#
# Epoch 27 Batch 0 Loss 0.0187
# Epoch 27 Loss 0.0246
# Time taken for 1 epoch 75.06 sec
#
# Epoch 28 Batch 0 Loss 0.0215
# Epoch 28 Loss 0.0220
# Time taken for 1 epoch 75.36 sec
#
# Epoch 29 Batch 0 Loss 0.0189
# Epoch 29 Loss 0.0201
# Time taken for 1 epoch 74.96 sec
#
# Epoch 30 Batch 0 Loss 0.0175
# Epoch 30 Loss 0.0197
# Time taken for 1 epoch 75.44 sec
#
# Epoch 31 Batch 0 Loss 0.0085
# Epoch 31 Loss 0.0185
# Time taken for 1 epoch 74.96 sec
#
# Epoch 32 Batch 0 Loss 0.0236
# Epoch 32 Loss 0.0179
# Time taken for 1 epoch 75.33 sec
#
# Epoch 33 Batch 0 Loss 0.0216
# Epoch 33 Loss 0.0171
# Time taken for 1 epoch 74.87 sec
#
# Epoch 34 Batch 0 Loss 0.0087
# Epoch 34 Loss 0.0160
# Time taken for 1 epoch 75.43 sec
#
# Epoch 35 Batch 0 Loss 0.0088
# Epoch 35 Loss 0.0147
# Time taken for 1 epoch 74.98 sec
#
# Epoch 36 Batch 0 Loss 0.0027
# Epoch 36 Loss 0.0138
# Time taken for 1 epoch 75.45 sec
#
# Epoch 37 Batch 0 Loss 0.0190
# Epoch 37 Loss 0.0129
# Time taken for 1 epoch 74.93 sec
#
# Epoch 38 Batch 0 Loss 0.0129
# Epoch 38 Loss 0.0131
# Time taken for 1 epoch 75.41 sec
#
# Epoch 39 Batch 0 Loss 0.0082
# Epoch 39 Loss 0.0124
# Time taken for 1 epoch 74.79 sec
#
# Epoch 40 Batch 0 Loss 0.0242
# Epoch 40 Loss 0.0123
# Time taken for 1 epoch 75.25 sec
#
# Epoch 41 Batch 0 Loss 0.0084
# Epoch 41 Loss 0.0129
# Time taken for 1 epoch 74.83 sec
#
# Epoch 42 Batch 0 Loss 0.0111
# Epoch 42 Loss 0.0133
# Time taken for 1 epoch 75.24 sec
#
# Epoch 43 Batch 0 Loss 0.0151
# Epoch 43 Loss 0.0134
# Time taken for 1 epoch 74.90 sec
#
# Epoch 44 Batch 0 Loss 0.0044
# Epoch 44 Loss 0.0147
# Time taken for 1 epoch 75.17 sec
#
# Epoch 45 Batch 0 Loss 0.0108
# Epoch 45 Loss 0.0164
# Time taken for 1 epoch 74.84 sec
#
# Epoch 46 Batch 0 Loss 0.0152
# Epoch 46 Loss 0.0163
# Time taken for 1 epoch 75.32 sec
#
# Epoch 47 Batch 0 Loss 0.0104
# Epoch 47 Loss 0.0172
# Time taken for 1 epoch 74.80 sec
#
# Epoch 48 Batch 0 Loss 0.0194
# Epoch 48 Loss 0.0145
# Time taken for 1 epoch 75.25 sec
#
# Epoch 49 Batch 0 Loss 0.0054
# Epoch 49 Loss 0.0135
# Time taken for 1 epoch 74.84 sec
#
# Epoch 50 Batch 0 Loss 0.0127
# Epoch 50 Loss 0.0126
# Time taken for 1 epoch 75.28 sec
#
# Epoch 51 Batch 0 Loss 0.0009
# Epoch 51 Loss 0.0117
# Time taken for 1 epoch 74.79 sec
#
# Epoch 52 Batch 0 Loss 0.0106
# Epoch 52 Loss 0.0110
# Time taken for 1 epoch 75.18 sec
#
# Epoch 53 Batch 0 Loss 0.0013
# Epoch 53 Loss 0.0106
# Time taken for 1 epoch 74.71 sec
#
# Epoch 54 Batch 0 Loss 0.0093
# Epoch 54 Loss 0.0102
# Time taken for 1 epoch 75.12 sec
#
# Epoch 55 Batch 0 Loss 0.0089
# Epoch 55 Loss 0.0111
# Time taken for 1 epoch 74.68 sec
#
# Epoch 56 Batch 0 Loss 0.0130
# Epoch 56 Loss 0.0112
# Time taken for 1 epoch 75.18 sec
#
# Epoch 57 Batch 0 Loss 0.0171
# Epoch 57 Loss 0.0105
# Time taken for 1 epoch 74.72 sec
#
# Epoch 58 Batch 0 Loss 0.0099
# Epoch 58 Loss 0.0096
# Time taken for 1 epoch 75.21 sec
#
# Epoch 59 Batch 0 Loss 0.0020
# Epoch 59 Loss 0.0095
# Time taken for 1 epoch 74.72 sec
#
# Epoch 60 Batch 0 Loss 0.0088
# Epoch 60 Loss 0.0096
# Time taken for 1 epoch 75.13 sec
#
# Epoch 61 Batch 0 Loss 0.0045
# Epoch 61 Loss 0.0110
# Time taken for 1 epoch 74.79 sec
#
# Epoch 62 Batch 0 Loss 0.0149
# Epoch 62 Loss 0.0111
# Time taken for 1 epoch 74.99 sec
#
# Epoch 63 Batch 0 Loss 0.0055
# Epoch 63 Loss 0.0106
# Time taken for 1 epoch 74.65 sec
#
# Epoch 64 Batch 0 Loss 0.0021
# Epoch 64 Loss 0.0113
# Time taken for 1 epoch 75.19 sec
#
# Epoch 65 Batch 0 Loss 0.0023
# Epoch 65 Loss 0.0113
# Time taken for 1 epoch 74.63 sec
#
# Epoch 66 Batch 0 Loss 0.0074
# Epoch 66 Loss 0.0110
# Time taken for 1 epoch 75.14 sec
#
# Epoch 67 Batch 0 Loss 0.0089
# Epoch 67 Loss 0.0102
# Time taken for 1 epoch 74.64 sec
#
# Epoch 68 Batch 0 Loss 0.0224
# Epoch 68 Loss 0.0105
# Time taken for 1 epoch 75.17 sec
#
# Epoch 69 Batch 0 Loss 0.0094
# Epoch 69 Loss 0.0108
# Time taken for 1 epoch 74.66 sec
#
# Epoch 70 Batch 0 Loss 0.0037
# Epoch 70 Loss 0.0104
# Time taken for 1 epoch 75.12 sec
#
# Epoch 71 Batch 0 Loss 0.0083
# Epoch 71 Loss 0.0110
# Time taken for 1 epoch 74.61 sec
#
# Epoch 72 Batch 0 Loss 0.0017
# Epoch 72 Loss 0.0104
# Time taken for 1 epoch 75.03 sec
#
# Epoch 73 Batch 0 Loss 0.0061
# Epoch 73 Loss 0.0104
# Time taken for 1 epoch 74.65 sec
#
# Epoch 74 Batch 0 Loss 0.0075
# Epoch 74 Loss 0.0113
# Time taken for 1 epoch 75.07 sec
#
# Epoch 75 Batch 0 Loss 0.0046
# Epoch 75 Loss 0.0111
# Time taken for 1 epoch 74.72 sec
#
# Epoch 76 Batch 0 Loss 0.0035
# Epoch 76 Loss 0.0108
# Time taken for 1 epoch 75.04 sec
#
# Epoch 77 Batch 0 Loss 0.0054
# Epoch 77 Loss 0.0100
# Time taken for 1 epoch 74.76 sec
#
# Epoch 78 Batch 0 Loss 0.0061
# Epoch 78 Loss 0.0101
# Time taken for 1 epoch 75.20 sec
#
# Epoch 79 Batch 0 Loss 0.0058
# Epoch 79 Loss 0.0091
# Time taken for 1 epoch 74.69 sec
#
# Epoch 80 Batch 0 Loss 0.0090
# Epoch 80 Loss 0.0081
# Time taken for 1 epoch 75.17 sec
#
# Epoch 81 Batch 0 Loss 0.0113
# Epoch 81 Loss 0.0076
# Time taken for 1 epoch 74.73 sec
#
# Epoch 82 Batch 0 Loss 0.0053
# Epoch 82 Loss 0.0067
# Time taken for 1 epoch 75.12 sec
#
# Epoch 83 Batch 0 Loss 0.0006
# Epoch 83 Loss 0.0069
# Time taken for 1 epoch 74.76 sec
#
# Epoch 84 Batch 0 Loss 0.0061
# Epoch 84 Loss 0.0068
# Time taken for 1 epoch 75.18 sec
#
# Epoch 85 Batch 0 Loss 0.0211
# Epoch 85 Loss 0.0070
# Time taken for 1 epoch 74.72 sec
#
# Epoch 86 Batch 0 Loss 0.0020
# Epoch 86 Loss 0.0066
# Time taken for 1 epoch 75.22 sec
#
# Epoch 87 Batch 0 Loss 0.0097
# Epoch 87 Loss 0.0072
# Time taken for 1 epoch 74.73 sec
#
# Epoch 88 Batch 0 Loss 0.0024
# Epoch 88 Loss 0.0074
# Time taken for 1 epoch 75.14 sec
#
# Epoch 89 Batch 0 Loss 0.0122
# Epoch 89 Loss 0.0076
# Time taken for 1 epoch 74.48 sec
#
# Epoch 90 Batch 0 Loss 0.0053
# Epoch 90 Loss 0.0083
# Time taken for 1 epoch 74.84 sec
#
# Epoch 91 Batch 0 Loss 0.0049
# Epoch 91 Loss 0.0082
# Time taken for 1 epoch 74.40 sec
#
# Epoch 92 Batch 0 Loss 0.0046
# Epoch 92 Loss 0.0088
# Time taken for 1 epoch 74.74 sec
#
# Epoch 93 Batch 0 Loss 0.0131
# Epoch 93 Loss 0.0102
# Time taken for 1 epoch 74.33 sec
#
# Epoch 94 Batch 0 Loss 0.0208
# Epoch 94 Loss 0.0097
# Time taken for 1 epoch 74.86 sec
#
# Epoch 95 Batch 0 Loss 0.0049
# Epoch 95 Loss 0.0107
# Time taken for 1 epoch 74.34 sec
#
# Epoch 96 Batch 0 Loss 0.0029
# Epoch 96 Loss 0.0116
# Time taken for 1 epoch 74.83 sec
#
# Epoch 97 Batch 0 Loss 0.0022
# Epoch 97 Loss 0.0124
# Time taken for 1 epoch 74.21 sec
#
# Epoch 98 Batch 0 Loss 0.0068
# Epoch 98 Loss 0.0107
# Time taken for 1 epoch 74.73 sec
#
# Epoch 99 Batch 0 Loss 0.0005
# Epoch 99 Loss 0.0099
# Time taken for 1 epoch 74.40 sec
#
# Epoch 100 Batch 0 Loss 0.0058
# Epoch 100 Loss 0.0077
# Time taken for 1 epoch 74.76 sec

# %%
DICT_WEIGHTS
# Out:
# {0: [array([[-0.04617412, -0.04694629,  0.03839928, ..., -0.01506268,
#            0.00338002, -0.02008821],
#          [-0.01440911, -0.03498006,  0.03520472, ..., -0.05574363,
#           -0.0160945 ,  0.00039731],
#          [ 0.00944467,  0.01194007,  0.0045286 , ...,  0.01428585,
#           -0.0316886 , -0.01283053],
#          ...,
#          [-0.03414195, -0.046904  ,  0.04817901, ..., -0.03848206,
#           -0.02726094, -0.02074008],
#          [ 0.03829492,  0.03746558, -0.03203278, ...,  0.03579752,
#            0.00362042,  0.03451482],
#          [-0.01617262,  0.00820626,  0.01379946, ..., -0.00566489,
#           -0.03925814, -0.00275345]], dtype=float32),
#   array([-0.03473484, -0.03243148,  0.00537093, ..., -0.02225018,
#          -0.02878586, -0.02323317], dtype=float32)],
#  1: [array([[-0.05422829, -0.05556699,  0.0321335 , ..., -0.02456994,
#            0.00448207, -0.02661474],
#          [-0.01809153, -0.03833961,  0.03348066, ..., -0.06467839,
#           -0.02035792, -0.00832529],
#          [ 0.00263997,  0.00434488, -0.00011717, ...,  0.01637185,
#           -0.04410893, -0.02977779],
#          ...,
#          [-0.04151193, -0.05478866,  0.04056223, ..., -0.04741279,
#           -0.03064658, -0.0323416 ],
#          [ 0.03940323,  0.03858582, -0.03205279, ...,  0.04033555,
#            0.0017002 ,  0.03577305],
#          [-0.01474991,  0.00969027,  0.015025  , ..., -0.01311246,
#           -0.02567567,  0.00889428]], dtype=float32),
#   array([-0.05206708, -0.04778022, -0.01477634, ..., -0.01705112,
#          -0.03294208, -0.02331851], dtype=float32)],
#  2: [array([[-0.05951354, -0.06128821,  0.02739765, ..., -0.03492833,
#            0.00545544, -0.03456643],
#          [-0.02073628, -0.04072203,  0.02843956, ..., -0.07521696,
#           -0.02013292, -0.0212323 ],
#          [ 0.0014573 ,  0.00329316, -0.00183423, ...,  0.00929166,
#           -0.03162313, -0.04133608],
#          ...,
#          [-0.04580403, -0.05935965,  0.03511801, ..., -0.05513856,
#           -0.03024145, -0.04040068],
#          [ 0.03872121,  0.03801595, -0.03216586, ...,  0.03100829,
#           -0.01522971,  0.02182668],
#          [-0.0144544 ,  0.00988282,  0.01919008, ..., -0.00859025,
#           -0.01718085,  0.01989247]], dtype=float32),
#   array([-0.06535932, -0.05977047, -0.02398557, ..., -0.0195766 ,
#          -0.03255713, -0.01956585], dtype=float32)],
#  3: [array([[-0.06372799, -0.06579932,  0.0266611 , ..., -0.04029822,
#            0.00106392, -0.03985846],
#          [-0.02275919, -0.04257353,  0.02552988, ..., -0.08520366,
#           -0.03320697, -0.02980544],
#          [ 0.00545991,  0.00760157, -0.00057637, ..., -0.00037848,
#           -0.02044788, -0.04295137],
#          ...,
#          [-0.05038819, -0.064369  ,  0.03359424, ..., -0.06275667,
#           -0.03304403, -0.04607791],
#          [ 0.04051866,  0.04005593, -0.03120402, ...,  0.0344188 ,
#           -0.01721738,  0.03745395],
#          [-0.01436115,  0.01022404,  0.02387934, ...,  0.00601232,
#           -0.02110142,  0.00688244]], dtype=float32),
#   array([-0.07646807, -0.069511  , -0.02819303, ..., -0.01010673,
#          -0.03602861, -0.02097648], dtype=float32)],
#  4: [array([[-0.06701305, -0.06920852,  0.02741566, ..., -0.04501046,
#           -0.00284878, -0.04405188],
#          [-0.02330044, -0.04304493,  0.02417161, ..., -0.07160777,
#           -0.04710038, -0.03616431],
#          [ 0.00665529,  0.00907714,  0.00046402, ..., -0.00169021,
#           -0.00802684, -0.05244111],
#          ...,
#          [-0.05285929, -0.06696559,  0.0341745 , ..., -0.06480689,
#           -0.03255474, -0.04803073],
#          [ 0.04117923,  0.04101944, -0.02985946, ...,  0.03525906,
#           -0.02870412,  0.03051375],
#          [-0.01363418,  0.01112365,  0.02614819, ...,  0.00415139,
#           -0.022246  ,  0.00630799]], dtype=float32),
#   array([-0.08386552, -0.07598747, -0.03081672, ..., -0.01237625,
#          -0.03553554, -0.01790685], dtype=float32)],
#  5: [array([[-0.06879779, -0.07089287,  0.02648396, ..., -0.04613602,
#           -0.01046113, -0.04646277],
#          [-0.02304974, -0.04287538,  0.02336666, ..., -0.07799745,
#           -0.05474551, -0.03632313],
#          [ 0.00904452,  0.01178142,  0.00114288, ..., -0.01561089,
#           -0.00886562, -0.05230613],
#          ...,
#          [-0.05442284, -0.06854965,  0.03298458, ..., -0.06757656,
#           -0.03830419, -0.04879505],
#          [ 0.04161711,  0.04158756, -0.03084831, ...,  0.04125708,
#           -0.03791675,  0.00032891],
#          [-0.01218178,  0.0127019 ,  0.02645388, ...,  0.00395635,
#           -0.01210245,  0.0114775 ]], dtype=float32),
#   array([-0.0893119 , -0.08043674, -0.03347889, ..., -0.00448928,
#          -0.04123623, -0.01970673], dtype=float32)],
#  6: [array([[-0.07002351, -0.07202464,  0.02792872, ..., -0.04895332,
#           -0.01417307, -0.0482018 ],
#          [-0.02317073, -0.04296276,  0.02354668, ..., -0.07575642,
#           -0.06054814, -0.03847753],
#          [ 0.01024186,  0.0132978 ,  0.00217183, ..., -0.02794034,
#           -0.00588969, -0.0571495 ],
#          ...,
#          [-0.05527051, -0.06939609,  0.03425819, ..., -0.06933251,
#           -0.03975848, -0.0492539 ],
#          [ 0.04217776,  0.04225561, -0.03411327, ...,  0.04243524,
#           -0.0420525 ,  0.00501137],
#          [-0.01065311,  0.0141084 ,  0.0208217 , ...,  0.00338969,
#           -0.0154696 ,  0.01842266]], dtype=float32),
#   array([-0.09270838, -0.08326213, -0.03406836, ..., -0.00297568,
#          -0.04137375, -0.01810203], dtype=float32)],
#  7: [array([[-0.07078921, -0.07278212,  0.02953644, ..., -0.05067123,
#           -0.01614807, -0.04957193],
#          [-0.02333673, -0.04312893,  0.02400245, ..., -0.06762109,
#           -0.06553333, -0.03851542],
#          [ 0.0107417 ,  0.01392948,  0.00322178, ..., -0.02454343,
#           -0.00461375, -0.05929685],
#          ...,
#          [-0.05560534, -0.06973443,  0.03563833, ..., -0.07089585,
#           -0.03914067, -0.04943677],
#          [ 0.04251143,  0.04260627, -0.03529024, ...,  0.04196559,
#           -0.03275857, -0.00427175],
#          [-0.0093499 ,  0.01537909,  0.02639383, ..., -0.00801497,
#           -0.01584844,  0.01430228]], dtype=float32),
#   array([-0.0945643 , -0.08483758, -0.0344863 , ..., -0.00738166,
#          -0.0413934 , -0.01793767], dtype=float32)],
#  8: [array([[-0.07119085, -0.07317141,  0.02906452, ..., -0.05297774,
#           -0.02658512, -0.05132844],
#          [-0.02343023, -0.04321241,  0.02409445, ..., -0.06387487,
#           -0.06885464, -0.0406412 ],
#          [ 0.01099531,  0.01430444,  0.00425347, ..., -0.00562082,
#           -0.00878534, -0.06791528],
#          ...,
#          [-0.05574212, -0.06986998,  0.03479464, ..., -0.0716724 ,
#           -0.0434543 , -0.0494937 ],
#          [ 0.04245703,  0.04255901, -0.03303286, ...,  0.03588155,
#           -0.00662917,  0.00454702],
#          [-0.00864905,  0.01605778,  0.01266372, ..., -0.01837552,
#            0.02661421,  0.01318478]], dtype=float32),
#   array([-0.09546359, -0.08558718, -0.03585065, ..., -0.0077891 ,
#          -0.04564638, -0.01543778], dtype=float32)],
#  9: [array([[-0.07142206, -0.07338858,  0.02948079, ..., -0.05305419,
#           -0.02430061, -0.05231893],
#          [-0.02351072, -0.0432815 ,  0.02318316, ..., -0.06363269,
#           -0.07365059, -0.04201198],
#          [ 0.01105921,  0.01439324,  0.00483526, ..., -0.01347562,
#           -0.00817378, -0.06832243],
#          ...,
#          [-0.05579129, -0.06991442,  0.03434829, ..., -0.0723556 ,
#           -0.03910892, -0.04928695],
#          [ 0.04241332,  0.04253311, -0.02960256, ...,  0.02997262,
#            0.00444596, -0.00781937],
#          [-0.00850738,  0.01618971,  0.01548626, ..., -0.0247184 ,
#            0.02294587,  0.00780641]], dtype=float32),
#   array([-0.09590606, -0.08593769, -0.03652734, ..., -0.00584239,
#          -0.04544712, -0.01655542], dtype=float32)],
#  10: [array([[-0.07154408, -0.07350855,  0.03131169, ..., -0.05256023,
#           -0.02479891, -0.0535287 ],
#          [-0.02354933, -0.04331856,  0.02470268, ..., -0.06000026,
#           -0.07608099, -0.04372754],
#          [ 0.01110742,  0.01445131,  0.00489179, ..., -0.00827437,
#           -0.00849716, -0.07231176],
#          ...,
#          [-0.05581887, -0.06993736,  0.03567746, ..., -0.07196356,
#           -0.03859545, -0.04925362],
#          [ 0.04235076,  0.04248902, -0.0268189 , ...,  0.02035168,
#            0.00829185, -0.0357412 ],
#          [-0.00849604,  0.01619984,  0.0058388 , ..., -0.04221265,
#            0.0340783 ,  0.0082064 ]], dtype=float32),
#   array([-0.09613845, -0.08611928, -0.03568855, ..., -0.00624768,
#          -0.04591545, -0.01498074], dtype=float32)],
#  11: [array([[-0.07162244, -0.07358368,  0.03218872, ..., -0.05203792,
#           -0.01918957, -0.05485015],
#          [-0.02357533, -0.04334172,  0.02550134, ..., -0.05731518,
#           -0.08084315, -0.04522497],
#          [ 0.01111183,  0.01446405,  0.00291269, ...,  0.01203506,
#           -0.00610545, -0.0753835 ],
#          ...,
#          [-0.05581303, -0.06993098,  0.03584936, ..., -0.07155268,
#           -0.03478253, -0.0492772 ],
#          [ 0.04230831,  0.04245947, -0.02602803, ...,  0.01690762,
#            0.02113993, -0.04077971],
#          [-0.0085424 ,  0.01615769,  0.00832228, ..., -0.06079724,
#            0.04531005,  0.02256132]], dtype=float32),
#   array([-0.09627255, -0.08622146, -0.03542564, ..., -0.00479782,
#          -0.04401014, -0.01397598], dtype=float32)],
#  12: [array([[-0.07166716, -0.07362602,  0.03549704, ..., -0.05216592,
#           -0.02209698, -0.05668983],
#          [-0.02359176, -0.04335541,  0.02635551, ..., -0.05506054,
#           -0.07763721, -0.04907229],
#          [ 0.01111297,  0.01446825,  0.00158331, ...,  0.00758057,
#           -0.00848118, -0.08068925],
#          ...,
#          [-0.05581113, -0.06993079,  0.03832006, ..., -0.06950408,
#           -0.03594632, -0.04931963],
#          [ 0.04227517,  0.04243503, -0.02060507, ...,  0.01489131,
#            0.01839719, -0.02961185],
#          [-0.00861293,  0.01609338,  0.00534556, ..., -0.07858721,
#            0.04361   ,  0.02841273]], dtype=float32),
#   array([-0.09635254, -0.08628129, -0.03339398, ..., -0.00489016,
#          -0.04615255, -0.01028057], dtype=float32)],
#  13: [array([[-0.07170028, -0.0736573 ,  0.03580571, ..., -0.05124445,
#           -0.02007777, -0.05611492],
#          [-0.02360393, -0.0433651 ,  0.02676415, ..., -0.05403129,
#           -0.07807931, -0.04963003],
#          [ 0.01112745,  0.01448294,  0.00425984, ...,  0.00606526,
#           -0.00817219, -0.08270304],
#          ...,
#          [-0.05580911, -0.06992821,  0.03875464, ..., -0.06912488,
#           -0.03544638, -0.04925763],
#          [ 0.04227506,  0.04243718, -0.01999493, ...,  0.01716136,
#            0.02192799, -0.01944124],
#          [-0.00864344,  0.01606465, -0.00700651, ..., -0.08117324,
#            0.04716036,  0.03622156]], dtype=float32),
#   array([-0.0964076 , -0.0863217 , -0.03335401, ..., -0.00496175,
#          -0.04595562, -0.00933889], dtype=float32)],
#  14: [array([[-0.07172609, -0.07368215,  0.03776999, ..., -0.05071454,
#           -0.02068638, -0.054276  ],
#          [-0.02361186, -0.04337145,  0.02545526, ..., -0.04969802,
#           -0.07934061, -0.04650404],
#          [ 0.01113994,  0.01449341,  0.00226033, ...,  0.00744687,
#           -0.00894348, -0.07926216],
#          ...,
#          [-0.0558103 , -0.06992766,  0.04099717, ..., -0.06734452,
#           -0.03653158, -0.04906788],
#          [ 0.04226285,  0.04242894, -0.02459249, ...,  0.01961314,
#            0.02203858, -0.02544521],
#          [-0.00866368,  0.01604288,  0.00146663, ..., -0.08201324,
#            0.04817124,  0.03656733]], dtype=float32),
#   array([-0.09645048, -0.0863523 , -0.03221371, ..., -0.00705208,
#          -0.04668235, -0.01358119], dtype=float32)],
#  15: [array([[-0.07174995, -0.07370314,  0.03919809, ..., -0.05291137,
#           -0.01806911, -0.05480329],
#          [-0.02362038, -0.04337768,  0.02007633, ..., -0.05216825,
#           -0.07743302, -0.04513006],
#          [ 0.01113068,  0.01448859,  0.00312616, ..., -0.00280189,
#           -0.00740947, -0.07916001],
#          ...,
#          [-0.05580705, -0.06992488,  0.04253769, ..., -0.07169484,
#           -0.03593868, -0.0487998 ],
#          [ 0.04225469,  0.04242465, -0.03052494, ...,  0.01779443,
#            0.02289142, -0.0201767 ],
#          [-0.00870422,  0.01600933, -0.01178153, ..., -0.10585915,
#            0.05692124,  0.03974255]], dtype=float32),
#   array([-0.09647986, -0.08637314, -0.03104139, ..., -0.0015178 ,
#          -0.04544301, -0.01510921], dtype=float32)],
#  16: [array([[-0.07176487, -0.0737166 ,  0.04053949, ..., -0.04810618,
#           -0.01974683, -0.05485056],
#          [-0.02362517, -0.04338215,  0.01883361, ..., -0.02869754,
#           -0.07820651, -0.04688901],
#          [ 0.01112846,  0.01448892,  0.00198554, ...,  0.01321492,
#           -0.00844029, -0.07955107],
#          ...,
#          [-0.05580446, -0.06992261,  0.04328372, ..., -0.06173786,
#           -0.03748666, -0.04867334],
#          [ 0.04224914,  0.04242237, -0.0226769 , ...,  0.02212532,
#            0.02159012, -0.01421372],
#          [-0.00872394,  0.01599304, -0.01761336, ..., -0.09996553,
#            0.05622022,  0.04228368]], dtype=float32),
#   array([-0.09650095, -0.08638843, -0.03097922, ..., -0.01458301,
#          -0.04644748, -0.01522192], dtype=float32)],
#  17: [array([[-0.07178359, -0.07373632,  0.04086567, ..., -0.05228552,
#           -0.01994617, -0.05503512],
#          [-0.02362996, -0.04338707,  0.01464592, ..., -0.03234942,
#           -0.07767931, -0.04625054],
#          [ 0.01112429,  0.01448518,  0.00249257, ..., -0.00019225,
#           -0.00855368, -0.07873248],
#          ...,
#          [-0.05580101, -0.06991774,  0.04391792, ..., -0.07236908,
#           -0.0382663 , -0.04839395],
#          [ 0.04224283,  0.04241729, -0.02137304, ...,  0.00614523,
#            0.02235995, -0.01359993],
#          [-0.00875338,  0.01596333, -0.01858743, ..., -0.11829532,
#            0.05687841,  0.04143229]], dtype=float32),
#   array([-0.09651954, -0.08640252, -0.0306261 , ..., -0.00485257,
#          -0.04658628, -0.01624544], dtype=float32)],
#  18: [array([[-0.07179914, -0.07375196,  0.04437013, ..., -0.05086482,
#           -0.01878133, -0.05497973],
#          [-0.02363164, -0.04338887,  0.01677398, ..., -0.0199679 ,
#           -0.07560878, -0.04618835],
#          [ 0.01111711,  0.01448036, -0.00094308, ...,  0.00670042,
#           -0.00760107, -0.07974554],
#          ...,
#          [-0.05579985, -0.06991725,  0.04621575, ..., -0.05920183,
#           -0.03738718, -0.04834435],
#          [ 0.04223735,  0.04241315, -0.02059873, ...,  0.00767767,
#            0.02601268, -0.00937444],
#          [-0.00877239,  0.01594613, -0.02376285, ..., -0.10251486,
#            0.06020121,  0.04338126]], dtype=float32),
#   array([-0.09653449, -0.08641371, -0.02813314, ..., -0.01114085,
#          -0.04580629, -0.01607917], dtype=float32)],
#  19: [array([[-0.07180776, -0.07376045,  0.04282933, ..., -0.05269201,
#           -0.01992776, -0.05469872],
#          [-0.02363462, -0.04339133,  0.01623476, ..., -0.03168927,
#           -0.07433529, -0.04550816],
#          [ 0.01111208,  0.01447728, -0.003649  , ..., -0.00588939,
#           -0.00860993, -0.07866774],
#          ...,
#          [-0.05579656, -0.06991412,  0.04463688, ..., -0.07372686,
#           -0.03915828, -0.04825315],
#          [ 0.04223663,  0.04241382, -0.01613751, ..., -0.0067805 ,
#            0.02581544, -0.00566314],
#          [-0.0087825 ,  0.01593718, -0.01846064, ..., -0.11417777,
#            0.05989256,  0.04088445]], dtype=float32),
#   array([-0.09654614, -0.08642226, -0.02997417, ..., -0.00156152,
#          -0.04674777, -0.0174048 ], dtype=float32)],
#  20: [array([[-0.07181839, -0.07377055,  0.04386899, ..., -0.04808586,
#           -0.02034115, -0.05461792],
#          [-0.02363745, -0.04339368,  0.01771284, ..., -0.00616901,
#           -0.07329673, -0.0454807 ],
#          [ 0.01110507,  0.01447225, -0.00715204, ...,  0.01057678,
#           -0.00889931, -0.07889698],
#          ...,
#          [-0.05579715, -0.06991395,  0.04544234, ..., -0.04759702,
#           -0.03989474, -0.04819075],
#          [ 0.04223249,  0.04241215, -0.02099066, ...,  0.0070849 ,
#            0.02621499, -0.00419993],
#          [-0.00879042,  0.01592987, -0.02152675, ..., -0.10876254,
#            0.06004674,  0.04145566]], dtype=float32),
#   array([-0.09655698, -0.08643045, -0.02914982, ..., -0.01525018,
#          -0.04702363, -0.01736557], dtype=float32)],
#  21: [array([[-0.07182698, -0.07377912,  0.04324713, ..., -0.04959506,
#           -0.02061986, -0.05451469],
#          [-0.02364017, -0.04339623,  0.01615233, ..., -0.00672302,
#           -0.07263745, -0.04426844],
#          [ 0.01110059,  0.01446914, -0.00930151, ..., -0.00035314,
#           -0.00920226, -0.078401  ],
#          ...,
#          [-0.05579892, -0.06991591,  0.04613044, ..., -0.05453772,
#           -0.04070413, -0.04815225],
#          [ 0.04222654,  0.04240788, -0.0207565 , ...,  0.02076849,
#            0.02620765, -0.00567564],
#          [-0.0087998 ,  0.01592082, -0.02116897, ..., -0.13623583,
#            0.06014959,  0.04051111]], dtype=float32),
#   array([-0.09656546, -0.08643676, -0.02914924, ..., -0.00565031,
#          -0.04736682, -0.01796017], dtype=float32)],
#  22: [array([[-0.0718358 , -0.07378795,  0.04492644, ..., -0.05000835,
#           -0.02021192, -0.05449431],
#          [-0.02364277, -0.04339877,  0.01864566, ..., -0.01505926,
#           -0.06978054, -0.04347041],
#          [ 0.01109568,  0.01446543, -0.00787206, ..., -0.00334562,
#           -0.0083742 , -0.07884297],
#          ...,
#          [-0.05580015, -0.06991666,  0.04641647, ..., -0.06290745,
#           -0.04031295, -0.04810019],
#          [ 0.04222445,  0.04240707, -0.0249346 , ...,  0.01809112,
#            0.02836496, -0.00326368],
#          [-0.00880207,  0.01591762, -0.02618301, ..., -0.13494393,
#            0.06250881,  0.04082204]], dtype=float32),
#   array([-0.09657297, -0.0864424 , -0.0277109 , ..., -0.00321439,
#          -0.0466921 , -0.01793946], dtype=float32)],
#  23: [array([[-0.07184401, -0.07379688,  0.0431493 , ..., -0.05034257,
#           -0.02059   , -0.054431  ],
#          [-0.02364312, -0.04339926,  0.01844128, ..., -0.01184232,
#           -0.0689216 , -0.04313387],
#          [ 0.01108839,  0.01445879, -0.00673601, ..., -0.00721187,
#           -0.0086095 , -0.07890488],
#          ...,
#          [-0.05579809, -0.06991534,  0.04651574, ..., -0.06767482,
#           -0.04102829, -0.04805854],
#          [ 0.04221851,  0.04240286, -0.01784642, ...,  0.01345384,
#            0.02852295, -0.00262021],
#          [-0.00880611,  0.01591447, -0.02056001, ..., -0.13681984,
#            0.06261395,  0.04096295]], dtype=float32),
#   array([-0.09657989, -0.08644761, -0.02904298, ..., -0.00038693,
#          -0.04691846, -0.01795124], dtype=float32)],
#  24: [array([[-0.07185183, -0.07380398,  0.04627858, ..., -0.04928082,
#           -0.02081069, -0.05442928],
#          [-0.02364423, -0.04340025,  0.01824011, ..., -0.00705359,
#           -0.06789803, -0.04340737],
#          [ 0.01108012,  0.01445258, -0.00359475, ...,  0.00019919,
#           -0.00854634, -0.07922924],
#          ...,
#          [-0.05579466, -0.06991276,  0.04827295, ..., -0.05973834,
#           -0.0413602 , -0.04800734],
#          [ 0.04221461,  0.04240062, -0.01771783, ...,  0.02435459,
#            0.02922085,  0.00045518],
#          [-0.00881538,  0.01590686, -0.02795386, ..., -0.12370184,
#            0.06326946,  0.04155946]], dtype=float32),
#   array([-0.09658636, -0.0864522 , -0.0262161 , ..., -0.0068918 ,
#          -0.04688602, -0.01776262], dtype=float32)],
#  25: [array([[-0.07185896, -0.0738107 ,  0.04572167, ..., -0.05033704,
#           -0.02112294, -0.05444992],
#          [-0.02364487, -0.04340101,  0.02178604, ..., -0.01241986,
#           -0.06784575, -0.0434094 ],
#          [ 0.01107381,  0.01444802, -0.00425715, ..., -0.01042009,
#           -0.00883481, -0.07931452],
#          ...,
#          [-0.05579336, -0.06991197,  0.04686445, ..., -0.07105692,
#           -0.04199817, -0.04797878],
#          [ 0.04221179,  0.04239907, -0.02202426, ...,  0.03750965,
#            0.02895608,  0.00157459],
#          [-0.00881379,  0.01590733, -0.02704637, ..., -0.13523397,
#            0.06304491,  0.04173649]], dtype=float32),
#   array([-0.09659199, -0.08645628, -0.02658326, ...,  0.00222753,
#          -0.04715307, -0.01774037], dtype=float32)],
#  26: [array([[-0.07186583, -0.07381733,  0.04536785, ..., -0.04886913,
#           -0.02134825, -0.0544627 ],
#          [-0.0236458 , -0.04340177,  0.02412192, ..., -0.00256932,
#           -0.06745934, -0.0431073 ],
#          [ 0.01106997,  0.01444565, -0.00828894, ...,  0.00321156,
#           -0.00911404, -0.0792862 ],
#          ...,
#          [-0.05579408, -0.06991263,  0.04603573, ..., -0.05676775,
#           -0.04284857, -0.0479659 ],
#          [ 0.04220917,  0.04239784, -0.02216412, ...,  0.01055039,
#            0.02890501,  0.00197699],
#          [-0.00881839,  0.01590297, -0.02295727, ..., -0.11995786,
#            0.06317271,  0.04161715]], dtype=float32),
#   array([-0.09659734, -0.08646019, -0.02684432, ..., -0.01086187,
#          -0.04741301, -0.01784448], dtype=float32)],
#  27: [array([[-0.07187136, -0.07382299,  0.04661076, ..., -0.04906426,
#           -0.02171937, -0.05445294],
#          [-0.02364627, -0.04340219,  0.02288431, ..., -0.00352915,
#           -0.06665514, -0.04290339],
#          [ 0.01106687,  0.01444328, -0.00808911, ...,  0.00092263,
#           -0.00940744, -0.07917475],
#          ...,
#          [-0.05579522, -0.06991445,  0.04677812, ..., -0.0600298 ,
#           -0.0437675 , -0.04794103],
#          [ 0.04220607,  0.04239507, -0.02367831, ...,  0.01297217,
#            0.02872217,  0.00254485],
#          [-0.00881937,  0.01590155, -0.03052941, ..., -0.12109513,
#            0.06342512,  0.04135001]], dtype=float32),
#   array([-0.09660151, -0.08646344, -0.02603537, ..., -0.00881268,
#          -0.04768148, -0.01799337], dtype=float32)],
#  28: [array([[-0.07187678, -0.07382806,  0.04695123, ..., -0.04990928,
#           -0.02188728, -0.05445418],
#          [-0.02364733, -0.04340307,  0.02235315, ..., -0.01082228,
#           -0.06685111, -0.04319547],
#          [ 0.01106061,  0.01443887, -0.00657067, ..., -0.0128406 ,
#           -0.00960005, -0.07923649],
#          ...,
#          [-0.05579655, -0.06991578,  0.04654899, ..., -0.08205454,
#           -0.04421374, -0.04792321],
#          [ 0.04220228,  0.04239263, -0.02544514, ...,  0.02679653,
#            0.0288012 ,  0.00381219],
#          [-0.0088154 ,  0.01590385, -0.02657227, ..., -0.12562972,
#            0.06335058,  0.04141909]], dtype=float32),
#   array([-0.09660628, -0.08646685, -0.02622451, ...,  0.00350134,
#          -0.0478608 , -0.01798728], dtype=float32)],
#  29: [array([[-0.07188408, -0.07383455,  0.04471299, ..., -0.0495884 ,
#           -0.02202119, -0.05441225],
#          [-0.02364819, -0.04340381,  0.02014416, ...,  0.01016865,
#           -0.06665358, -0.04341995],
#          [ 0.01105423,  0.014434  , -0.00883482, ..., -0.00548736,
#           -0.00973601, -0.07938118],
#          ...,
#          [-0.05580023, -0.06991926,  0.04418748, ..., -0.05932481,
#           -0.04487787, -0.04791171],
#          [ 0.04219822,  0.04239005, -0.02448934, ...,  0.02355815,
#            0.02935878,  0.00677805],
#          [-0.00881244,  0.01590653, -0.03474389, ..., -0.11582914,
#            0.06333944,  0.04150642]], dtype=float32),
#   array([-0.0966111 , -0.08647037, -0.02820741, ..., -0.00436706,
#          -0.0479891 , -0.01798007], dtype=float32)],
#  30: [array([[-0.07188799, -0.07383822,  0.04639343, ..., -0.04977832,
#           -0.02227511, -0.05445028],
#          [-0.02364862, -0.0434042 ,  0.02532524, ...,  0.00811861,
#           -0.06696879, -0.04393365],
#          [ 0.01105151,  0.01443213, -0.01554275, ..., -0.01072177,
#           -0.01000115, -0.07950891],
#          ...,
#          [-0.05579999, -0.06991988,  0.04660695, ..., -0.06967807,
#           -0.04554726, -0.04791536],
#          [ 0.04219632,  0.04238918, -0.03083619, ...,  0.02914617,
#            0.02893165,  0.00848648],
#          [-0.00881325,  0.01590554, -0.0280911 , ..., -0.1165853 ,
#            0.06286119,  0.04172637]], dtype=float32),
#   array([-0.0966149 , -0.08647319, -0.02658177, ...,  0.0005842 ,
#          -0.04823945, -0.01790521], dtype=float32)],
#  31: [array([[-0.07189339, -0.07384427,  0.04654416, ..., -0.04944403,
#           -0.02236369, -0.05448546],
#          [-0.02364919, -0.04340474,  0.02628876, ...,  0.00933134,
#           -0.06712497, -0.0434914 ],
#          [ 0.01104668,  0.0144275 , -0.01749643, ..., -0.00896189,
#           -0.01011913, -0.07954578],
#          ...,
#          [-0.05580324, -0.06992434,  0.04630182, ..., -0.0667638 ,
#           -0.04614493, -0.04788586],
#          [ 0.04219329,  0.04238674, -0.03236188, ...,  0.02880213,
#            0.02943106,  0.00969131],
#          [-0.00881161,  0.01590848, -0.03744999, ..., -0.11512291,
#            0.06292949,  0.04171253]], dtype=float32),
#   array([-0.09661903, -0.08647653, -0.02640232, ..., -0.00107374,
#          -0.04835282, -0.01792786], dtype=float32)],
#  32: [array([[-0.07189634, -0.07384638,  0.04493884, ..., -0.04954471,
#           -0.02228245, -0.05452725],
#          [-0.02364888, -0.04340409,  0.02622852, ...,  0.0095866 ,
#           -0.06630448, -0.0435165 ],
#          [ 0.01104367,  0.01442574, -0.02101907, ..., -0.01350925,
#           -0.01007419, -0.07963708],
#          ...,
#          [-0.05580357, -0.06992488,  0.04634403, ..., -0.0748407 ,
#           -0.04648335, -0.04787456],
#          [ 0.04218909,  0.04238348, -0.03479082, ...,  0.03959967,
#            0.03012234,  0.01068253],
#          [-0.00881171,  0.01590792, -0.02067568, ..., -0.11527346,
#            0.06339886,  0.04187318]], dtype=float32),
#   array([-0.09662345, -0.08647975, -0.02716191, ...,  0.00299639,
#          -0.04832501, -0.01789211], dtype=float32)],
#  33: [array([[-0.07189962, -0.07385007,  0.04581852, ..., -0.04898932,
#           -0.02171017, -0.05460501],
#          [-0.02364954, -0.04340469,  0.02897928, ...,  0.0129184 ,
#           -0.06177238, -0.04345431],
#          [ 0.01104291,  0.01442615, -0.0184904 , ..., -0.00694515,
#           -0.00919358, -0.0798235 ],
#          ...,
#          [-0.05580334, -0.06992543,  0.04867049, ..., -0.06540985,
#           -0.04654322, -0.0478851 ],
#          [ 0.0421871 ,  0.04238173, -0.03635217, ...,  0.02528427,
#            0.03287848,  0.0122059 ],
#          [-0.00881597,  0.01590301, -0.02873223, ..., -0.10980199,
#            0.0654998 ,  0.04219012]], dtype=float32),
#   array([-0.09662669, -0.08648226, -0.026933  , ..., -0.00332695,
#          -0.04757611, -0.01777654], dtype=float32)],
#  34: [array([[-0.07190256, -0.07385288,  0.04523782, ..., -0.04989817,
#           -0.02192784, -0.05446338],
#          [-0.02365016, -0.04340525,  0.02267992, ...,  0.01287325,
#           -0.06206961, -0.04365228],
#          [ 0.01103952,  0.01442362, -0.01429977, ..., -0.014426  ,
#           -0.00948148, -0.07937631],
#          ...,
#          [-0.05580417, -0.06992665,  0.04813939, ..., -0.06572746,
#           -0.04743674, -0.04787628],
#          [ 0.04218504,  0.04238039, -0.03564385, ...,  0.02807224,
#            0.03250948,  0.01163517],
#          [-0.00881904,  0.01590037, -0.02848898, ..., -0.10876648,
#            0.06515227,  0.04110073]], dtype=float32),
#   array([-0.09662982, -0.08648457, -0.02720079, ...,  0.00358474,
#          -0.04783249, -0.01828621], dtype=float32)],
#  35: [array([[-0.07190522, -0.07385556,  0.04651184, ..., -0.04947121,
#           -0.02210813, -0.0544855 ],
#          [-0.02365057, -0.04340564,  0.03059913, ...,  0.01346456,
#           -0.06189929, -0.04359191],
#          [ 0.01103688,  0.01442188, -0.02033884, ..., -0.01085842,
#           -0.00960781, -0.07943995],
#          ...,
#          [-0.05580416, -0.06992707,  0.04841954, ..., -0.06412599,
#           -0.0477838 , -0.04787529],
#          [ 0.04218448,  0.04238025, -0.03871892, ...,  0.02491491,
#            0.03260743,  0.01257845],
#          [-0.00882101,  0.01589824, -0.0314386 , ..., -0.10086275,
#            0.06500106,  0.04119056]], dtype=float32),
#   array([-0.09663298, -0.08648694, -0.02708981, ...,  0.00015981,
#          -0.04794901, -0.01826967], dtype=float32)],
#  36: [array([[-0.07190933, -0.0738597 ,  0.04514132, ..., -0.04950088,
#           -0.02229334, -0.05460133],
#          [-0.02365083, -0.04340604,  0.02965293, ...,  0.01529112,
#           -0.06241833, -0.04399057],
#          [ 0.01103289,  0.01441875, -0.01752333, ..., -0.01072964,
#           -0.01018561, -0.07969221],
#          ...,
#          [-0.05580651, -0.06992981,  0.04811899, ..., -0.06326637,
#           -0.05220869, -0.04791386],
#          [ 0.04218308,  0.04237962, -0.02582915, ...,  0.02458773,
#            0.03105428,  0.01488321],
#          [-0.00882487,  0.01589343, -0.01820697, ..., -0.10150587,
#            0.06387281,  0.04163965]], dtype=float32),
#   array([-9.6636400e-02, -8.6489536e-02, -2.7124783e-02, ...,
#           3.2380860e-05, -4.8457429e-02, -1.8104499e-02], dtype=float32)],
#  37: [array([[-0.07191613, -0.07386669,  0.04471735, ..., -0.04958056,
#           -0.02234591, -0.0546045 ],
#          [-0.02365104, -0.04340646,  0.02912199, ...,  0.01536128,
#           -0.0619624 , -0.04383709],
#          [ 0.01102676,  0.01441491, -0.01474905, ..., -0.0119199 ,
#           -0.01028019, -0.07965115],
#          ...,
#          [-0.05581255, -0.06993611,  0.04937691, ..., -0.06587175,
#           -0.05274013, -0.04792076],
#          [ 0.04218006,  0.04237729, -0.03846355, ...,  0.02606976,
#            0.03130964,  0.01486722],
#          [-0.00883141,  0.01588533, -0.02317601, ..., -0.10144987,
#            0.06386159,  0.04152077]], dtype=float32),
#   array([-0.09664033, -0.08649269, -0.0263468 , ...,  0.00114776,
#          -0.04854659, -0.01817084], dtype=float32)],
#  38: [array([[-0.07191969, -0.07386996,  0.04646901, ..., -0.04963405,
#           -0.02250727, -0.05462927],
#          [-0.02365118, -0.04340663,  0.03512776, ...,  0.01749939,
#           -0.06104811, -0.04377027],
#          [ 0.01102349,  0.0144126 , -0.00897472, ..., -0.01218532,
#           -0.01057701, -0.07971839],
#          ...,
#          [-0.05581344, -0.069937  ,  0.05086624, ..., -0.06539638,
#           -0.05355584, -0.04791784],
#          [ 0.04218053,  0.04237869, -0.0369359 , ...,  0.02641475,
#            0.03168269,  0.01564327],
#          [-0.00883506,  0.01588135, -0.02882653, ..., -0.10186338,
#            0.06370295,  0.04161738]], dtype=float32),
#   array([-0.09664356, -0.08649524, -0.02466648, ...,  0.00137339,
#          -0.04880898, -0.01813862], dtype=float32)],
#  39: [array([[-0.0719251 , -0.07387427,  0.04797938, ..., -0.04963262,
#           -0.0210956 , -0.05481441],
#          [-0.02365119, -0.04340657,  0.03346634, ...,  0.01889155,
#           -0.0573203 , -0.0444475 ],
#          [ 0.01101778,  0.01440835, -0.01316898, ..., -0.01173515,
#           -0.00922631, -0.08095258],
#          ...,
#          [-0.0558175 , -0.06994022,  0.05356707, ..., -0.06298253,
#           -0.05432276, -0.04793743],
#          [ 0.04217953,  0.04237866, -0.03879103, ...,  0.02639171,
#            0.03615869,  0.02588183],
#          [-0.00883744,  0.0158796 , -0.02705142, ..., -0.10110073,
#            0.06703305,  0.04376289]], dtype=float32),
#   array([-0.09664673, -0.08649748, -0.02412845, ...,  0.00091566,
#          -0.04764565, -0.0172196 ], dtype=float32)],
#  40: [array([[-0.07193113, -0.07387936,  0.04444357, ..., -0.0497351 ,
#           -0.02158709, -0.0547385 ],
#          [-0.0236515 , -0.04340692,  0.03746949, ...,  0.01964517,
#           -0.05875462, -0.04387597],
#          [ 0.0110115 ,  0.01440379, -0.01651728, ..., -0.01226157,
#           -0.00961991, -0.08091841],
#          ...,
#          [-0.05581992, -0.06994245,  0.05000055, ..., -0.06404247,
#           -0.05560716, -0.04790981],
#          [ 0.04217853,  0.04237852, -0.03171708, ...,  0.0278279 ,
#            0.03613846,  0.0254114 ],
#          [-0.00884116,  0.01587656, -0.01982055, ..., -0.10100678,
#            0.06648687,  0.04349685]], dtype=float32),
#   array([-0.09665036, -0.08649997, -0.02803222, ...,  0.00140474,
#          -0.04799475, -0.01737161], dtype=float32)],
#  41: [array([[-0.07193522, -0.07388338,  0.04756955, ..., -0.0496757 ,
#           -0.02164395, -0.05471057],
#          [-0.02365225, -0.0434078 ,  0.03801002, ...,  0.02490393,
#           -0.05938452, -0.04371702],
#          [ 0.01100714,  0.0144005 , -0.00877415, ..., -0.01210798,
#           -0.00962558, -0.08095136],
#          ...,
#          [-0.05582111, -0.06994409,  0.05313806, ..., -0.06266148,
#           -0.05666753, -0.0478541 ],
#          [ 0.04217824,  0.04237913, -0.03493641, ...,  0.02754441,
#            0.03716017,  0.02566131],
#          [-0.00884605,  0.01587207, -0.02334745, ..., -0.10099965,
#            0.06677817,  0.04351782]], dtype=float32),
#   array([-0.09665379, -0.08650255, -0.02459336, ...,  0.00103918,
#          -0.0480059 , -0.01740985], dtype=float32)],
#  42: [array([[-0.07193797, -0.07388557,  0.04576413, ..., -0.04973731,
#           -0.02172122, -0.05461473],
#          [-0.02365252, -0.04340804,  0.03618289, ...,  0.02651252,
#           -0.05891887, -0.04330524],
#          [ 0.01100177,  0.01439635, -0.0108788 , ..., -0.01095669,
#           -0.00959472, -0.08073819],
#          ...,
#          [-0.05582206, -0.06994497,  0.05209405, ..., -0.06084144,
#           -0.05685611, -0.04785023],
#          [ 0.04217704,  0.04237796, -0.02966968, ...,  0.02922091,
#            0.03750868,  0.02521029],
#          [-0.00884955,  0.01586961, -0.02066567, ..., -0.09676093,
#            0.06695934,  0.0421508 ]], dtype=float32),
#   array([-0.09665781, -0.08650575, -0.0256431 , ..., -0.00047856,
#          -0.0479873 , -0.01802537], dtype=float32)],
#  43: [array([[-0.0719404 , -0.07388782,  0.04496149, ..., -0.04971487,
#           -0.02128302, -0.05461287],
#          [-0.02365284, -0.04340826,  0.03670865, ...,  0.02661815,
#           -0.05635288, -0.04317696],
#          [ 0.01099876,  0.01439429, -0.00540077, ..., -0.01108967,
#           -0.00881158, -0.0808064 ],
#          ...,
#          [-0.05582167, -0.06994504,  0.05100227, ..., -0.06168418,
#           -0.05699498, -0.04782379],
#          [ 0.04217627,  0.04237743, -0.03359861, ...,  0.02878696,
#            0.0383795 ,  0.02556578],
#          [-0.00885023,  0.0158686 , -0.02445588, ..., -0.09660833,
#            0.06890628,  0.04227165]], dtype=float32),
#   array([-0.09666093, -0.08650805, -0.02572546, ..., -0.00038603,
#          -0.04732548, -0.01800045], dtype=float32)],
#  44: [array([[-0.0719441 , -0.07389309,  0.05041566, ..., -0.05053446,
#           -0.02054465, -0.05480164],
#          [-0.02365553, -0.04341124,  0.04122752, ...,  0.03130368,
#           -0.04980018, -0.04170182],
#          [ 0.01100057,  0.01439662, -0.00822481, ..., -0.01002392,
#           -0.00751064, -0.08190091],
#          ...,
#          [-0.05581202, -0.06993493,  0.05250641, ..., -0.05887466,
#           -0.05635928, -0.04783351],
#          [ 0.0421766 ,  0.04237907, -0.02867038, ...,  0.02857861,
#            0.04053608,  0.02137325],
#          [-0.00885372,  0.01586575, -0.02243412, ..., -0.09657561,
#            0.07183266,  0.04428686]], dtype=float32),
#   array([-0.09666697, -0.08651306, -0.02522692, ..., -0.00153144,
#          -0.04621005, -0.01714385], dtype=float32)],
#  45: [array([[-0.07195132, -0.07389802,  0.04673182, ..., -0.05092159,
#           -0.02064361, -0.05487605],
#          [-0.02365685, -0.04341258,  0.03855247, ...,  0.03147607,
#           -0.04921116, -0.04223884],
#          [ 0.01099308,  0.01439308,  0.0063629 , ..., -0.01103458,
#           -0.00774415, -0.08255026],
#          ...,
#          [-0.05581516, -0.06993511,  0.05048578, ..., -0.06310974,
#           -0.05710938, -0.04780158],
#          [ 0.04217304,  0.04237682, -0.02940384, ...,  0.02885628,
#            0.04064026,  0.02511919],
#          [-0.00886758,  0.0158571 , -0.02721842, ..., -0.09596359,
#            0.07169518,  0.04567324]], dtype=float32),
#   array([-0.0966728 , -0.08651715, -0.02673596, ..., -0.00034264,
#          -0.04643666, -0.01655437], dtype=float32)],
#  46: [array([[-0.07195404, -0.07390088,  0.05171917, ..., -0.0509932 ,
#           -0.02078344, -0.05496491],
#          [-0.02365728, -0.04341296,  0.0387271 , ...,  0.03159951,
#           -0.04961693, -0.04209593],
#          [ 0.01099057,  0.01439119, -0.00318127, ..., -0.01483998,
#           -0.00802861, -0.08281141],
#          ...,
#          [-0.05581406, -0.0699338 ,  0.05477934, ..., -0.07455762,
#           -0.0579728 , -0.04785308],
#          [ 0.04217015,  0.04237464, -0.04013235, ...,  0.03543141,
#            0.0410803 ,  0.02674183],
#          [-0.00887301,  0.01585185, -0.03269836, ..., -0.09640297,
#            0.07167216,  0.04606413]], dtype=float32),
#   array([-0.09667639, -0.0865199 , -0.02322105, ...,  0.0031323 ,
#          -0.04672416, -0.01643259], dtype=float32)],
#  47: [array([[-0.07196071, -0.07390653,  0.0439346 , ..., -0.0511478 ,
#           -0.02090814, -0.05501537],
#          [-0.02365766, -0.04341364,  0.02961703, ...,  0.03212693,
#           -0.05011444, -0.04176981],
#          [ 0.01098941,  0.0143909 , -0.00253832, ..., -0.01416202,
#           -0.00835576, -0.08284689],
#          ...,
#          [-0.05581035, -0.06993063,  0.04673441, ..., -0.07168845,
#           -0.05873753, -0.04781477],
#          [ 0.0421698 ,  0.04237611, -0.0416402 , ...,  0.03501631,
#            0.04138586,  0.02524334],
#          [-0.00887907,  0.01584692, -0.04132348, ..., -0.0966496 ,
#            0.07133244,  0.04608944]], dtype=float32),
#   array([-0.09668114, -0.08652324, -0.02746554, ...,  0.0022899 ,
#          -0.04702054, -0.01645109], dtype=float32)],
#  48: [array([[-0.07196523, -0.07391101,  0.0467045 , ..., -0.05133568,
#           -0.01747156, -0.05507011],
#          [-0.023658  , -0.04341423,  0.03288171, ...,  0.03251459,
#           -0.0389118 , -0.04131236],
#          [ 0.01099012,  0.01439239, -0.001658  , ..., -0.02435265,
#           -0.00424062, -0.0831317 ],
#          ...,
#          [-0.05580916, -0.06992937,  0.05128857, ..., -0.08728487,
#           -0.05928766, -0.04773026],
#          [ 0.04216812,  0.04237527, -0.0322727 , ...,  0.04552139,
#            0.03641422,  0.02724085],
#          [-0.00888796,  0.01583847, -0.02949697, ..., -0.1085591 ,
#            0.07287384,  0.0463642 ]], dtype=float32),
#   array([-0.09668544, -0.08652663, -0.02489445, ...,  0.01155795,
#          -0.04343619, -0.01636888], dtype=float32)],
#  49: [array([[-0.07197145, -0.073917  ,  0.04997433, ..., -0.05072879,
#           -0.01624467, -0.05570401],
#          [-0.02365878, -0.04341506,  0.03027813, ...,  0.03373489,
#           -0.03738837, -0.03859635],
#          [ 0.01098662,  0.01438949, -0.00810547, ..., -0.00610135,
#           -0.0022507 , -0.08828401],
#          ...,
#          [-0.05580729, -0.06992741,  0.05258642, ..., -0.0711916 ,
#           -0.0732308 , -0.04768081],
#          [ 0.04216686,  0.04237485, -0.03330788, ...,  0.04032264,
#            0.02205205,  0.00439593],
#          [-0.00888974,  0.01583751, -0.01843879, ..., -0.08424012,
#            0.08388337,  0.05581878]], dtype=float32),
#   array([-0.09668941, -0.08652954, -0.0225971 , ..., -0.00638302,
#          -0.04171347, -0.01205296], dtype=float32)],
#  50: [array([[-0.07197629, -0.07392336,  0.04981994, ..., -0.05361835,
#           -0.01844764, -0.05567786],
#          [-0.02365927, -0.04341568,  0.03587946, ...,  0.03229302,
#           -0.03858927, -0.0366708 ],
#          [ 0.01098395,  0.01438656, -0.00425526, ..., -0.01611158,
#           -0.00454411, -0.08807562],
#          ...,
#          [-0.05580667, -0.06992704,  0.05382386, ..., -0.08709023,
#           -0.07570145, -0.04742285],
#          [ 0.04216715,  0.04237478, -0.03564483, ...,  0.05018357,
#            0.0229361 ,  0.00018033],
#          [-0.00889915,  0.01582724, -0.02519674, ..., -0.0830318 ,
#            0.08572683,  0.05520824]], dtype=float32),
#   array([-0.09669294, -0.08653262, -0.02255537, ...,  0.00411383,
#          -0.04379379, -0.0124193 ], dtype=float32)],
#  51: [array([[-0.07198543, -0.07393859,  0.04728955, ..., -0.05320012,
#           -0.01930218, -0.0555292 ],
#          [-0.02365986, -0.04341635,  0.03253686, ...,  0.0476588 ,
#           -0.03923224, -0.03237568],
#          [ 0.01098387,  0.01439089, -0.00940862, ..., -0.01361004,
#           -0.00538623, -0.08670326],
#          ...,
#          [-0.05581076, -0.06993514,  0.05178742, ..., -0.07008515,
#           -0.07707656, -0.04728079],
#          [ 0.0421642 ,  0.04236963, -0.03638061, ...,  0.04625719,
#            0.02336267, -0.00086072],
#          [-0.00892656,  0.01578174, -0.01355234, ..., -0.08306196,
#            0.0862384 ,  0.0526546 ]], dtype=float32),
#   array([-0.09669972, -0.08654092, -0.02356992, ...,  0.00153172,
#          -0.04457251, -0.01378298], dtype=float32)],
#  52: [array([[-0.07198877, -0.07394198,  0.04646476, ..., -0.05334393,
#           -0.02002267, -0.05532934],
#          [-0.02366   , -0.04341645,  0.03980493, ...,  0.04944805,
#           -0.03918834, -0.02973814],
#          [ 0.01097986,  0.01438808,  0.00546301, ..., -0.0150416 ,
#           -0.0062558 , -0.08564495],
#          ...,
#          [-0.05581145, -0.06993627,  0.05102518, ..., -0.07496441,
#           -0.07850253, -0.0472137 ],
#          [ 0.04216325,  0.0423691 , -0.03168907, ...,  0.0505875 ,
#            0.02385797, -0.00153949],
#          [-0.00893229,  0.01577677, -0.01498529, ..., -0.08321292,
#            0.08607681,  0.05066995]], dtype=float32),
#   array([-0.09670297, -0.08654329, -0.02528865, ...,  0.0029422 ,
#          -0.0453895 , -0.01482373], dtype=float32)],
#  53: [array([[-0.07199369, -0.07394775,  0.04794335, ..., -0.0531587 ,
#           -0.02083144, -0.05019595],
#          [-0.02366041, -0.04341687,  0.0342741 , ...,  0.04948315,
#           -0.04001012, -0.02850986],
#          [ 0.01097537,  0.01438363,  0.00490474, ..., -0.01530927,
#           -0.00723036, -0.08384305],
#          ...,
#          [-0.05581248, -0.06993818,  0.04903905, ..., -0.0761439 ,
#           -0.07983498, -0.0470097 ],
#          [ 0.04216266,  0.04236858, -0.03239336, ...,  0.05123098,
#            0.02417718, -0.00876491],
#          [-0.00893714,  0.01577189, -0.00801348, ..., -0.08294099,
#            0.08662954,  0.04774472]], dtype=float32),
#   array([-0.09670679, -0.08654612, -0.02284383, ...,  0.00326084,
#          -0.04626711, -0.01651088], dtype=float32)],
#  54: [array([[-0.07200071, -0.07395387,  0.05140351, ..., -0.05320887,
#           -0.02136697, -0.04995152],
#          [-0.02366024, -0.04341684,  0.04020177, ...,  0.05013849,
#           -0.04031613, -0.02779994],
#          [ 0.01096803,  0.01437813,  0.02315767, ..., -0.02105705,
#           -0.00784227, -0.08345936],
#          ...,
#          [-0.05581572, -0.06994054,  0.05619102, ..., -0.09005561,
#           -0.08029927, -0.04701973],
#          [ 0.04216037,  0.04236767, -0.04710933, ...,  0.06508227,
#            0.02453743, -0.00918948],
#          [-0.00894597,  0.01576607, -0.01915888, ..., -0.08700245,
#            0.08675627,  0.04696988]], dtype=float32),
#   array([-0.0967114 , -0.08654929, -0.02053152, ...,  0.01002124,
#          -0.04685764, -0.01689318], dtype=float32)],
#  55: [array([[-0.07200412, -0.07395751,  0.05268547, ..., -0.04765709,
#           -0.02225897, -0.04981178],
#          [-0.02366027, -0.04341694,  0.03173338, ...,  0.05151358,
#           -0.04016074, -0.02650689],
#          [ 0.01096416,  0.01437514,  0.00977815, ..., -0.00767422,
#           -0.00873479, -0.08291864],
#          ...,
#          [-0.05581674, -0.06994187,  0.05840094, ..., -0.06523412,
#           -0.08179229, -0.04703426],
#          [ 0.0421599 ,  0.04236742, -0.04317628, ...,  0.03941854,
#            0.02476581, -0.01024123],
#          [-0.00894977,  0.01576296, -0.02457773, ..., -0.06638347,
#            0.08780609,  0.04589577]], dtype=float32),
#   array([-0.09671468, -0.0865517 , -0.01912415, ..., -0.01064403,
#          -0.04766193, -0.01740951], dtype=float32)],
#  56: [array([[-0.07201949, -0.07397187,  0.04982292, ..., -0.04944864,
#           -0.02270306, -0.04993529],
#          [-0.02365994, -0.04341672,  0.04653465, ...,  0.05114598,
#           -0.04009346, -0.02560656],
#          [ 0.01094789,  0.01436079,  0.00785309, ..., -0.01518135,
#           -0.00908761, -0.08281437],
#          ...,
#          [-0.05582823, -0.06995115,  0.055202  , ..., -0.0718752 ,
#           -0.08222584, -0.04710598],
#          [ 0.04215658,  0.04236485, -0.04170403, ...,  0.06318825,
#            0.02476777, -0.01066002],
#          [-0.0089453 ,  0.0157662 , -0.01904504, ..., -0.0699273 ,
#            0.08753991,  0.04575291]], dtype=float32),
#   array([-0.09672077, -0.0865562 , -0.02483919, ...,  0.00348456,
#          -0.04798786, -0.01749167], dtype=float32)],
#  57: [array([[-0.07202678, -0.0739793 ,  0.04916112, ..., -0.0496206 ,
#           -0.02291517, -0.05887473],
#          [-0.02366069, -0.04341706,  0.04022609, ...,  0.05255598,
#           -0.03995496, -0.00552986],
#          [ 0.01093809,  0.014352  ,  0.00098751, ..., -0.01568593,
#           -0.0094965 , -0.08562315],
#          ...,
#          [-0.05583084, -0.06995362,  0.0585203 , ..., -0.06894046,
#           -0.08232588, -0.04684209],
#          [ 0.04215547,  0.04236433, -0.03556879, ...,  0.06628008,
#            0.02516839, -0.04392073],
#          [-0.00894857,  0.01576305, -0.0135047 , ..., -0.07033893,
#            0.08760925,  0.06412087]], dtype=float32),
#   array([-0.09672538, -0.08655946, -0.02206555, ...,  0.0029969 ,
#          -0.04835866, -0.0044024 ], dtype=float32)],
#  58: [array([[-0.07203089, -0.07398302,  0.04990874, ..., -0.0498057 ,
#           -0.02305377, -0.04780613],
#          [-0.02366063, -0.04341688,  0.04397931, ...,  0.05269269,
#           -0.03995906,  0.00543273],
#          [ 0.0109326 ,  0.01434752,  0.00435493, ..., -0.02106933,
#           -0.00976832, -0.07123899],
#          ...,
#          [-0.05583113, -0.06995416,  0.05712328, ..., -0.07624759,
#           -0.08263753, -0.04713341],
#          [ 0.04215519,  0.04236466, -0.03913026, ...,  0.07645248,
#            0.02524817, -0.01557381],
#          [-0.00895378,  0.01575828, -0.02013663, ..., -0.06999317,
#            0.08765975,  0.02824293]], dtype=float32),
#   array([-0.09672862, -0.08656175, -0.02265111, ...,  0.01092148,
#          -0.04860457, -0.0368169 ], dtype=float32)],
#  59: [array([[-0.07203793, -0.07399146,  0.04782603, ..., -0.04901479,
#           -0.0232757 , -0.04874565],
#          [-0.02366074, -0.04341717,  0.03688861, ...,  0.0587006 ,
#           -0.03991653,  0.00449439],
#          [ 0.01092372,  0.01433727, -0.00412271, ..., -0.00871974,
#           -0.01003974, -0.07448497],
#          ...,
#          [-0.05583319, -0.06995738,  0.05613007, ..., -0.05085988,
#           -0.0829227 , -0.04734582],
#          [ 0.04215549,  0.04236586, -0.04443516, ...,  0.0882991 ,
#            0.02555202, -0.01409954],
#          [-0.00896266,  0.01574944, -0.02149019, ..., -0.05160774,
#            0.08769476,  0.03099092]], dtype=float32),
#   array([-0.09673323, -0.08656576, -0.02290884, ..., -0.01086649,
#          -0.04885272, -0.03425594], dtype=float32)],
#  60: [array([[-0.07204203, -0.07399622,  0.05318474, ..., -0.0501404 ,
#           -0.02347204, -0.04885031],
#          [-0.0236588 , -0.04341596,  0.04717069, ...,  0.05785926,
#           -0.04002178,  0.00440306],
#          [ 0.01091543,  0.01432941, -0.01752971, ..., -0.01842471,
#           -0.01024465, -0.07474373],
#          ...,
#          [-0.05583315, -0.06995775,  0.058199  , ..., -0.05744583,
#           -0.08313397, -0.04751338],
#          [ 0.04215364,  0.04236497, -0.04318855, ...,  0.10145103,
#            0.02586   , -0.01413017],
#          [-0.00896367,  0.01574911, -0.02227558, ..., -0.05184356,
#            0.08788998,  0.03111226]], dtype=float32),
#   array([-0.0967381 , -0.0865694 , -0.02132567, ..., -0.00309653,
#          -0.04904425, -0.0341448 ], dtype=float32)],
#  61: [array([[-0.07204598, -0.07400007,  0.05080314, ..., -0.05038814,
#           -0.02369473, -0.04906295],
#          [-0.02365798, -0.0434156 ,  0.03790404, ...,  0.05781202,
#           -0.04008237,  0.00402587],
#          [ 0.01091038,  0.01432458, -0.01585755, ..., -0.02016048,
#           -0.01046385, -0.0755939 ],
#          ...,
#          [-0.0558341 , -0.06995878,  0.05752186, ..., -0.05833405,
#           -0.08334129, -0.04757409],
#          [ 0.04215088,  0.04236351, -0.04282859, ...,  0.10272945,
# ...
#           -0.09009962, -0.04857874],
#          [ 0.04214727,  0.04237608, -0.05447877, ...,  0.10690296,
#            0.01605011, -0.01282197],
#          [-0.00918465,  0.01551047, -0.0266062 , ..., -0.05400366,
#            0.09562629,  0.04041925]], dtype=float32),
#   array([-0.09686516, -0.08667338, -0.01337034, ...,  0.00879505,
#          -0.04913201, -0.02561756], dtype=float32)],
#  80: [array([[-0.07223641, -0.0741953 ,  0.06343468, ..., -0.05208153,
#           -0.02212939, -0.04663425],
#          [-0.02365851, -0.04342081,  0.08186201, ...,  0.06118949,
#           -0.03005355, -0.00176561],
#          [ 0.0106614 ,  0.01407109, -0.00053299, ..., -0.03147205,
#           -0.01022673, -0.08681322],
#          ...,
#          [-0.05580379, -0.06988679,  0.06935441, ..., -0.0817401 ,
#           -0.09100069, -0.04806212],
#          [ 0.04214446,  0.04237135, -0.05448302, ...,  0.10609059,
#            0.01558747, -0.00243941],
#          [-0.00918363,  0.01550974, -0.02912614, ..., -0.05115791,
#            0.0959681 ,  0.0313492 ]], dtype=float32),
#   array([-0.09687144, -0.08667942, -0.01185618, ...,  0.00682725,
#          -0.04939259, -0.03415545], dtype=float32)],
#  81: [array([[-0.07224655, -0.07420735,  0.06046264, ..., -0.05207089,
#           -0.02249796, -0.04827469],
#          [-0.02365833, -0.04342071,  0.08268462, ...,  0.06142041,
#           -0.03015995, -0.00920037],
#          [ 0.01066086,  0.01407033, -0.01048384, ..., -0.03139561,
#           -0.01033324, -0.09112585],
#          ...,
#          [-0.05579734, -0.06988072,  0.06717056, ..., -0.08167227,
#           -0.09131044, -0.04811278],
#          [ 0.04214456,  0.04237184, -0.04919416, ...,  0.10603705,
#            0.01540597, -0.00508595],
#          [-0.00921445,  0.0154788 , -0.01685878, ..., -0.05104323,
#            0.09590954,  0.03375979]], dtype=float32),
#   array([-0.09687974, -0.08668654, -0.01480003, ...,  0.00669133,
#          -0.04952557, -0.03189066], dtype=float32)],
#  82: [array([[-0.07225437, -0.07421602,  0.05646569, ..., -0.05207545,
#           -0.02270396, -0.04839256],
#          [-0.02365793, -0.04342039,  0.07289026, ...,  0.0623074 ,
#           -0.03003497, -0.00960324],
#          [ 0.0106554 ,  0.01406713, -0.0098316 , ..., -0.03111879,
#           -0.01035517, -0.0914588 ],
#          ...,
#          [-0.05580213, -0.06988566,  0.06265278, ..., -0.0805187 ,
#           -0.09180415, -0.04816767],
#          [ 0.04214532,  0.04237286, -0.04761282, ...,  0.10598405,
#            0.01481562, -0.00522681],
#          [-0.00921694,  0.01547268, -0.02148876, ..., -0.05096915,
#            0.09635291,  0.03391368]], dtype=float32),
#   array([-0.09688436, -0.08669034, -0.01590098, ...,  0.00604177,
#          -0.04957438, -0.03174849], dtype=float32)],
#  83: [array([[-0.07226139, -0.07422421,  0.05496349, ..., -0.05213431,
#           -0.02310399, -0.04851428],
#          [-0.02365785, -0.04342033,  0.0810198 , ...,  0.06257342,
#           -0.0303304 , -0.01001076],
#          [ 0.01064579,  0.01405722, -0.00788623, ..., -0.03093884,
#           -0.01055884, -0.09208004],
#          ...,
#          [-0.05579876, -0.06988267,  0.06228947, ..., -0.08037429,
#           -0.0920902 , -0.04819773],
#          [ 0.04214639,  0.0423742 , -0.05160871, ...,  0.10589131,
#            0.01478687, -0.00538661],
#          [-0.00921792,  0.01547078, -0.02848881, ..., -0.05093133,
#            0.09653538,  0.03416835]], dtype=float32),
#   array([-0.09689023, -0.08669522, -0.01592758, ...,  0.00580774,
#          -0.04977585, -0.03151321], dtype=float32)],
#  84: [array([[-0.0722676 , -0.07423044,  0.05451117, ..., -0.05233965,
#           -0.02669352, -0.04862646],
#          [-0.02365789, -0.04342039,  0.0695302 , ...,  0.06291454,
#           -0.03372595, -0.01047361],
#          [ 0.01063457,  0.01404696, -0.01533501, ..., -0.03075666,
#           -0.01122862, -0.0925052 ],
#          ...,
#          [-0.05579646, -0.06988145,  0.06181882, ..., -0.08029096,
#           -0.09233068, -0.04820927],
#          [ 0.04214619,  0.04237423, -0.05397922, ...,  0.10579171,
#            0.01440039, -0.00545364],
#          [-0.0092222 ,  0.01546684, -0.02731446, ..., -0.05092813,
#            0.09492697,  0.03434179]], dtype=float32),
#   array([-0.09689774, -0.08670104, -0.01579671, ...,  0.00561303,
#          -0.05072692, -0.03135215], dtype=float32)],
#  85: [array([[-0.07227404, -0.07423702,  0.05445277, ..., -0.05256879,
#           -0.02729006, -0.0487085 ],
#          [-0.02365705, -0.04341957,  0.0772095 , ...,  0.06331804,
#           -0.03376881, -0.01131108],
#          [ 0.01063034,  0.01404494, -0.01025168, ..., -0.02885655,
#           -0.01144312, -0.09307204],
#          ...,
#          [-0.05579227, -0.06987554,  0.06026156, ..., -0.07881285,
#           -0.09278695, -0.04824885],
#          [ 0.04214549,  0.04237409, -0.04946074, ...,  0.10467757,
#            0.01428943, -0.00557521],
#          [-0.0092231 ,  0.0154665 , -0.02008882, ..., -0.04861908,
#            0.09494183,  0.03458844]], dtype=float32),
#   array([-0.09690317, -0.0867055 , -0.01671384, ...,  0.00411176,
#          -0.05094964, -0.03112206], dtype=float32)],
#  86: [array([[-0.07227965, -0.0742426 ,  0.0557295 , ..., -0.05306619,
#           -0.02733243, -0.04879164],
#          [-0.02365701, -0.04341955,  0.07701931, ...,  0.06343709,
#           -0.03351546, -0.01272937],
#          [ 0.01062952,  0.01404645, -0.01027204, ..., -0.0287463 ,
#           -0.01140399, -0.09449984],
#          ...,
#          [-0.05579199, -0.06987374,  0.05911664, ..., -0.07856672,
#           -0.09283912, -0.04829208],
#          [ 0.04214463,  0.04237404, -0.04951772, ...,  0.10467984,
#            0.01409838, -0.00619742],
#          [-0.00922483,  0.01546564, -0.0264625 , ..., -0.0485815 ,
#            0.09517763,  0.03516605]], dtype=float32),
#   array([-0.09690744, -0.08670919, -0.01587616, ...,  0.00397987,
#          -0.05092546, -0.03058226], dtype=float32)],
#  87: [array([[-0.07228331, -0.07424677,  0.0582054 , ..., -0.0532302 ,
#           -0.02718322, -0.04885563],
#          [-0.02365643, -0.04341899,  0.07900643, ...,  0.06290159,
#           -0.03276994, -0.01142063],
#          [ 0.01062608,  0.01404358,  0.0030402 , ..., -0.03034006,
#           -0.01121718, -0.0958362 ],
#          ...,
#          [-0.05579005, -0.06986999,  0.06183001, ..., -0.08290229,
#           -0.09288804, -0.04835452],
#          [ 0.04214627,  0.04237552, -0.04936872, ...,  0.10717745,
#            0.0135187 , -0.00654588],
#          [-0.00922205,  0.01546918, -0.02623385, ..., -0.04746305,
#            0.0956113 ,  0.03571197]], dtype=float32),
#   array([-0.09691376, -0.08671466, -0.01378178, ...,  0.00587299,
#          -0.05076897, -0.03007183], dtype=float32)],
#  88: [array([[-0.07227718, -0.07423773,  0.0573589 , ..., -0.05322491,
#           -0.02699153, -0.04892199],
#          [-0.02365684, -0.04341953,  0.07710823, ...,  0.06326129,
#           -0.03204308, -0.0121004 ],
#          [ 0.01062651,  0.01404655, -0.00516146, ..., -0.03001305,
#           -0.01101965, -0.09621276],
#          ...,
#          [-0.05578523, -0.06986368,  0.06238176, ..., -0.08282894,
#           -0.09297195, -0.04865503],
#          [ 0.04214809,  0.04237796, -0.0570348 , ...,  0.10704559,
#            0.0129396 , -0.00658109],
#          [-0.00922601,  0.01546548, -0.03360426, ..., -0.04773876,
#            0.09615026,  0.03586519]], dtype=float32),
#   array([-0.0969236 , -0.08672281, -0.01379575, ...,  0.00558812,
#          -0.05061651, -0.02994039], dtype=float32)],
#  89: [array([[-0.07228677, -0.07424881,  0.05106319, ..., -0.05375457,
#           -0.02740881, -0.04898157],
#          [-0.02365742, -0.04342   ,  0.07730168, ...,  0.06332559,
#           -0.03227333, -0.01234934],
#          [ 0.01061639,  0.01403634, -0.00685444, ..., -0.02999874,
#           -0.01123752, -0.09673969],
#          ...,
#          [-0.05578639, -0.06986544,  0.05471691, ..., -0.08290667,
#           -0.09315547, -0.04869775],
#          [ 0.04214842,  0.04237788, -0.03889913, ...,  0.10703369,
#            0.01323749, -0.00677009],
#          [-0.00922833,  0.01546561, -0.02645443, ..., -0.0477249 ,
#            0.09651689,  0.0360809 ]], dtype=float32),
#   array([-0.09692995, -0.08672803, -0.01952444, ...,  0.00555092,
#          -0.05084642, -0.02974014], dtype=float32)],
#  90: [array([[-0.07232133, -0.0742748 ,  0.05741817, ..., -0.05485894,
#           -0.02721831, -0.04904207],
#          [-0.02364998, -0.04341587,  0.080564  , ...,  0.063454  ,
#           -0.03206595, -0.01165991],
#          [ 0.0105768 ,  0.01400929, -0.0007319 , ..., -0.03000034,
#           -0.01122232, -0.09673239],
#          ...,
#          [-0.05582197, -0.06988834,  0.06454954, ..., -0.08311395,
#           -0.09321421, -0.04870677],
#          [ 0.04214486,  0.04237512, -0.05278896, ...,  0.10700264,
#            0.01348223, -0.00684817],
#          [-0.00920019,  0.01547664, -0.01826217, ..., -0.04786523,
#            0.0968105 ,  0.03611162]], dtype=float32),
#   array([-0.09695133, -0.08674104, -0.01374921, ...,  0.00551631,
#          -0.05085612, -0.02971628], dtype=float32)],
#  91: [array([[-0.07233   , -0.07428446,  0.05602682, ..., -0.0557996 ,
#           -0.02561399, -0.04915075],
#          [-0.02365073, -0.04341634,  0.08023339, ...,  0.06346233,
#           -0.0298493 , -0.01166766],
#          [ 0.01057128,  0.01400436, -0.00228935, ..., -0.03047914,
#           -0.01067476, -0.09727654],
#          ...,
#          [-0.0558233 , -0.06989087,  0.0581449 , ..., -0.0841514 ,
#           -0.09327226, -0.04882164],
#          [ 0.0421423 ,  0.04237281, -0.04918621, ...,  0.1073391 ,
#            0.0133862 , -0.00712109],
#          [-0.00920964,  0.015466  , -0.01809743, ..., -0.04804353,
#            0.09819219,  0.03652705]], dtype=float32),
#   array([-0.09695891, -0.08674709, -0.01595083, ...,  0.00581564,
#          -0.05039022, -0.02932825], dtype=float32)],
#  92: [array([[-0.07235781, -0.07431684,  0.05757746, ..., -0.0559768 ,
#           -0.02538903, -0.04922273],
#          [-0.02364955, -0.04341535,  0.090291  , ...,  0.06354383,
#           -0.02974765, -0.01153913],
#          [ 0.01053169,  0.01396073, -0.01287075, ..., -0.0330515 ,
#           -0.01074713, -0.09764446],
#          ...,
#          [-0.05579865, -0.0698668 ,  0.05980615, ..., -0.08873728,
#           -0.09341668, -0.04883097],
#          [ 0.04213564,  0.04236754, -0.05900585, ...,  0.11127628,
#            0.01346026, -0.00712691],
#          [-0.00916672,  0.01551137, -0.0166997 , ..., -0.04820664,
#            0.09850548,  0.03666545]], dtype=float32),
#   array([-0.09697463, -0.08676101, -0.01445211, ...,  0.00765204,
#          -0.0504654 , -0.02920136], dtype=float32)],
#  93: [array([[-0.0723673 , -0.07432589,  0.05506695, ..., -0.05608053,
#           -0.02547718, -0.0490164 ],
#          [-0.02365018, -0.0434159 ,  0.09131499, ...,  0.06359402,
#           -0.02980791, -0.0114    ],
#          [ 0.01052709,  0.01395771, -0.0087277 , ..., -0.03341911,
#           -0.01083605, -0.09766863],
#          ...,
#          [-0.05579486, -0.06986243,  0.05370457, ..., -0.08955753,
#           -0.09349319, -0.04883391],
#          [ 0.04213357,  0.04236628, -0.05712472, ...,  0.11202336,
#            0.01358102, -0.00613222],
#          [-0.00915932,  0.01551714, -0.02587272, ..., -0.04820382,
#            0.09861693,  0.03576024]], dtype=float32),
#   array([-0.09698264, -0.08676733, -0.01688464, ...,  0.00789135,
#          -0.05057281, -0.03006051], dtype=float32)],
#  94: [array([[-0.07237219, -0.07433071,  0.05104209, ..., -0.05605808,
#           -0.02562304, -0.04927519],
#          [-0.02365073, -0.04341645,  0.09821916, ...,  0.06375483,
#           -0.03010136, -0.00848898],
#          [ 0.01051993,  0.0139501 , -0.02599409, ..., -0.03330193,
#           -0.01120555, -0.10030515],
#          ...,
#          [-0.05579356, -0.0698608 ,  0.05296574, ..., -0.08971547,
#           -0.09397776, -0.04851134],
#          [ 0.04213534,  0.04236845, -0.05574145, ...,  0.11174224,
#            0.01426436, -0.0074982 ],
#          [-0.00917112,  0.01550577, -0.01744601, ..., -0.04852851,
#            0.09802934,  0.03682311]], dtype=float32),
#   array([-0.09699072, -0.08677395, -0.0207175 , ...,  0.00776448,
#          -0.05096202, -0.02906778], dtype=float32)],
#  95: [array([[-0.07238009, -0.07433926,  0.05539028, ..., -0.05655312,
#           -0.02854638, -0.04945556],
#          [-0.02364718, -0.04341437,  0.1040597 , ...,  0.06410529,
#           -0.03275028, -0.00830328],
#          [ 0.0105044 ,  0.01393807, -0.02145601, ..., -0.03165232,
#           -0.01227885, -0.10047849],
#          ...,
#          [-0.05579368, -0.06986162,  0.05237301, ..., -0.08939533,
#           -0.09733993, -0.04849843],
#          [ 0.04212987,  0.04236504, -0.04741778, ...,  0.10946598,
#            0.01474387, -0.00761464],
#          [-0.00918057,  0.0154973 , -0.01721496, ..., -0.04827292,
#            0.09965076,  0.03685658]], dtype=float32),
#   array([-0.09700248, -0.08678307, -0.02017455, ...,  0.00660435,
#          -0.05192675, -0.02904903], dtype=float32)],
#  96: [array([[-0.07238972, -0.07435117,  0.06113967, ..., -0.05701283,
#           -0.02920508, -0.04964128],
#          [-0.02364698, -0.04341446,  0.10348433, ...,  0.06530074,
#           -0.03280682, -0.0081584 ],
#          [ 0.01049084,  0.01392222, -0.01473141, ..., -0.02978875,
#           -0.01231   , -0.10060217],
#          ...,
#          [-0.05580157, -0.06987046,  0.06016971, ..., -0.08874085,
#           -0.09816282, -0.04850714],
#          [ 0.04212088,  0.04235426, -0.0530696 , ...,  0.10931884,
#            0.01457584, -0.00760589],
#          [-0.00920548,  0.0154664 , -0.01844807, ..., -0.04899812,
#            0.10059232,  0.03683044]], dtype=float32),
#   array([-0.09701391, -0.08679269, -0.011368  , ...,  0.00548698,
#          -0.05197953, -0.02908715], dtype=float32)],
#  97: [array([[-0.07240337, -0.07436801,  0.06210474, ..., -0.05729339,
#           -0.02924159, -0.0498262 ],
#          [-0.02364719, -0.04341471,  0.09677768, ...,  0.06544168,
#           -0.03261247, -0.0081281 ],
#          [ 0.01047832,  0.01390631, -0.01471949, ..., -0.03352183,
#           -0.01238316, -0.10077663],
#          ...,
#          [-0.05580442, -0.06987382,  0.05968473, ..., -0.09653287,
#           -0.09838994, -0.04852525],
#          [ 0.04211912,  0.04235291, -0.05121533, ...,  0.1127293 ,
#            0.01440592, -0.0075844 ],
#          [-0.00921737,  0.01545686, -0.0184237 , ..., -0.05376266,
#            0.10075526,  0.03689326]], dtype=float32),
#   array([-0.09702446, -0.08680189, -0.01159203, ...,  0.00867387,
#          -0.05206871, -0.02903905], dtype=float32)],
#  98: [array([[-0.07244726, -0.07442124,  0.05211775, ..., -0.05759142,
#           -0.02919327, -0.05377482],
#          [-0.02364671, -0.04341418,  0.10075972, ...,  0.06552993,
#           -0.03247019, -0.00955884],
#          [ 0.01041824,  0.01383364, -0.02523772, ..., -0.03304398,
#           -0.01213726, -0.10323483],
#          ...,
#          [-0.05584473, -0.06992111,  0.05254362, ..., -0.09531386,
#           -0.09862912, -0.04912943],
#          [ 0.04211885,  0.04235253, -0.04754028, ...,  0.11202825,
#            0.01529575,  0.00100304],
#          [-0.00919761,  0.01547485, -0.0219854 , ..., -0.05339108,
#            0.10155381,  0.04661162]], dtype=float32),
#   array([-0.09704553, -0.08682218, -0.0187784 , ...,  0.00816512,
#          -0.05187653, -0.01986833], dtype=float32)],
#  99: [array([[-0.07246386, -0.07443805,  0.05919933, ..., -0.05886287,
#           -0.02910812, -0.04166326],
#          [-0.02364666, -0.04341401,  0.09649333, ...,  0.06567062,
#           -0.03243062, -0.0128303 ],
#          [ 0.01040279,  0.0138187 , -0.00639413, ..., -0.03277957,
#           -0.01204384, -0.0996283 ],
#          ...,
#          [-0.0558551 , -0.06993234,  0.05681328, ..., -0.09470885,
#           -0.09872441, -0.04348541],
#          [ 0.04211668,  0.04235082, -0.04571272, ...,  0.11185518,
#            0.01568808,  0.00564844],
#          [-0.00921106,  0.01546218, -0.01044673, ..., -0.0538368 ,
#            0.10183998,  0.01790542]], dtype=float32),
#   array([-0.09705596, -0.08683077, -0.01474901, ...,  0.0078471 ,
#          -0.05181262, -0.04829824], dtype=float32)]}

# %%
# Converts the unicode file to ascii
def unicode_to_ascii(s):
  return ''.join(c for c in unicodedata.normalize('NFD', s)
                 if unicodedata.category(c) != 'Mn')


def preprocess_sentence(w):
  w = unicode_to_ascii(w.lower().strip())

  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,¿])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  w = re.sub(r"[^a-zA-Z?.!,¿]+", " ", w)

  w = w.strip()

  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
  w = '<start> ' + w + ' <end>'
  return w

# %%
def evaluate(sentence):
  attention_plot = np.zeros((max_length_targ, max_length_inp))

  sentence = preprocess_sentence(sentence)

  inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, units))]
  enc_out, enc_hidden = encoder(inputs, hidden)

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  for t in range(max_length_targ):
    predictions, dec_hidden, attention_weights = decoder(dec_input,
                                                         dec_hidden,
                                                         enc_out)

    # storing the attention weights to plot later on
    attention_weights = tf.reshape(attention_weights, (-1, ))
    attention_plot[t] = attention_weights.numpy()

    predicted_id = tf.argmax(predictions[0]).numpy()

    result += targ_lang.index_word[predicted_id] + ' '

    if targ_lang.index_word[predicted_id] == '<end>':
      return result, sentence, attention_plot

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence, attention_plot

# %%
# function for plotting the attention weights
def plot_attention(attention, sentence, predicted_sentence):
  fig = plt.figure(figsize=(10, 10))
  ax = fig.add_subplot(1, 1, 1)
  ax.matshow(attention, cmap='viridis')

  fontdict = {'fontsize': 14}

  ax.set_xticklabels([''] + sentence, fontdict=fontdict, rotation=90)
  ax.set_yticklabels([''] + predicted_sentence, fontdict=fontdict)

  ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
  ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

  plt.show()

# %%
def translate(sentence):
  result, sentence, attention_plot = evaluate(sentence)

  print('Input:', sentence)
  print('Predicted translation:', result)

  attention_plot = attention_plot[:len(result.split(' ')),
                                  :len(sentence.split(' '))]
  plot_attention(attention_plot, sentence.split(' '), result.split(' '))

# %%
# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
test_sentence = 'a cirurgia foi um sucesso .'
translate(test_sentence)
# Out:
# Input: <start> a cirurgia foi um sucesso . <end>
# Predicted translation: the surgery was successful . <end>

# %%
np.save("gru_attention_100epoch_1500data_weights.npy", DICT_WEIGHTS)

# %%
# !cp gru_attention_100epoch_1500data_weights.npy "drive/My Drive/DSA5204_mine/GRU_attention"

# %%
pip install -q pyyaml h5py  # Required to save models in HDF5 format

# %%
encoder.save_weights('encoder_GRUattention_100epoch_1500dataset.h5')
# !cp encoder_GRUattention_100epoch_1500dataset.h5 "drive/My Drive/DSA5204_mine/GRU_attention"

# %%
decoder.save_weights('decoder_GRUattention_100epoch_1500dataset.h5')
# !cp decoder_GRUattention_100epoch_1500dataset.h5 "drive/My Drive/DSA5204_mine/GRU_attention"

# %% [markdown]
# To recall the weights, next time call `encoder.load_weights(path_to_load_weights)` or `decoder.load_weights(path_to_load_weights)`
